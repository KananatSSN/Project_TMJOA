# %%
import pandas as pd
import numpy as np

# Read the CSV file
input = r'd:\Kananat\Data\alldata_new_normalized\labels.csv'
df = pd.read_csv(input)

# Extract patient ID from the id column
# Assumes format: 'patient_id_L/R_Year' or 'patient_id_L/R'
df['patient_id'] = df['ID'].str.split(' ').str[0]

# Get unique patient IDs
unique_patients = df['patient_id'].unique()

# Shuffle patient IDs for random assignment
np.random.seed(1)  # Set seed for reproducibility
shuffled_patients = np.random.permutation(unique_patients)

# Calculate split indices
n_patients = len(shuffled_patients)
train_end = int(0.7 * n_patients)
val_end = int(0.9 * n_patients)

# Assign patients to splits
train_patients = set(shuffled_patients[:train_end])
val_patients = set(shuffled_patients[train_end:val_end])
test_patients = set(shuffled_patients[val_end:])

# Create split column based on patient ID
df['split'] = df['patient_id'].apply(
    lambda pid: 'train' if pid in train_patients 
    else ('val' if pid in val_patients else 'test')
)

# Optional: Remove the temporary patient_id column if you don't need it
df = df.drop('patient_id', axis=1)

# Save the result
df.to_csv(input, index=False)

# Print split statistics
print("Split distribution:")
print(f"Train: {len(train_patients)}")
print(f"Val: {len(val_patients)}")
print(f"Test: {len(test_patients)}")
df['split'].value_counts()
# Out:
# Split distribution:
# Train: 275
# Val: 79
# Test: 40

# %%
OA_positive = df[df['OA'] == 1]
train_df = OA_positive[OA_positive['split'] == 'train']
val_df = OA_positive[OA_positive['split'] == 'val']
test_df = OA_positive[OA_positive['split'] == 'test']

# %%
cols = ['erosion', 'subCyst', 'genSclerosis', 'osteophyte', 'flattening']

print("TRAIN")
split_df = train_df
score = 0
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    split_score = 1-abs(pos-neg)/sum(pos_neg)
    score += split_score
    print(f"{col}: {pos_neg}, diff = {split_score:.2f}")
print(score/5)


print("\nVAL")
split_df = val_df
score = 0
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    split_score = 1-abs(pos-neg)/sum(pos_neg)
    score += split_score
    print(f"{col}: {pos_neg}, diff = {split_score:.2f}")
print(score/5)

print("\nTEST")
split_df = test_df
score = 0
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    split_score = 1-abs(pos-neg)/sum(pos_neg)
    score += split_score
    print(f"{col}: {pos_neg}, diff = {split_score:.2f}")
print(score/5)

# %%
from pathlib import Path
import pandas as pd

labels_csv = r"d:\Kananat\Data\alldata_new_normalized\labels.csv"
dataset_source = Path(r"D:\Kananat\Data\alldata_new_normalized")
dataset_target_folder = Path(r"d:\Kananat\Data\Last0\OA")

df = pd.read_csv(labels_csv)
task = 'OA'
check = []

for index, row in df.iterrows():
    select = f"{row['ID'].split(' ')[0]}"
    check.append([select, row['split']])

def check_consistent_splits(data):
    id_to_splits = {}
    inconsistent_ids = []
    
    for id_val, split_val in data:
        if id_val in id_to_splits:
            # If this ID already exists, check if split is different
            if id_to_splits[id_val] != split_val:
                inconsistent_ids.append(id_val)
        else:
            # First time seeing this ID
            id_to_splits[id_val] = split_val
    
    return inconsistent_ids

inconsistent = check_consistent_splits(check)

if inconsistent:
    print(f"IDs with inconsistent splits: {inconsistent}")
else:
    print("All IDs have consistent split values")

# %%
dataset_source = Path(r"D:\Kananat\Data\Last0\3_Preprocessed")

for file in dataset_source.glob("*.nii.gz"):
    print(file.name)

# %%
from pathlib import Path
import pandas as pd
import shutil
import os

labels_csv = r"D:\Kananat\Data\Last0\labels.csv"
dataset_source = Path(r"D:\Kananat\Data\Last0\3_Preprocessed")
dataset_target_folder = Path(r"D:\Kananat\Data\Last0")

df = pd.read_csv(labels_csv)

task = 'OA'
splits = ["train", "val", "test"]
classes = ["0", "1"]

for split in splits:
    for cls in classes:
        dir_path = dataset_target_folder / task / split / cls
        dir_path.mkdir(parents=True, exist_ok=True)

for index, row in df.iterrows():
    file = f"{row['ID']}_preprocessed.nii.gz"
    split = str(row['split'])
    label = str(row[task])
    selected_files = list(dataset_source.glob(file))

    if len(selected_files) != 1:
        print("="*40)
        print(f"Skipping ID: {row['ID']}, found {len(list(selected_files))} files: {list(selected_files)}")
        print("="*40)
        continue
    
    move_to = dataset_target_folder / task / split / label / file
    # print(selected_files[0])

    print(f"Copying [{file}, {split}, {label}] to {move_to}")

    # if os.path.isfile(selected_files[0]):
    #     print(f"File exists: {selected_files[0]}")

    shutil.copy2(selected_files[0], move_to)
# Out:
# Copying [47-4881 L 2014_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-4881 L 2014_preprocessed.nii.gz
# Copying [47-4881 R 2014_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-4881 R 2014_preprocessed.nii.gz
# Copying [54-21497 L 2014_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\54-21497 L 2014_preprocessed.nii.gz
# Copying [54-21497 R 2014_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\54-21497 R 2014_preprocessed.nii.gz
# Copying [57-10397 L 2015_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\57-10397 L 2015_preprocessed.nii.gz
# Copying [57-10397 R 2015_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\57-10397 R 2015_preprocessed.nii.gz
# Copying [54-21497 L 2016_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\54-21497 L 2016_preprocessed.nii.gz
# Copying [54-21497 R 2016_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\54-21497 R 2016_preprocessed.nii.gz
# Copying [52-18852 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\52-18852 L_preprocessed.nii.gz
# Copying [52-18852 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\52-18852 R_preprocessed.nii.gz
# Copying [52-37193 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-37193 L_preprocessed.nii.gz
# Copying [52-37193 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-37193 R_preprocessed.nii.gz
# Copying [54-50 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\54-50 L_preprocessed.nii.gz
# Copying [54-50 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\54-50 R_preprocessed.nii.gz
# Copying [54-25927 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\54-25927 L_preprocessed.nii.gz
# Copying [54-25927 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\54-25927 R_preprocessed.nii.gz
# Copying [57-24983 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\57-24983 L_preprocessed.nii.gz
# Copying [57-24983 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\57-24983 R_preprocessed.nii.gz
# Copying [57-34770 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\57-34770 L_preprocessed.nii.gz
# Copying [57-34770 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\57-34770 R_preprocessed.nii.gz
# Copying [59-6269 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-6269 L_preprocessed.nii.gz
# Copying [48-5955 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\48-5955 L_preprocessed.nii.gz
# Copying [48-5955 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\48-5955 R_preprocessed.nii.gz
# Copying [52-27708 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-27708 R_preprocessed.nii.gz
# Copying [55-1648 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\55-1648 L_preprocessed.nii.gz
# Copying [55-1648 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\55-1648 R_preprocessed.nii.gz
# Copying [56-14343 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\56-14343 L_preprocessed.nii.gz
# Copying [57-28760 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-28760 L_preprocessed.nii.gz
# Copying [57-28760 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-28760 R_preprocessed.nii.gz
# Copying [57-36050 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\57-36050 L_preprocessed.nii.gz
# Copying [57-36050 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\57-36050 R_preprocessed.nii.gz
# Copying [58-15574 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\58-15574 L_preprocessed.nii.gz
# Copying [58-15574 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-15574 R_preprocessed.nii.gz
# Copying [58-32020 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-32020 R_preprocessed.nii.gz
# Copying [58-38918 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-38918 L_preprocessed.nii.gz
# Copying [58-38918 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-38918 R_preprocessed.nii.gz
# Copying [59-35009 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-35009 L_preprocessed.nii.gz
# Copying [59-35009 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-35009 R_preprocessed.nii.gz
# Copying [58-43911 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\58-43911 L_preprocessed.nii.gz
# Copying [58-43911 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\58-43911 R_preprocessed.nii.gz
# Copying [60-16447 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-16447 L_preprocessed.nii.gz
# Copying [60-16447 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-16447 R_preprocessed.nii.gz
# Copying [60-21851 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\60-21851 L_preprocessed.nii.gz
# Copying [60-21851 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-21851 R_preprocessed.nii.gz
# Copying [60-24908 L 2017_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-24908 L 2017_preprocessed.nii.gz
# Copying [60-24908 R 2017_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-24908 R 2017_preprocessed.nii.gz
# Copying [60-25232 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-25232 L_preprocessed.nii.gz
# Copying [60-25232 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-25232 R_preprocessed.nii.gz
# Copying [60-33107 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\60-33107 L_preprocessed.nii.gz
# Copying [60-33107 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\60-33107 R_preprocessed.nii.gz
# Copying [60-33597 L 2017_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-33597 L 2017_preprocessed.nii.gz
# Copying [60-34373 L 2017_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-34373 L 2017_preprocessed.nii.gz
# Copying [60-34373 R 2017_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-34373 R 2017_preprocessed.nii.gz
# Copying [60-4194 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-4194 L_preprocessed.nii.gz
# Copying [60-4194 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-4194 R_preprocessed.nii.gz
# Copying [60-700759 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-700759 L_preprocessed.nii.gz
# Copying [60-700759 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-700759 R_preprocessed.nii.gz
# Copying [60-700919 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\60-700919 L_preprocessed.nii.gz
# Copying [60-700919 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-700919 R_preprocessed.nii.gz
# Copying [60-701005 L 2017_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701005 L 2017_preprocessed.nii.gz
# Copying [60-701005 R 2017_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701005 R 2017_preprocessed.nii.gz
# Copying [60-701042 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701042 L_preprocessed.nii.gz
# Copying [60-701042 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701042 R_preprocessed.nii.gz
# Copying [60-701142 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-701142 L_preprocessed.nii.gz
# Copying [60-701142 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701142 R_preprocessed.nii.gz
# Copying [60-701166 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-701166 L_preprocessed.nii.gz
# Copying [60-701166 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-701166 R_preprocessed.nii.gz
# Copying [60-701195 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701195 L_preprocessed.nii.gz
# Copying [60-7166 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-7166 L_preprocessed.nii.gz
# Copying [60-7166 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-7166 R_preprocessed.nii.gz
# Copying [60-9722 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\60-9722 L_preprocessed.nii.gz
# Copying [60-9722 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\60-9722 R_preprocessed.nii.gz
# Copying [47-16872 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-16872 L_preprocessed.nii.gz
# Copying [47-16872 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-16872 R_preprocessed.nii.gz
# Copying [47-4881 L 2018_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-4881 L 2018_preprocessed.nii.gz
# Copying [47-4881 R 2018_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\47-4881 R 2018_preprocessed.nii.gz
# Copying [51-28114 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\51-28114 L_preprocessed.nii.gz
# Copying [51-28114 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\51-28114 R_preprocessed.nii.gz
# Copying [51-3282 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\51-3282 L_preprocessed.nii.gz
# Copying [51-3282 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\51-3282 R_preprocessed.nii.gz
# Copying [52-11116 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\52-11116 L_preprocessed.nii.gz
# Copying [52-11116 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\52-11116 R_preprocessed.nii.gz
# Copying [55-17177 L 2018_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\55-17177 L 2018_preprocessed.nii.gz
# Copying [55-17177 R 2018_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\55-17177 R 2018_preprocessed.nii.gz
# Copying [55-27313 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\55-27313 L_preprocessed.nii.gz
# Copying [56-18364 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\56-18364 L_preprocessed.nii.gz
# Copying [56-18364 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\56-18364 R_preprocessed.nii.gz
# Copying [57-10397 L 2018_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\57-10397 L 2018_preprocessed.nii.gz
# Copying [57-10397 R 2018_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\57-10397 R 2018_preprocessed.nii.gz
# Copying [59-31824 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-31824 L_preprocessed.nii.gz
# Copying [59-31824 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-31824 R_preprocessed.nii.gz
# Copying [60-2918 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-2918 L_preprocessed.nii.gz
# Copying [60-30757 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-30757 R_preprocessed.nii.gz
# Copying [60-39505 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-39505 L_preprocessed.nii.gz
# Copying [60-39505 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-39505 R_preprocessed.nii.gz
# Copying [61-14198 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\61-14198 L_preprocessed.nii.gz
# Copying [61-14198 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-14198 R_preprocessed.nii.gz
# Copying [61-18860 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-18860 L_preprocessed.nii.gz
# Copying [61-18860 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-18860 R_preprocessed.nii.gz
# Copying [61-21027 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-21027 L_preprocessed.nii.gz
# Copying [61-21027 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-21027 R_preprocessed.nii.gz
# Copying [61-33141 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-33141 L_preprocessed.nii.gz
# Copying [61-33141 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-33141 R_preprocessed.nii.gz
# Copying [61-5225 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-5225 L_preprocessed.nii.gz
# Copying [61-5586 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-5586 L_preprocessed.nii.gz
# Copying [61-5586 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-5586 R_preprocessed.nii.gz
# Copying [61-6974 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-6974 L_preprocessed.nii.gz
# Copying [61-6974 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-6974 R_preprocessed.nii.gz
# Copying [61-700034 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-700034 L_preprocessed.nii.gz
# Copying [61-700034 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-700034 R_preprocessed.nii.gz
# Copying [61-700101 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-700101 L_preprocessed.nii.gz
# Copying [61-700101 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-700101 R_preprocessed.nii.gz
# Copying [61-700554 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-700554 L_preprocessed.nii.gz
# Copying [61-700554 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-700554 R_preprocessed.nii.gz
# Copying [61-700847 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-700847 L_preprocessed.nii.gz
# Copying [61-700847 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-700847 R_preprocessed.nii.gz
# Copying [61-701246 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-701246 L_preprocessed.nii.gz
# Copying [61-701246 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\61-701246 R_preprocessed.nii.gz
# Copying [47-22136 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\47-22136 L_preprocessed.nii.gz
# Copying [47-22136 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\47-22136 R_preprocessed.nii.gz
# Copying [50-30909 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\50-30909 R_preprocessed.nii.gz
# Copying [51-26987 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\51-26987 L_preprocessed.nii.gz
# Copying [51-26987 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\51-26987 R_preprocessed.nii.gz
# Copying [53-13011 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\53-13011 L_preprocessed.nii.gz
# Copying [53-13011 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\53-13011 R_preprocessed.nii.gz
# Copying [56-19232 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\56-19232 L_preprocessed.nii.gz
# Copying [57-29097 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-29097 L_preprocessed.nii.gz
# Copying [57-29097 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-29097 R_preprocessed.nii.gz
# Copying [58-23240 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-23240 L_preprocessed.nii.gz
# Copying [58-23240 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\58-23240 R_preprocessed.nii.gz
# Copying [58-42016 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\58-42016 L_preprocessed.nii.gz
# Copying [58-42016 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\58-42016 R_preprocessed.nii.gz
# Copying [59-33496 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-33496 L_preprocessed.nii.gz
# Copying [59-33496 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-33496 R_preprocessed.nii.gz
# Copying [59-36616 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-36616 L_preprocessed.nii.gz
# Copying [59-36616 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-36616 R_preprocessed.nii.gz
# Copying [60-33597 L 2019 03 11_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-33597 L 2019 03 11_preprocessed.nii.gz
# Copying [60-33597 L 2019 09 02_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\60-33597 L 2019 09 02_preprocessed.nii.gz
# Copying [60-34373 L 2019_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-34373 L 2019_preprocessed.nii.gz
# Copying [60-34373 R 2019_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-34373 R 2019_preprocessed.nii.gz
# Copying [60-38868 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\60-38868 R_preprocessed.nii.gz
# Copying [61-13344 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\61-13344 L_preprocessed.nii.gz
# Copying [61-13344 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\61-13344 R_preprocessed.nii.gz
# Copying [62-12734 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-12734 R_preprocessed.nii.gz
# Copying [62-13410 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-13410 L_preprocessed.nii.gz
# Copying [62-13410 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-13410 R_preprocessed.nii.gz
# Copying [62-1401 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-1401 L_preprocessed.nii.gz
# Copying [62-14053 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\62-14053 L_preprocessed.nii.gz
# Copying [62-14053 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\62-14053 R_preprocessed.nii.gz
# Copying [62-2274 R 2019_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-2274 R 2019_preprocessed.nii.gz
# Copying [62-23102 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-23102 L_preprocessed.nii.gz
# Copying [62-23102 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-23102 R_preprocessed.nii.gz
# Copying [62-25311 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-25311 R_preprocessed.nii.gz
# Copying [62-25333 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\62-25333 L_preprocessed.nii.gz
# Copying [62-25333 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\62-25333 R_preprocessed.nii.gz
# Copying [62-26639 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-26639 L_preprocessed.nii.gz
# Copying [62-26639 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-26639 R_preprocessed.nii.gz
# Copying [62-27556 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-27556 L_preprocessed.nii.gz
# Copying [62-27556 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-27556 R_preprocessed.nii.gz
# Copying [62-330 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-330 L_preprocessed.nii.gz
# Copying [62-700605 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-700605 R_preprocessed.nii.gz
# Copying [62-700851 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-700851 L_preprocessed.nii.gz
# Copying [62-700851 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-700851 R_preprocessed.nii.gz
# Copying [62-701148 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\62-701148 L_preprocessed.nii.gz
# Copying [62-701148 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\62-701148 R_preprocessed.nii.gz
# Copying [62-701248 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-701248 R_preprocessed.nii.gz
# Copying [62-701261 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-701261 L_preprocessed.nii.gz
# Copying [62-701261 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-701261 R_preprocessed.nii.gz
# Copying [54-1411 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\54-1411 L_preprocessed.nii.gz
# Copying [54-1411 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\54-1411 R_preprocessed.nii.gz
# Copying [55-17177 L 2020_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\55-17177 L 2020_preprocessed.nii.gz
# Copying [55-17177 R 2020_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\55-17177 R 2020_preprocessed.nii.gz
# Copying [56-9695 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\56-9695 L_preprocessed.nii.gz
# Copying [56-9695 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\56-9695 R_preprocessed.nii.gz
# Copying [57-24048 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\57-24048 L_preprocessed.nii.gz
# Copying [58-651 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-651 L_preprocessed.nii.gz
# Copying [58-651 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\58-651 R_preprocessed.nii.gz
# Copying [59-24008 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-24008 L_preprocessed.nii.gz
# Copying [61-20310 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-20310 L_preprocessed.nii.gz
# Copying [61-20310 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-20310 R_preprocessed.nii.gz
# Copying [61-21564 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-21564 L_preprocessed.nii.gz
# Copying [61-21564 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-21564 R_preprocessed.nii.gz
# Copying [61-34247 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\61-34247 L_preprocessed.nii.gz
# Copying [61-34247 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\61-34247 R_preprocessed.nii.gz
# Copying [62-12908 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-12908 R_preprocessed.nii.gz
# Copying [62-21678 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-21678 L_preprocessed.nii.gz
# Copying [62-24379 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-24379 R_preprocessed.nii.gz
# Copying [62-34626 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-34626 R_preprocessed.nii.gz
# Copying [62-7533 R 2020_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\62-7533 R 2020_preprocessed.nii.gz
# Copying [63-1330 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-1330 L_preprocessed.nii.gz
# Copying [63-1330 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-1330 R_preprocessed.nii.gz
# Copying [63-17862 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-17862 L_preprocessed.nii.gz
# Copying [63-17862 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-17862 R_preprocessed.nii.gz
# Copying [63-2829 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\63-2829 L_preprocessed.nii.gz
# Copying [63-700223 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-700223 L_preprocessed.nii.gz
# Copying [63-700223 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\63-700223 R_preprocessed.nii.gz
# Copying [63-700385 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\63-700385 L_preprocessed.nii.gz
# Copying [63-700385 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-700385 R_preprocessed.nii.gz
# Copying [63-700449 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\63-700449 L_preprocessed.nii.gz
# Copying [63-700449 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\63-700449 R_preprocessed.nii.gz
# Copying [53-26507 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-26507 L_preprocessed.nii.gz
# Copying [53-26507 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-26507 R_preprocessed.nii.gz
# Copying [56-27847 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\56-27847 L_preprocessed.nii.gz
# Copying [56-27847 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\56-27847 R_preprocessed.nii.gz
# Copying [59-14284 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-14284 L_preprocessed.nii.gz
# Copying [59-14284 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-14284 R_preprocessed.nii.gz
# Copying [59-23032 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\59-23032 R_preprocessed.nii.gz
# Copying [60-701005 L 2021_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-701005 L 2021_preprocessed.nii.gz
# Copying [60-701005 R 2021_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-701005 R 2021_preprocessed.nii.gz
# Copying [61-25724 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-25724 L_preprocessed.nii.gz
# Copying [61-25724 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-25724 R_preprocessed.nii.gz
# Copying [61-32062 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-32062 L_preprocessed.nii.gz
# Copying [61-32062 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\61-32062 R_preprocessed.nii.gz
# Copying [62-2274 R 2021_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-2274 R 2021_preprocessed.nii.gz
# Copying [62-24749 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-24749 L_preprocessed.nii.gz
# Copying [62-24749 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\62-24749 R_preprocessed.nii.gz
# Copying [62-7533 L 2021_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-7533 L 2021_preprocessed.nii.gz
# Copying [62-7533 R 2021_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-7533 R 2021_preprocessed.nii.gz
# Copying [63-12252 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\63-12252 L_preprocessed.nii.gz
# Copying [63-12252 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\63-12252 R_preprocessed.nii.gz
# Copying [63-15359 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-15359 L_preprocessed.nii.gz
# Copying [63-15359 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-15359 R_preprocessed.nii.gz
# Copying [64-10902 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-10902 L_preprocessed.nii.gz
# Copying [64-10902 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-10902 R_preprocessed.nii.gz
# Copying [64-3795 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\64-3795 L_preprocessed.nii.gz
# Copying [64-700092 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-700092 L_preprocessed.nii.gz
# Copying [64-700178 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\64-700178 L_preprocessed.nii.gz
# Copying [64-700383 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\64-700383 L_preprocessed.nii.gz
# Copying [64-7881 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-7881 L_preprocessed.nii.gz
# Copying [64-7881 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\64-7881 R_preprocessed.nii.gz
# Copying [64-8619 L 2021_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-8619 L 2021_preprocessed.nii.gz
# Copying [64-8619 R 2021_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-8619 R 2021_preprocessed.nii.gz
# Copying [64-8619 L 2022_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-8619 L 2022_preprocessed.nii.gz
# Copying [49-18165 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\49-18165 L_preprocessed.nii.gz
# Copying [49-18165 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\49-18165 R_preprocessed.nii.gz
# Copying [49-3614 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\49-3614 L_preprocessed.nii.gz
# Copying [49-3614 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\49-3614 R_preprocessed.nii.gz
# Copying [53-12918 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-12918 L_preprocessed.nii.gz
# Copying [53-12918 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-12918 R_preprocessed.nii.gz
# Copying [55-9422 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\55-9422 L_preprocessed.nii.gz
# Copying [55-9422 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\55-9422 R_preprocessed.nii.gz
# Copying [56-24221 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\56-24221 L_preprocessed.nii.gz
# Copying [56-24221 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\56-24221 R_preprocessed.nii.gz
# Copying [57-12957 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\57-12957 L_preprocessed.nii.gz
# Copying [57-12957 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\57-12957 R_preprocessed.nii.gz
# Copying [58-9834 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-9834 L_preprocessed.nii.gz
# Copying [58-9834 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\58-9834 R_preprocessed.nii.gz
# Copying [59-39978 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\59-39978 L_preprocessed.nii.gz
# Copying [59-39978 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\59-39978 R_preprocessed.nii.gz
# Copying [61-16015 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-16015 L_preprocessed.nii.gz
# Copying [61-16015 R 2022_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\61-16015 R 2022_preprocessed.nii.gz
# Copying [62-30049 L_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-30049 L_preprocessed.nii.gz
# Copying [62-30049 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-30049 R_preprocessed.nii.gz
# Copying [62-435 L_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-435 L_preprocessed.nii.gz
# Copying [62-435 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\62-435 R_preprocessed.nii.gz
# Copying [63-17877 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\63-17877 L_preprocessed.nii.gz
# Copying [63-17877 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\63-17877 R_preprocessed.nii.gz
# Copying [63-17957 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\63-17957 L_preprocessed.nii.gz
# Copying [63-17957 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-17957 R_preprocessed.nii.gz
# Copying [63-20205 L_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\63-20205 L_preprocessed.nii.gz
# Copying [63-20205 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\63-20205 R_preprocessed.nii.gz
# Copying [64-6935 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-6935 L_preprocessed.nii.gz
# Copying [64-6935 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-6935 R_preprocessed.nii.gz
# Copying [64-7980 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\64-7980 L_preprocessed.nii.gz
# Copying [64-7980 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\64-7980 R_preprocessed.nii.gz
# Copying [65-11496 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-11496 L_preprocessed.nii.gz
# Copying [65-14582 R 2022_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\65-14582 R 2022_preprocessed.nii.gz
# Copying [65-1579 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-1579 L_preprocessed.nii.gz
# Copying [65-1579 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-1579 R_preprocessed.nii.gz
# Copying [65-23331 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-23331 L_preprocessed.nii.gz
# Copying [65-23331 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-23331 R_preprocessed.nii.gz
# Copying [65-2425 L 2022 02 17_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-2425 L 2022 02 17_preprocessed.nii.gz
# Copying [65-2425 R 2022 02 17_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\65-2425 R 2022 02 17_preprocessed.nii.gz
# Copying [65-2425 L 2022 10 03_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-2425 L 2022 10 03_preprocessed.nii.gz
# Copying [65-2425 R 2022 10 03_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\65-2425 R 2022 10 03_preprocessed.nii.gz
# Copying [65-4483 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-4483 L_preprocessed.nii.gz
# Copying [65-4998 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-4998 L_preprocessed.nii.gz
# Copying [65-4998 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-4998 R_preprocessed.nii.gz
# Copying [65-700003 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-700003 L_preprocessed.nii.gz
# Copying [65-700003 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-700003 R_preprocessed.nii.gz
# Copying [65-700131 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-700131 L_preprocessed.nii.gz
# Copying [65-700131 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-700131 R_preprocessed.nii.gz
# Copying [65-700197 L_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\65-700197 L_preprocessed.nii.gz
# Copying [65-700197 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\65-700197 R_preprocessed.nii.gz
# Copying [65-700405 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-700405 L_preprocessed.nii.gz
# Copying [65-700405 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-700405 R_preprocessed.nii.gz
# Copying [65-14582 R 2023_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\65-14582 R 2023_preprocessed.nii.gz
# Copying [48-26453 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\48-26453 L_preprocessed.nii.gz
# Copying [52-15073 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\52-15073 L_preprocessed.nii.gz
# Copying [52-15073 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-15073 R_preprocessed.nii.gz
# Copying [52-15242 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-15242 L_preprocessed.nii.gz
# Copying [52-15242 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\52-15242 R_preprocessed.nii.gz
# Copying [53-22559 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-22559 L_preprocessed.nii.gz
# Copying [53-22559 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-22559 R_preprocessed.nii.gz
# Copying [53-24700 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\53-24700 L_preprocessed.nii.gz
# Copying [53-24700 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\53-24700 R_preprocessed.nii.gz
# Copying [54-17099 L_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\54-17099 L_preprocessed.nii.gz
# Copying [54-17099 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\54-17099 R_preprocessed.nii.gz
# Copying [55-15078 L_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\55-15078 L_preprocessed.nii.gz
# Copying [55-15078 R_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\55-15078 R_preprocessed.nii.gz
# Copying [56-26683 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\56-26683 L_preprocessed.nii.gz
# Copying [57-16393 L_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\57-16393 L_preprocessed.nii.gz
# Copying [57-16393 R_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\57-16393 R_preprocessed.nii.gz
# Copying [57-30513 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-30513 L_preprocessed.nii.gz
# Copying [57-30513 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\57-30513 R_preprocessed.nii.gz
# Copying [59-27051 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-27051 L_preprocessed.nii.gz
# Copying [59-27051 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-27051 R_preprocessed.nii.gz
# Copying [59-38408 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-38408 L_preprocessed.nii.gz
# Copying [60-24908 L 2023_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-24908 L 2023_preprocessed.nii.gz
# Copying [60-24908 R 2023_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-24908 R 2023_preprocessed.nii.gz
# Copying [60-2688 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-2688 L_preprocessed.nii.gz
# Copying [60-2688 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-2688 R_preprocessed.nii.gz
# Copying [62-8585 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-8585 L_preprocessed.nii.gz
# Copying [62-8585 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\62-8585 R_preprocessed.nii.gz
# Copying [63-7894 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-7894 L_preprocessed.nii.gz
# Copying [63-7894 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-7894 R_preprocessed.nii.gz
# Copying [64-10402 L 2023 02 08_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-10402 L 2023 02 08_preprocessed.nii.gz
# Copying [64-10402 R 2023 02 08_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\64-10402 R 2023 02 08_preprocessed.nii.gz
# Copying [64-10402 R 2023 11 21_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\64-10402 R 2023 11 21_preprocessed.nii.gz
# Copying [64-7936 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-7936 L_preprocessed.nii.gz
# Copying [64-7936 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\64-7936 R_preprocessed.nii.gz
# Copying [65-14920 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-14920 L_preprocessed.nii.gz
# Copying [65-14920 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-14920 R_preprocessed.nii.gz
# Copying [65-20101 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-20101 L_preprocessed.nii.gz
# Copying [65-20101 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-20101 R_preprocessed.nii.gz
# Copying [65-20231 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-20231 L_preprocessed.nii.gz
# Copying [65-20231 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-20231 R_preprocessed.nii.gz
# Copying [65-24090 L 2023 11 17_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\65-24090 L 2023 11 17_preprocessed.nii.gz
# Copying [65-24090 R 2023 11 17_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\65-24090 R 2023 11 17_preprocessed.nii.gz
# Copying [65-24090 R 2023 11 29_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\65-24090 R 2023 11 29_preprocessed.nii.gz
# Copying [65-2425 L 2023_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\65-2425 L 2023_preprocessed.nii.gz
# Copying [65-2425 R 2023_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\65-2425 R 2023_preprocessed.nii.gz
# Copying [65-25886 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-25886 R_preprocessed.nii.gz
# Copying [65-26867 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-26867 L_preprocessed.nii.gz
# Copying [65-26867 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-26867 R_preprocessed.nii.gz
# Copying [65-27050 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-27050 R_preprocessed.nii.gz
# Copying [65-27889 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-27889 L_preprocessed.nii.gz
# Copying [65-8582 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-8582 R_preprocessed.nii.gz
# Copying [66-12948 R_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\66-12948 R_preprocessed.nii.gz
# Copying [66-13889 R_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\66-13889 R_preprocessed.nii.gz
# Copying [66-18213 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-18213 L_preprocessed.nii.gz
# Copying [66-18213 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-18213 R_preprocessed.nii.gz
# Copying [66-20679 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-20679 L_preprocessed.nii.gz
# Copying [66-21702 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-21702 L_preprocessed.nii.gz
# Copying [66-2177 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-2177 L_preprocessed.nii.gz
# Copying [66-2177 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-2177 R_preprocessed.nii.gz
# Copying [66-218 L 2023 06 16_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\66-218 L 2023 06 16_preprocessed.nii.gz
# Copying [66-218 R 2023 06 16_preprocessed.nii.gz, val, 0] to D:\Kananat\Data\Last0\OA\val\0\66-218 R 2023 06 16_preprocessed.nii.gz
# Copying [66-23248 L 2023 11 29_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-23248 L 2023 11 29_preprocessed.nii.gz
# Copying [66-23248 R 2023 11 29_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-23248 R 2023 11 29_preprocessed.nii.gz
# Copying [66-4559 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-4559 L_preprocessed.nii.gz
# Copying [66-4559 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-4559 R_preprocessed.nii.gz
# Copying [66-59 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-59 L_preprocessed.nii.gz
# Copying [66-59 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-59 R_preprocessed.nii.gz
# Copying [66-700261 L_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-700261 L_preprocessed.nii.gz
# Copying [66-700261 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700261 R_preprocessed.nii.gz
# Copying [66-700314 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700314 L_preprocessed.nii.gz
# Copying [66-700314 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-700314 R_preprocessed.nii.gz
# Copying [66-700362 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700362 L_preprocessed.nii.gz
# Copying [66-700362 R_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\66-700362 R_preprocessed.nii.gz
# Copying [66-700404 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700404 L_preprocessed.nii.gz
# Copying [66-700404 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700404 R_preprocessed.nii.gz
# Copying [66-700681 L_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700681 L_preprocessed.nii.gz
# Copying [66-700681 R_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-700681 R_preprocessed.nii.gz
# Copying [58-41636 R 20160129_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\58-41636 R 20160129_preprocessed.nii.gz
# Copying [58-41636 L 20160129_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\58-41636 L 20160129_preprocessed.nii.gz
# Copying [59-2326 R 20160220_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-2326 R 20160220_preprocessed.nii.gz
# Copying [59-2326 L 20160220_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-2326 L 20160220_preprocessed.nii.gz
# Copying [59-6269 R 20160326_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\59-6269 R 20160326_preprocessed.nii.gz
# Copying [59-6269 L 20160326_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\59-6269 L 20160326_preprocessed.nii.gz
# Copying [67-700034 R 20240127_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\67-700034 R 20240127_preprocessed.nii.gz
# Copying [67-700034 L 20240127_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\67-700034 L 20240127_preprocessed.nii.gz
# Copying [56-30067 R 20240131_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\56-30067 R 20240131_preprocessed.nii.gz
# Copying [63-9054 R 20240308_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\63-9054 R 20240308_preprocessed.nii.gz
# Copying [63-9054 L 20240308_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\63-9054 L 20240308_preprocessed.nii.gz
# Copying [66-22465 R 20240527_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-22465 R 20240527_preprocessed.nii.gz
# Copying [67-9653 L 20240701_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\67-9653 L 20240701_preprocessed.nii.gz
# Copying [60-34373 R 20241008_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\60-34373 R 20241008_preprocessed.nii.gz
# Copying [60-34373 L 20241008_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\60-34373 L 20241008_preprocessed.nii.gz
# Copying [66-8695 R 20241114_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\66-8695 R 20241114_preprocessed.nii.gz
# Copying [67-10136 R 20241208_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\67-10136 R 20241208_preprocessed.nii.gz
# Copying [65-4618 R 20241218_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-4618 R 20241218_preprocessed.nii.gz
# Copying [65-4618 L 20241218_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\65-4618 L 20241218_preprocessed.nii.gz
# Copying [50-11620 R 20250213_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\50-11620 R 20250213_preprocessed.nii.gz
# Copying [50-11620 L 20250213_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\50-11620 L 20250213_preprocessed.nii.gz
# Copying [67-24015 R 20250213_preprocessed.nii.gz, test, 0] to D:\Kananat\Data\Last0\OA\test\0\67-24015 R 20250213_preprocessed.nii.gz
# Copying [67-24015 L 20250213_preprocessed.nii.gz, test, 1] to D:\Kananat\Data\Last0\OA\test\1\67-24015 L 20250213_preprocessed.nii.gz
# Copying [68-700050 R 20250226_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\68-700050 R 20250226_preprocessed.nii.gz
# Copying [68-700050 L 20250226_preprocessed.nii.gz, train, 0] to D:\Kananat\Data\Last0\OA\train\0\68-700050 L 20250226_preprocessed.nii.gz
# Copying [66-1461 R 20250319_preprocessed.nii.gz, val, 1] to D:\Kananat\Data\Last0\OA\val\1\66-1461 R 20250319_preprocessed.nii.gz
# Copying [68-700244 L 20250419_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\68-700244 L 20250419_preprocessed.nii.gz
# Copying [63-0010001 R 20240527_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-0010001 R 20240527_preprocessed.nii.gz
# Copying [63-0010001 L 20240527_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\63-0010001 L 20240527_preprocessed.nii.gz
# Copying [65-32395 L 20250123_preprocessed.nii.gz, train, 1] to D:\Kananat\Data\Last0\OA\train\1\65-32395 L 20250123_preprocessed.nii.gz

# %%
OA_neg = df[df['OA'] == 0]
OA_neg
# Out:
#                   ID  OA  erosion  subCyst  genSclerosis  osteophyte  \
# 3    54-21497 R 2014   0        0        0             0           0
# 4    57-10397 L 2015   0        0        0             0           0
# 5    57-10397 R 2015   0        0        0             0           0
# 7    54-21497 R 2016   0        0        0             0           0
# 12           54-50 L   0        0        0             0           0
# ..               ...  ..      ...      ...           ...         ...
# 383       50-11620 R   0        0        0             0           0
# 384       50-11620 L   0        0        0             0           0
# 385       67-24015 R   0        0        0             0           0
# 387      68-700050 R   0        0        0             0           0
# 388      68-700050 L   0        0        0             0           0
#
#      flattening  split
# 3             1  train
# 4             1    val
# 5             0  train
# 7             0  train
# 12            1  train
# ..          ...    ...
# 383           0  train
# 384           1    val
# 385           1  train
# 387           1    val
# 388           0  train
#
# [156 rows x 8 columns]

# %%
OA_positive = df[df['OA'] == 1]
train_df = OA_positive[OA_positive['split'] == 'train']
val_df = OA_positive[OA_positive['split'] == 'val']
test_df = OA_positive[OA_positive['split'] == 'test']

# %%
cols = ['erosion', 'subCyst', 'genSclerosis', 'osteophyte', 'flattening']

print("TRAIN")
split_df = train_df
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    print(f"{col}: {pos_neg}, diff = {1-abs(pos-neg)/sum(pos_neg)}")

print("\nVAL")
split_df = val_df
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    print(f"{col}: {pos_neg}, diff = {1-abs(pos-neg)/sum(pos_neg)}")

print("\nTEST")
split_df = test_df
for col in cols:
    pos = (split_df[col] == 1).sum()
    neg = (split_df[col] == 0).sum()
    pos_neg = [pos, neg]
    print(f"{col}: {pos_neg}, diff = {1-abs(pos-neg)/sum(pos_neg)}")
# Out:
# TRAIN
# erosion: [149, 17], diff = 0.20481927710843373
# subCyst: [80, 86], diff = 0.963855421686747
# genSclerosis: [50, 116], diff = 0.6024096385542168
# osteophyte: [126, 40], diff = 0.4819277108433735
# flattening: [115, 51], diff = 0.6144578313253012
#
# VAL
# erosion: [43, 2], diff = 0.0888888888888889
# subCyst: [21, 24], diff = 0.9333333333333333
# genSclerosis: [9, 36], diff = 0.4
# osteophyte: [33, 12], diff = 0.5333333333333333
# flattening: [27, 18], diff = 0.8
#
# TEST
# erosion: [26, 1], diff = 0.07407407407407407
# subCyst: [16, 11], diff = 0.8148148148148149
# genSclerosis: [10, 17], diff = 0.7407407407407407
# osteophyte: [23, 4], diff = 0.2962962962962963
# flattening: [21, 6], diff = 0.4444444444444444
