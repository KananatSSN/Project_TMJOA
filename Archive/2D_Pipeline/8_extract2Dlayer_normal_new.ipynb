# %%
import os
import argparse
import numpy as np
import nibabel as nib
from PIL import Image
from pathlib import Path
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def normalize_voxel_values(data, background_value=-250):
    """
    Normalize voxel values from [-250, max_value] to [0, 255]
    
    Args:
        data: 3D numpy array
        background_value: Background value (default: -250)
    
    Returns:
        Normalized data as uint8
    """
    # Clip values to ensure minimum is background_value
    data = np.clip(data, background_value, 1500)
    
    # Get min and max values
    min_val = data.min()
    max_val = data.max()
    
    if max_val == min_val:
        # Handle case where all values are the same
        return np.zeros_like(data, dtype=np.uint8)
    
    # Normalize to [0, 255]
    normalized = ((data - min_val) / (max_val - min_val)) * 255
    return normalized.astype(np.uint8)

def find_max_non_background_layer(data, background_value=-250):
    """
    Find the layer (along axis 0) with maximum number of non-background voxels
    
    Args:
        data: 3D numpy array
        background_value: Background value to exclude
    
    Returns:
        Layer index with maximum non-background voxels
    """
    non_background_counts = []
    
    for i in range(data.shape[0]):
        layer = data[i, :, :]
        non_background_count = np.sum(layer != background_value)
        non_background_counts.append(non_background_count)
    
    max_layer_idx = np.argmax(non_background_counts)
    logger.info(f"Max non-background layer: {max_layer_idx} with {non_background_counts[max_layer_idx]} non-background voxels")
    
    return max_layer_idx

def extract_layers(data, center_layer, n, background_value=-250):
    """
    Extract layers: center, center±n, center±2n
    
    Args:
        data: 3D numpy array
        center_layer: Index of the center layer
        n: Distance parameter
        background_value: Background value
    
    Returns:
        Dictionary of layer indices and their corresponding 2D arrays
    """
    layers = {}
    max_layer = data.shape[0] - 1
    
    # Define layer indices to extract
    layer_offsets = [0, n, 2*n, -n, -2*n]
    layer_names = ['center', 'plus_n', 'plus_2n', 'minus_n', 'minus_2n']
    
    for offset, name in zip(layer_offsets, layer_names):
        layer_idx = center_layer + offset
        
        # Check bounds
        if 0 <= layer_idx <= max_layer:
            layers[f"{name}_{layer_idx:03d}"] = data[layer_idx, :, :]
            logger.info(f"Extracted layer {layer_idx} ({name})")
        else:
            logger.warning(f"Layer {layer_idx} ({name}) is out of bounds [0, {max_layer}], skipping")
    
    return layers

def save_layer_as_png(layer_data, output_path):
    """
    Save 2D layer as PNG with 3 identical channels
    
    Args:
        layer_data: 2D numpy array (normalized to 0-255)
        output_path: Output file path
    """
    # Create 3-channel image (RGB) with identical values
    rgb_image = np.stack([layer_data, layer_data, layer_data], axis=-1)
    
    # Convert to PIL Image and save
    pil_image = Image.fromarray(rgb_image, mode='RGB')
    pil_image.save(output_path)

def process_nifti_file(nifti_path, output_dir, n, background_value=-250):
    """
    Process a single NIfTI file and extract layers
    
    Args:
        nifti_path: Path to .nii.gz file
        output_dir: Output directory for this file's layers
        n: Distance parameter
        background_value: Background value
    """
    try:
        logger.info(f"Processing: {nifti_path}")
        
        # Load NIfTI file
        nifti_img = nib.load(nifti_path)
        data = nifti_img.get_fdata()
        
        logger.info(f"Data shape: {data.shape}")
        logger.info(f"Data range: [{data.min():.2f}, {data.max():.2f}]")
        
        # Find layer with maximum non-background voxels
        center_layer = find_max_non_background_layer(data, background_value)
        
        # Extract layers
        layers = extract_layers(data, center_layer, n, background_value)
        
        # Process and save each layer
        filename_base = Path(nifti_path).stem.replace('.nii', '')  # Remove .nii.gz extension
        
        for layer_name, layer_data in layers.items():
            # Normalize the layer
            normalized_layer = normalize_voxel_values(layer_data, background_value)
            
            # Create output filename
            output_filename = f"{filename_base}_{layer_name}.png"
            output_path = os.path.join(output_dir, output_filename)
            
            # Save as PNG
            save_layer_as_png(normalized_layer, output_path)
            logger.info(f"Saved: {output_path}")
    
    except Exception as e:
        logger.error(f"Error processing {nifti_path}: {str(e)}")

def process_dataset(input_dataset_dir, output_dataset_dir, n, background_value=-250):
    """
    Process entire dataset
    
    Args:
        input_dataset_dir: Input dataset directory
        output_dataset_dir: Output dataset directory
        n: Distance parameter
        background_value: Background value
    """
    input_path = Path(input_dataset_dir)
    output_path = Path(output_dataset_dir)
    
    # Iterate through train/val/test folders
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            logger.info(f"Processing split: {split_dir.name}")
            
            # Iterate through class folders (0, 1)
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    logger.info(f"Processing class: {class_dir.name}")
                    
                    # Create output directory
                    output_class_dir = output_path / split_dir.name / class_dir.name
                    output_class_dir.mkdir(parents=True, exist_ok=True)
                    
                    # Process all .nii.gz files in this directory
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    logger.info(f"Found {len(nifti_files)} NIfTI files")
                    
                    for nifti_file in nifti_files:
                        process_nifti_file(nifti_file, output_class_dir, n, background_value)

# %% [markdown]
# # Extract layer around the most informative layer

# %%
input_dataset = r'D:\Kananat\Data\training_dataset_3D\training_dataset_OA'  # Replace with actual input dataset path
output_dataset = r'D:\Kananat\Data\training_dataset_2D\training_dataset_OA'  # Replace with actual output dataset path
n = 5  # Replace with actual distance parameter (n)
background_value = -250

logger.info(f"Input dataset: {input_dataset}")
logger.info(f"Output dataset: {output_dataset}")
logger.info(f"Distance parameter (n): {n}")
logger.info(f"Background value: {background_value}")

# Validate input directory
if not os.path.exists(input_dataset):
    logger.error(f"Input dataset directory does not exist: {input_dataset}")

# Process the dataset
process_dataset(input_dataset, output_dataset, n, background_value)

logger.info("Processing completed!")
# Out:
# INFO - Input dataset: D:\Kananat\Data\training_dataset_3D\training_dataset_OA
# INFO - Output dataset: D:\Kananat\Data\training_dataset_2D\training_dataset_OA
# INFO - Distance parameter (n): 5
# INFO - Background value: -250
# INFO - Processing split: test
# INFO - Processing class: 0
# INFO - Found 14 NIfTI files
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\57-16393 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1374.00]
# INFO - Max non-background layer: 149 with 18499 non-background voxels
# INFO - Extracted layer 149 (center)
# INFO - Extracted layer 154 (plus_n)
# INFO - Extracted layer 159 (plus_2n)
# INFO - Extracted layer 144 (minus_n)
# INFO - Extracted layer 139 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 L_adjustedBG_center_149.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 L_adjustedBG_plus_n_154.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 L_adjustedBG_plus_2n_159.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 L_adjustedBG_minus_n_144.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 L_adjustedBG_minus_2n_139.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\57-16393 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1372.00]
# INFO - Max non-background layer: 68 with 12475 non-background voxels
# INFO - Extracted layer 68 (center)
# INFO - Extracted layer 73 (plus_n)
# INFO - Extracted layer 78 (plus_2n)
# INFO - Extracted layer 63 (minus_n)
# INFO - Extracted layer 58 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 R_adjustedBG_center_068.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 R_adjustedBG_plus_n_073.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 R_adjustedBG_plus_2n_078.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 R_adjustedBG_minus_n_063.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-16393 R_adjustedBG_minus_2n_058.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\57-36050 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1336.00]
# INFO - Max non-background layer: 129 with 17389 non-background voxels
# INFO - Extracted layer 129 (center)
# INFO - Extracted layer 134 (plus_n)
# INFO - Extracted layer 139 (plus_2n)
# INFO - Extracted layer 124 (minus_n)
# INFO - Extracted layer 119 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-36050 L_adjustedBG_center_129.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-36050 L_adjustedBG_plus_n_134.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-36050 L_adjustedBG_plus_2n_139.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-36050 L_adjustedBG_minus_n_124.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\57-36050 L_adjustedBG_minus_2n_119.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\60-700759 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1280.00]
# INFO - Max non-background layer: 137 with 18283 non-background voxels
# INFO - Extracted layer 137 (center)
# INFO - Extracted layer 142 (plus_n)
# INFO - Extracted layer 147 (plus_2n)
# INFO - Extracted layer 132 (minus_n)
# INFO - Extracted layer 127 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 L_adjustedBG_center_137.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 L_adjustedBG_plus_n_142.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 L_adjustedBG_plus_2n_147.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 L_adjustedBG_minus_n_132.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 L_adjustedBG_minus_2n_127.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\60-700759 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1342.00]
# INFO - Max non-background layer: 107 with 16085 non-background voxels
# INFO - Extracted layer 107 (center)
# INFO - Extracted layer 112 (plus_n)
# INFO - Extracted layer 117 (plus_2n)
# INFO - Extracted layer 102 (minus_n)
# INFO - Extracted layer 97 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 R_adjustedBG_center_107.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 R_adjustedBG_plus_n_112.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 R_adjustedBG_plus_2n_117.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 R_adjustedBG_minus_n_102.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\60-700759 R_adjustedBG_minus_2n_097.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\61-25724 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1382.00]
# INFO - Max non-background layer: 99 with 13569 non-background voxels
# INFO - Extracted layer 99 (center)
# INFO - Extracted layer 104 (plus_n)
# INFO - Extracted layer 109 (plus_2n)
# INFO - Extracted layer 94 (minus_n)
# INFO - Extracted layer 89 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-25724 R_adjustedBG_center_099.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-25724 R_adjustedBG_plus_n_104.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-25724 R_adjustedBG_plus_2n_109.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-25724 R_adjustedBG_minus_n_094.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-25724 R_adjustedBG_minus_2n_089.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\61-5586 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1369.00]
# INFO - Max non-background layer: 91 with 9245 non-background voxels
# INFO - Extracted layer 91 (center)
# INFO - Extracted layer 96 (plus_n)
# INFO - Extracted layer 101 (plus_2n)
# INFO - Extracted layer 86 (minus_n)
# INFO - Extracted layer 81 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-5586 R_adjustedBG_center_091.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-5586 R_adjustedBG_plus_n_096.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-5586 R_adjustedBG_plus_2n_101.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-5586 R_adjustedBG_minus_n_086.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\61-5586 R_adjustedBG_minus_2n_081.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\62-25311 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1373.00]
# INFO - Max non-background layer: 114 with 12995 non-background voxels
# INFO - Extracted layer 114 (center)
# INFO - Extracted layer 119 (plus_n)
# INFO - Extracted layer 124 (plus_2n)
# INFO - Extracted layer 109 (minus_n)
# INFO - Extracted layer 104 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\62-25311 R_adjustedBG_center_114.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\62-25311 R_adjustedBG_plus_n_119.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\62-25311 R_adjustedBG_plus_2n_124.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\62-25311 R_adjustedBG_minus_n_109.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\62-25311 R_adjustedBG_minus_2n_104.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\63-2829 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1416.00]
# INFO - Max non-background layer: 160 with 17308 non-background voxels
# INFO - Extracted layer 160 (center)
# INFO - Extracted layer 165 (plus_n)
# INFO - Extracted layer 170 (plus_2n)
# INFO - Extracted layer 155 (minus_n)
# INFO - Extracted layer 150 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\63-2829 L_adjustedBG_center_160.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\63-2829 L_adjustedBG_plus_n_165.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\63-2829 L_adjustedBG_plus_2n_170.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\63-2829 L_adjustedBG_minus_n_155.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\63-2829 L_adjustedBG_minus_2n_150.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\64-7881 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1309.00]
# INFO - Max non-background layer: 73 with 13807 non-background voxels
# INFO - Extracted layer 73 (center)
# INFO - Extracted layer 78 (plus_n)
# INFO - Extracted layer 83 (plus_2n)
# INFO - Extracted layer 68 (minus_n)
# INFO - Extracted layer 63 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\64-7881 R_adjustedBG_center_073.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\64-7881 R_adjustedBG_plus_n_078.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\64-7881 R_adjustedBG_plus_2n_083.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\64-7881 R_adjustedBG_minus_n_068.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\64-7881 R_adjustedBG_minus_2n_063.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\65-23331 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1473.00]
# INFO - Max non-background layer: 163 with 14722 non-background voxels
# INFO - Extracted layer 163 (center)
# INFO - Extracted layer 168 (plus_n)
# INFO - Extracted layer 173 (plus_2n)
# INFO - Extracted layer 158 (minus_n)
# INFO - Extracted layer 153 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-23331 L_adjustedBG_center_163.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-23331 L_adjustedBG_plus_n_168.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-23331 L_adjustedBG_plus_2n_173.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-23331 L_adjustedBG_minus_n_158.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-23331 L_adjustedBG_minus_2n_153.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\65-27050 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1362.00]
# INFO - Max non-background layer: 132 with 17694 non-background voxels
# INFO - Extracted layer 132 (center)
# INFO - Extracted layer 137 (plus_n)
# INFO - Extracted layer 142 (plus_2n)
# INFO - Extracted layer 127 (minus_n)
# INFO - Extracted layer 122 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-27050 R_adjustedBG_center_132.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-27050 R_adjustedBG_plus_n_137.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-27050 R_adjustedBG_plus_2n_142.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-27050 R_adjustedBG_minus_n_127.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-27050 R_adjustedBG_minus_2n_122.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\65-700131 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1378.00]
# INFO - Max non-background layer: 134 with 12377 non-background voxels
# INFO - Extracted layer 134 (center)
# INFO - Extracted layer 139 (plus_n)
# INFO - Extracted layer 144 (plus_2n)
# INFO - Extracted layer 129 (minus_n)
# INFO - Extracted layer 124 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 L_adjustedBG_center_134.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 L_adjustedBG_plus_n_139.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 L_adjustedBG_plus_2n_144.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 L_adjustedBG_minus_n_129.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 L_adjustedBG_minus_2n_124.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\0\65-700131 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1458.00]
# INFO - Max non-background layer: 70 with 15916 non-background voxels
# INFO - Extracted layer 70 (center)
# INFO - Extracted layer 75 (plus_n)
# INFO - Extracted layer 80 (plus_2n)
# INFO - Extracted layer 65 (minus_n)
# INFO - Extracted layer 60 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 R_adjustedBG_center_070.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 R_adjustedBG_plus_n_075.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 R_adjustedBG_plus_2n_080.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 R_adjustedBG_minus_n_065.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\0\65-700131 R_adjustedBG_minus_2n_060.png
# INFO - Processing class: 1
# INFO - Found 25 NIfTI files
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1447.00]
# INFO - Max non-background layer: 162 with 14104 non-background voxels
# INFO - Extracted layer 162 (center)
# INFO - Extracted layer 167 (plus_n)
# INFO - Extracted layer 172 (plus_2n)
# INFO - Extracted layer 157 (minus_n)
# INFO - Extracted layer 152 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG_center_162.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG_plus_n_167.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG_plus_2n_172.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG_minus_n_157.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2014_adjustedBG_minus_2n_152.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1304.00]
# INFO - Max non-background layer: 169 with 14249 non-background voxels
# INFO - Extracted layer 169 (center)
# INFO - Extracted layer 174 (plus_n)
# INFO - Extracted layer 179 (plus_2n)
# INFO - Extracted layer 164 (minus_n)
# INFO - Extracted layer 159 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG_center_169.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG_plus_n_174.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG_plus_2n_179.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG_minus_n_164.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 L 2018_adjustedBG_minus_2n_159.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1436.00]
# INFO - Max non-background layer: 80 with 12763 non-background voxels
# INFO - Extracted layer 80 (center)
# INFO - Extracted layer 85 (plus_n)
# INFO - Extracted layer 90 (plus_2n)
# INFO - Extracted layer 75 (minus_n)
# INFO - Extracted layer 70 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG_center_080.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG_plus_n_085.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG_plus_2n_090.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG_minus_n_075.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2014_adjustedBG_minus_2n_070.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1371.00]
# INFO - Max non-background layer: 82 with 12787 non-background voxels
# INFO - Extracted layer 82 (center)
# INFO - Extracted layer 87 (plus_n)
# INFO - Extracted layer 92 (plus_2n)
# INFO - Extracted layer 77 (minus_n)
# INFO - Extracted layer 72 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG_center_082.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG_plus_n_087.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG_plus_2n_092.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG_minus_n_077.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\47-4881 R 2018_adjustedBG_minus_2n_072.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\50-30909 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1088.00]
# INFO - Max non-background layer: 61 with 13498 non-background voxels
# INFO - Extracted layer 61 (center)
# INFO - Extracted layer 66 (plus_n)
# INFO - Extracted layer 71 (plus_2n)
# INFO - Extracted layer 56 (minus_n)
# INFO - Extracted layer 51 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\50-30909 R_adjustedBG_center_061.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\50-30909 R_adjustedBG_plus_n_066.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\50-30909 R_adjustedBG_plus_2n_071.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\50-30909 R_adjustedBG_minus_n_056.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\50-30909 R_adjustedBG_minus_2n_051.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\53-13011 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1326.00]
# INFO - Max non-background layer: 118 with 15354 non-background voxels
# INFO - Extracted layer 118 (center)
# INFO - Extracted layer 123 (plus_n)
# INFO - Extracted layer 128 (plus_2n)
# INFO - Extracted layer 113 (minus_n)
# INFO - Extracted layer 108 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 L_adjustedBG_center_118.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 L_adjustedBG_plus_n_123.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 L_adjustedBG_plus_2n_128.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 L_adjustedBG_minus_n_113.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 L_adjustedBG_minus_2n_108.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\53-13011 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1325.00]
# INFO - Max non-background layer: 91 with 17263 non-background voxels
# INFO - Extracted layer 91 (center)
# INFO - Extracted layer 96 (plus_n)
# INFO - Extracted layer 101 (plus_2n)
# INFO - Extracted layer 86 (minus_n)
# INFO - Extracted layer 81 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 R_adjustedBG_center_091.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 R_adjustedBG_plus_n_096.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 R_adjustedBG_plus_2n_101.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 R_adjustedBG_minus_n_086.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\53-13011 R_adjustedBG_minus_2n_081.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\57-36050 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1361.00]
# INFO - Max non-background layer: 103 with 13373 non-background voxels
# INFO - Extracted layer 103 (center)
# INFO - Extracted layer 108 (plus_n)
# INFO - Extracted layer 113 (plus_2n)
# INFO - Extracted layer 98 (minus_n)
# INFO - Extracted layer 93 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\57-36050 R_adjustedBG_center_103.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\57-36050 R_adjustedBG_plus_n_108.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\57-36050 R_adjustedBG_plus_2n_113.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\57-36050 R_adjustedBG_minus_n_098.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\57-36050 R_adjustedBG_minus_2n_093.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\58-43911 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1315.00]
# INFO - Max non-background layer: 125 with 11240 non-background voxels
# INFO - Extracted layer 125 (center)
# INFO - Extracted layer 130 (plus_n)
# INFO - Extracted layer 135 (plus_2n)
# INFO - Extracted layer 120 (minus_n)
# INFO - Extracted layer 115 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 L_adjustedBG_center_125.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 L_adjustedBG_plus_n_130.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 L_adjustedBG_plus_2n_135.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 L_adjustedBG_minus_n_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 L_adjustedBG_minus_2n_115.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\58-43911 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1202.00]
# INFO - Max non-background layer: 91 with 9367 non-background voxels
# INFO - Extracted layer 91 (center)
# INFO - Extracted layer 96 (plus_n)
# INFO - Extracted layer 101 (plus_2n)
# INFO - Extracted layer 86 (minus_n)
# INFO - Extracted layer 81 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 R_adjustedBG_center_091.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 R_adjustedBG_plus_n_096.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 R_adjustedBG_plus_2n_101.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 R_adjustedBG_minus_n_086.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\58-43911 R_adjustedBG_minus_2n_081.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\59-38408 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1279.00]
# INFO - Max non-background layer: 129 with 12858 non-background voxels
# INFO - Extracted layer 129 (center)
# INFO - Extracted layer 134 (plus_n)
# INFO - Extracted layer 139 (plus_2n)
# INFO - Extracted layer 124 (minus_n)
# INFO - Extracted layer 119 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\59-38408 L_adjustedBG_center_129.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\59-38408 L_adjustedBG_plus_n_134.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\59-38408 L_adjustedBG_plus_2n_139.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\59-38408 L_adjustedBG_minus_n_124.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\59-38408 L_adjustedBG_minus_2n_119.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\60-25232 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1311.00]
# INFO - Max non-background layer: 151 with 13237 non-background voxels
# INFO - Extracted layer 151 (center)
# INFO - Extracted layer 156 (plus_n)
# INFO - Extracted layer 161 (plus_2n)
# INFO - Extracted layer 146 (minus_n)
# INFO - Extracted layer 141 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 L_adjustedBG_center_151.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 L_adjustedBG_plus_n_156.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 L_adjustedBG_plus_2n_161.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 L_adjustedBG_minus_n_146.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 L_adjustedBG_minus_2n_141.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\60-25232 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1303.00]
# INFO - Max non-background layer: 110 with 12449 non-background voxels
# INFO - Extracted layer 110 (center)
# INFO - Extracted layer 115 (plus_n)
# INFO - Extracted layer 120 (plus_2n)
# INFO - Extracted layer 105 (minus_n)
# INFO - Extracted layer 100 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 R_adjustedBG_center_110.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 R_adjustedBG_plus_n_115.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 R_adjustedBG_plus_2n_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 R_adjustedBG_minus_n_105.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-25232 R_adjustedBG_minus_2n_100.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1410.00]
# INFO - Max non-background layer: 123 with 13299 non-background voxels
# INFO - Extracted layer 123 (center)
# INFO - Extracted layer 128 (plus_n)
# INFO - Extracted layer 133 (plus_2n)
# INFO - Extracted layer 118 (minus_n)
# INFO - Extracted layer 113 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG_center_123.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG_plus_n_128.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG_plus_2n_133.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG_minus_n_118.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2017_adjustedBG_minus_2n_113.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1396.00]
# INFO - Max non-background layer: 150 with 13546 non-background voxels
# INFO - Extracted layer 150 (center)
# INFO - Extracted layer 155 (plus_n)
# INFO - Extracted layer 160 (plus_2n)
# INFO - Extracted layer 145 (minus_n)
# INFO - Extracted layer 140 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG_center_150.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG_plus_n_155.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG_plus_2n_160.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG_minus_n_145.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 03 11_adjustedBG_minus_2n_140.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1292.00]
# INFO - Max non-background layer: 138 with 13458 non-background voxels
# INFO - Extracted layer 138 (center)
# INFO - Extracted layer 143 (plus_n)
# INFO - Extracted layer 148 (plus_2n)
# INFO - Extracted layer 133 (minus_n)
# INFO - Extracted layer 128 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG_center_138.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG_plus_n_143.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG_plus_2n_148.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG_minus_n_133.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\60-33597 L 2019 09 02_adjustedBG_minus_2n_128.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\61-25724 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1391.00]
# INFO - Max non-background layer: 116 with 17451 non-background voxels
# INFO - Extracted layer 116 (center)
# INFO - Extracted layer 121 (plus_n)
# INFO - Extracted layer 126 (plus_2n)
# INFO - Extracted layer 111 (minus_n)
# INFO - Extracted layer 106 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-25724 L_adjustedBG_center_116.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-25724 L_adjustedBG_plus_n_121.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-25724 L_adjustedBG_plus_2n_126.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-25724 L_adjustedBG_minus_n_111.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-25724 L_adjustedBG_minus_2n_106.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\61-5586 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1370.00]
# INFO - Max non-background layer: 169 with 11024 non-background voxels
# INFO - Extracted layer 169 (center)
# INFO - Extracted layer 174 (plus_n)
# INFO - Extracted layer 179 (plus_2n)
# INFO - Extracted layer 164 (minus_n)
# INFO - Extracted layer 159 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-5586 L_adjustedBG_center_169.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-5586 L_adjustedBG_plus_n_174.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-5586 L_adjustedBG_plus_2n_179.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-5586 L_adjustedBG_minus_n_164.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\61-5586 L_adjustedBG_minus_2n_159.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\63-1330 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1351.00]
# INFO - Max non-background layer: 112 with 9471 non-background voxels
# INFO - Extracted layer 112 (center)
# INFO - Extracted layer 117 (plus_n)
# INFO - Extracted layer 122 (plus_2n)
# INFO - Extracted layer 107 (minus_n)
# INFO - Extracted layer 102 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 L_adjustedBG_center_112.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 L_adjustedBG_plus_n_117.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 L_adjustedBG_plus_2n_122.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 L_adjustedBG_minus_n_107.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 L_adjustedBG_minus_2n_102.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\63-1330 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1349.00]
# INFO - Max non-background layer: 86 with 7447 non-background voxels
# INFO - Extracted layer 86 (center)
# INFO - Extracted layer 91 (plus_n)
# INFO - Extracted layer 96 (plus_2n)
# INFO - Extracted layer 81 (minus_n)
# INFO - Extracted layer 76 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 R_adjustedBG_center_086.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 R_adjustedBG_plus_n_091.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 R_adjustedBG_plus_2n_096.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 R_adjustedBG_minus_n_081.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\63-1330 R_adjustedBG_minus_2n_076.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\64-7881 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1249.00]
# INFO - Max non-background layer: 131 with 14231 non-background voxels
# INFO - Extracted layer 131 (center)
# INFO - Extracted layer 136 (plus_n)
# INFO - Extracted layer 141 (plus_2n)
# INFO - Extracted layer 126 (minus_n)
# INFO - Extracted layer 121 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-7881 L_adjustedBG_center_131.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-7881 L_adjustedBG_plus_n_136.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-7881 L_adjustedBG_plus_2n_141.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-7881 L_adjustedBG_minus_n_126.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-7881 L_adjustedBG_minus_2n_121.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1289.00]
# INFO - Max non-background layer: 142 with 15328 non-background voxels
# INFO - Extracted layer 142 (center)
# INFO - Extracted layer 147 (plus_n)
# INFO - Extracted layer 152 (plus_2n)
# INFO - Extracted layer 137 (minus_n)
# INFO - Extracted layer 132 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG_center_142.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG_plus_n_147.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG_plus_2n_152.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG_minus_n_137.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2021_adjustedBG_minus_2n_132.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1401.00]
# INFO - Max non-background layer: 79 with 13758 non-background voxels
# INFO - Extracted layer 79 (center)
# INFO - Extracted layer 84 (plus_n)
# INFO - Extracted layer 89 (plus_2n)
# INFO - Extracted layer 74 (minus_n)
# INFO - Extracted layer 69 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG_center_079.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG_plus_n_084.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG_plus_2n_089.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG_minus_n_074.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 L 2022_adjustedBG_minus_2n_069.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1393.00]
# INFO - Max non-background layer: 92 with 15080 non-background voxels
# INFO - Extracted layer 92 (center)
# INFO - Extracted layer 97 (plus_n)
# INFO - Extracted layer 102 (plus_2n)
# INFO - Extracted layer 87 (minus_n)
# INFO - Extracted layer 82 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG_center_092.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG_plus_n_097.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG_plus_2n_102.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG_minus_n_087.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\64-8619 R 2021_adjustedBG_minus_2n_082.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\test\1\65-23331 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1389.00]
# INFO - Max non-background layer: 79 with 15647 non-background voxels
# INFO - Extracted layer 79 (center)
# INFO - Extracted layer 84 (plus_n)
# INFO - Extracted layer 89 (plus_2n)
# INFO - Extracted layer 74 (minus_n)
# INFO - Extracted layer 69 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\65-23331 R_adjustedBG_center_079.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\65-23331 R_adjustedBG_plus_n_084.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\65-23331 R_adjustedBG_plus_2n_089.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\65-23331 R_adjustedBG_minus_n_074.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\test\1\65-23331 R_adjustedBG_minus_2n_069.png
# INFO - Processing split: train
# INFO - Processing class: 0
# INFO - Found 102 NIfTI files
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\48-26453 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1390.00]
# INFO - Max non-background layer: 165 with 15883 non-background voxels
# INFO - Extracted layer 165 (center)
# INFO - Extracted layer 170 (plus_n)
# INFO - Extracted layer 175 (plus_2n)
# INFO - Extracted layer 160 (minus_n)
# INFO - Extracted layer 155 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\48-26453 L_adjustedBG_center_165.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\48-26453 L_adjustedBG_plus_n_170.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\48-26453 L_adjustedBG_plus_2n_175.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\48-26453 L_adjustedBG_minus_n_160.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\48-26453 L_adjustedBG_minus_2n_155.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\52-15073 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1363.00]
# INFO - Max non-background layer: 148 with 14081 non-background voxels
# INFO - Extracted layer 148 (center)
# INFO - Extracted layer 153 (plus_n)
# INFO - Extracted layer 158 (plus_2n)
# INFO - Extracted layer 143 (minus_n)
# INFO - Extracted layer 138 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\52-15073 L_adjustedBG_center_148.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\52-15073 L_adjustedBG_plus_n_153.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\52-15073 L_adjustedBG_plus_2n_158.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\52-15073 L_adjustedBG_minus_n_143.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\52-15073 L_adjustedBG_minus_2n_138.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-12918 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1339.00]
# INFO - Max non-background layer: 153 with 15344 non-background voxels
# INFO - Extracted layer 153 (center)
# INFO - Extracted layer 158 (plus_n)
# INFO - Extracted layer 163 (plus_2n)
# INFO - Extracted layer 148 (minus_n)
# INFO - Extracted layer 143 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 L_adjustedBG_center_153.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 L_adjustedBG_plus_n_158.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 L_adjustedBG_plus_2n_163.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 L_adjustedBG_minus_n_148.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 L_adjustedBG_minus_2n_143.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-12918 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1395.00]
# INFO - Max non-background layer: 110 with 17323 non-background voxels
# INFO - Extracted layer 110 (center)
# INFO - Extracted layer 115 (plus_n)
# INFO - Extracted layer 120 (plus_2n)
# INFO - Extracted layer 105 (minus_n)
# INFO - Extracted layer 100 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 R_adjustedBG_center_110.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 R_adjustedBG_plus_n_115.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 R_adjustedBG_plus_2n_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 R_adjustedBG_minus_n_105.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-12918 R_adjustedBG_minus_2n_100.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-22559 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1333.00]
# INFO - Max non-background layer: 165 with 13145 non-background voxels
# INFO - Extracted layer 165 (center)
# INFO - Extracted layer 170 (plus_n)
# INFO - Extracted layer 175 (plus_2n)
# INFO - Extracted layer 160 (minus_n)
# INFO - Extracted layer 155 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 L_adjustedBG_center_165.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 L_adjustedBG_plus_n_170.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 L_adjustedBG_plus_2n_175.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 L_adjustedBG_minus_n_160.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 L_adjustedBG_minus_2n_155.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-22559 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1402.00]
# INFO - Max non-background layer: 74 with 13635 non-background voxels
# INFO - Extracted layer 74 (center)
# INFO - Extracted layer 79 (plus_n)
# INFO - Extracted layer 84 (plus_2n)
# INFO - Extracted layer 69 (minus_n)
# INFO - Extracted layer 64 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 R_adjustedBG_center_074.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 R_adjustedBG_plus_n_079.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 R_adjustedBG_plus_2n_084.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 R_adjustedBG_minus_n_069.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-22559 R_adjustedBG_minus_2n_064.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-24700 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1333.00]
# INFO - Max non-background layer: 117 with 10577 non-background voxels
# INFO - Extracted layer 117 (center)
# INFO - Extracted layer 122 (plus_n)
# INFO - Extracted layer 127 (plus_2n)
# INFO - Extracted layer 112 (minus_n)
# INFO - Extracted layer 107 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-24700 R_adjustedBG_center_117.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-24700 R_adjustedBG_plus_n_122.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-24700 R_adjustedBG_plus_2n_127.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-24700 R_adjustedBG_minus_n_112.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-24700 R_adjustedBG_minus_2n_107.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\53-26507 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1341.00]
# INFO - Max non-background layer: 141 with 14676 non-background voxels
# INFO - Extracted layer 141 (center)
# INFO - Extracted layer 146 (plus_n)
# INFO - Extracted layer 151 (plus_2n)
# INFO - Extracted layer 136 (minus_n)
# INFO - Extracted layer 131 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-26507 L_adjustedBG_center_141.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\53-26507 L_adjustedBG_plus_n_146.png
# ...
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2015_adjustedBG_plus_2n_079.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2015_adjustedBG_minus_n_064.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2015_adjustedBG_minus_2n_059.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1354.00]
# INFO - Max non-background layer: 139 with 11258 non-background voxels
# INFO - Extracted layer 139 (center)
# INFO - Extracted layer 144 (plus_n)
# INFO - Extracted layer 149 (plus_2n)
# INFO - Extracted layer 134 (minus_n)
# INFO - Extracted layer 129 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG_center_139.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG_plus_n_144.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG_plus_2n_149.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG_minus_n_134.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-10397 R 2018_adjustedBG_minus_2n_129.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\57-34770 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1362.00]
# INFO - Max non-background layer: 165 with 13621 non-background voxels
# INFO - Extracted layer 165 (center)
# INFO - Extracted layer 170 (plus_n)
# INFO - Extracted layer 175 (plus_2n)
# INFO - Extracted layer 160 (minus_n)
# INFO - Extracted layer 155 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 L_adjustedBG_center_165.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 L_adjustedBG_plus_n_170.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 L_adjustedBG_plus_2n_175.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 L_adjustedBG_minus_n_160.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 L_adjustedBG_minus_2n_155.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\57-34770 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1371.00]
# INFO - Max non-background layer: 99 with 17371 non-background voxels
# INFO - Extracted layer 99 (center)
# INFO - Extracted layer 104 (plus_n)
# INFO - Extracted layer 109 (plus_2n)
# INFO - Extracted layer 94 (minus_n)
# INFO - Extracted layer 89 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 R_adjustedBG_center_099.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 R_adjustedBG_plus_n_104.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 R_adjustedBG_plus_2n_109.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 R_adjustedBG_minus_n_094.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\57-34770 R_adjustedBG_minus_2n_089.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\58-15574 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1397.00]
# INFO - Max non-background layer: 100 with 13795 non-background voxels
# INFO - Extracted layer 100 (center)
# INFO - Extracted layer 105 (plus_n)
# INFO - Extracted layer 110 (plus_2n)
# INFO - Extracted layer 95 (minus_n)
# INFO - Extracted layer 90 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-15574 L_adjustedBG_center_100.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-15574 L_adjustedBG_plus_n_105.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-15574 L_adjustedBG_plus_2n_110.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-15574 L_adjustedBG_minus_n_095.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-15574 L_adjustedBG_minus_2n_090.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\58-23240 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1364.00]
# INFO - Max non-background layer: 93 with 13784 non-background voxels
# INFO - Extracted layer 93 (center)
# INFO - Extracted layer 98 (plus_n)
# INFO - Extracted layer 103 (plus_2n)
# INFO - Extracted layer 88 (minus_n)
# INFO - Extracted layer 83 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-23240 R_adjustedBG_center_093.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-23240 R_adjustedBG_plus_n_098.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-23240 R_adjustedBG_plus_2n_103.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-23240 R_adjustedBG_minus_n_088.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-23240 R_adjustedBG_minus_2n_083.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\58-42016 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1494.00]
# INFO - Max non-background layer: 149 with 18742 non-background voxels
# INFO - Extracted layer 149 (center)
# INFO - Extracted layer 154 (plus_n)
# INFO - Extracted layer 159 (plus_2n)
# INFO - Extracted layer 144 (minus_n)
# INFO - Extracted layer 139 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 L_adjustedBG_center_149.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 L_adjustedBG_plus_n_154.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 L_adjustedBG_plus_2n_159.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 L_adjustedBG_minus_n_144.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 L_adjustedBG_minus_2n_139.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\58-42016 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1327.00]
# INFO - Max non-background layer: 115 with 19943 non-background voxels
# INFO - Extracted layer 115 (center)
# INFO - Extracted layer 120 (plus_n)
# INFO - Extracted layer 125 (plus_2n)
# INFO - Extracted layer 110 (minus_n)
# INFO - Extracted layer 105 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 R_adjustedBG_center_115.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 R_adjustedBG_plus_n_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 R_adjustedBG_plus_2n_125.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 R_adjustedBG_minus_n_110.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-42016 R_adjustedBG_minus_2n_105.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\58-651 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1431.00]
# INFO - Max non-background layer: 110 with 17326 non-background voxels
# INFO - Extracted layer 110 (center)
# INFO - Extracted layer 115 (plus_n)
# INFO - Extracted layer 120 (plus_2n)
# INFO - Extracted layer 105 (minus_n)
# INFO - Extracted layer 100 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-651 R_adjustedBG_center_110.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-651 R_adjustedBG_plus_n_115.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-651 R_adjustedBG_plus_2n_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-651 R_adjustedBG_minus_n_105.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\58-651 R_adjustedBG_minus_2n_100.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\59-14284 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1255.00]
# INFO - Max non-background layer: 120 with 12113 non-background voxels
# INFO - Extracted layer 120 (center)
# INFO - Extracted layer 125 (plus_n)
# INFO - Extracted layer 130 (plus_2n)
# INFO - Extracted layer 115 (minus_n)
# INFO - Extracted layer 110 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-14284 L_adjustedBG_center_120.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-14284 L_adjustedBG_plus_n_125.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-14284 L_adjustedBG_plus_2n_130.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-14284 L_adjustedBG_minus_n_115.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-14284 L_adjustedBG_minus_2n_110.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\59-27051 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1357.00]
# INFO - Max non-background layer: 154 with 13866 non-background voxels
# INFO - Extracted layer 154 (center)
# INFO - Extracted layer 159 (plus_n)
# INFO - Extracted layer 164 (plus_2n)
# INFO - Extracted layer 149 (minus_n)
# INFO - Extracted layer 144 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 L_adjustedBG_center_154.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 L_adjustedBG_plus_n_159.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 L_adjustedBG_plus_2n_164.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 L_adjustedBG_minus_n_149.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 L_adjustedBG_minus_2n_144.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\59-27051 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1408.00]
# INFO - Max non-background layer: 109 with 14302 non-background voxels
# INFO - Extracted layer 109 (center)
# INFO - Extracted layer 114 (plus_n)
# INFO - Extracted layer 119 (plus_2n)
# INFO - Extracted layer 104 (minus_n)
# INFO - Extracted layer 99 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 R_adjustedBG_center_109.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 R_adjustedBG_plus_n_114.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 R_adjustedBG_plus_2n_119.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 R_adjustedBG_minus_n_104.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-27051 R_adjustedBG_minus_2n_099.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\59-35009 R_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1471.00]
# INFO - Max non-background layer: 85 with 13349 non-background voxels
# INFO - Extracted layer 85 (center)
# INFO - Extracted layer 90 (plus_n)
# INFO - Extracted layer 95 (plus_2n)
# INFO - Extracted layer 80 (minus_n)
# INFO - Extracted layer 75 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-35009 R_adjustedBG_center_085.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-35009 R_adjustedBG_plus_n_090.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-35009 R_adjustedBG_plus_2n_095.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-35009 R_adjustedBG_minus_n_080.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-35009 R_adjustedBG_minus_2n_075.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\59-6269 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1403.00]
# INFO - Max non-background layer: 159 with 15373 non-background voxels
# INFO - Extracted layer 159 (center)
# INFO - Extracted layer 164 (plus_n)
# INFO - Extracted layer 169 (plus_2n)
# INFO - Extracted layer 154 (minus_n)
# INFO - Extracted layer 149 (minus_2n)
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-6269 L_adjustedBG_center_159.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-6269 L_adjustedBG_plus_n_164.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-6269 L_adjustedBG_plus_2n_169.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-6269 L_adjustedBG_minus_n_154.png
# INFO - Saved: D:\Kananat\Data\training_dataset_2D\training_dataset_OA\train\0\59-6269 L_adjustedBG_minus_2n_149.png
# INFO - Processing: D:\Kananat\Data\training_dataset_3D\training_dataset_OA\train\0\60-21851 L_adjustedBG.nii.gz
# INFO - Data shape: (255, 255, 255)
# INFO - Data range: [-250.00, 1328.00]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      13     logger.error(f"Input dataset directory does not exist: {input_dataset}")
#      15 # Process the dataset
# ---> 16 process_dataset(input_dataset, output_dataset, n, background_value)
#      18 logger.info("Processing completed!")
#
# Cell In[2], line 177, in process_dataset(input_dataset_dir, output_dataset_dir, n, background_value)
#     174 logger.info(f"Found {len(nifti_files)} NIfTI files")
#     176 for nifti_file in nifti_files:
# --> 177     process_nifti_file(nifti_file, output_class_dir, n, background_value)
#
# Cell In[2], line 122, in process_nifti_file(nifti_path, output_dir, n, background_value)
#     119 logger.info(f"Data range: [{data.min():.2f}, {data.max():.2f}]")
#     121 # Find layer with maximum non-background voxels
# --> 122 center_layer = find_max_non_background_layer(data, background_value)
#     124 # Extract layers
#     125 layers = extract_layers(data, center_layer, n, background_value)
#
# Cell In[2], line 46, in find_max_non_background_layer(data, background_value)
#      44 for i in range(data.shape[0]):
#      45     layer = data[i, :, :]
# ---> 46     non_background_count = np.sum(layer != background_value)
#      47     non_background_counts.append(non_background_count)
#      49 max_layer_idx = np.argmax(non_background_counts)
#
# File c:\Users\kanan\miniconda3\envs\2dmodelGPU\lib\site-packages\numpy\core\fromnumeric.py:2172, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)
#    2167
#    2168     """
#    2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2172 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2173                     initial=None, where=None):
#    2174     return (a, out)
#    2177 @array_function_dispatch(_sum_dispatcher)
#    2178 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2179         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %% [markdown]
# # Extract all layers with more than n percent non background

# %%
# 3D NIfTI to 2D PNG Layer Extractor - Top N Informative Layers
# Extracts the N most informative layers with minimum spacing between them

import os
import numpy as np
import nibabel as nib
from PIL import Image
from pathlib import Path
import logging

# Set up logging for Jupyter
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# =============================================================================
# CONFIGURATION - Modify these parameters
# =============================================================================

# Dataset paths
INPUT_DATASET_DIR = r'D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D'  # Update this path
OUTPUT_DATASET_DIR = r'D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\2D'  # Update this path

# Processing parameters
N_LAYERS = 20          # Number of most informative layers to extract
MIN_SPACING = 5       # Minimum spacing between selected layers (k parameter)
BACKGROUND_VALUE = -250   # Background value to exclude

print("Configuration:")
print(f"Input dataset: {INPUT_DATASET_DIR}")
print(f"Output dataset: {OUTPUT_DATASET_DIR}")
print(f"Number of layers to extract: {N_LAYERS}")
print(f"Minimum spacing between layers: {MIN_SPACING}")
print(f"Background value: {BACKGROUND_VALUE}")

# =============================================================================
# HELPER FUNCTIONS
# =============================================================================

def normalize_voxel_values(data, background_value=-250):
    """
    Normalize voxel values from [-250, max_value] to [0, 255]
    
    Args:
        data: 3D numpy array
        background_value: Background value (default: -250)
    
    Returns:
        Normalized data as uint8
    """
    # Clip values to ensure minimum is background_value
    data = np.clip(data, background_value, 1500)
    
    # Get min and max values
    min_val = data.min()
    max_val = data.max()
    
    if max_val == min_val:
        # Handle case where all values are the same
        return np.zeros_like(data, dtype=np.uint8)
    
    # Normalize to [0, 255]
    normalized = ((data - min_val) / (max_val - min_val)) * 255
    return normalized.astype(np.uint8)

def calculate_layer_informativeness(data, background_value=-250):
    """
    Calculate informativeness score for each layer
    Uses non-background ratio as the primary metric
    
    Args:
        data: 3D numpy array
        background_value: Background value to exclude
    
    Returns:
        List of tuples: (layer_index, informativeness_score)
    """
    layer_scores = []
    total_voxels_per_layer = data.shape[1] * data.shape[2]
    
    for i in range(data.shape[0]):
        layer = data[i, :, :]
        
        # Calculate non-background ratio
        non_background_count = np.sum(layer > background_value)
        non_background_ratio = non_background_count / total_voxels_per_layer
        
        # Additional informativeness metrics can be added here:
        # - Variance of non-background voxels
        # - Edge content
        # - Texture measures
        
        # For now, using non-background ratio as informativeness score
        informativeness_score = non_background_ratio
        
        layer_scores.append((i, informativeness_score))
    
    return layer_scores

def select_top_layers_with_spacing(layer_scores, n_layers, min_spacing):
    """
    Select top N layers ensuring minimum spacing between them
    
    Args:
        layer_scores: List of tuples (layer_index, score)
        n_layers: Number of layers to select
        min_spacing: Minimum spacing between selected layers
    
    Returns:
        List of tuples: (layer_index, score) for selected layers
    """
    # Sort by score in descending order
    sorted_layers = sorted(layer_scores, key=lambda x: x[1], reverse=True)
    
    selected_layers = []
    used_indices = set()
    
    print(f"  Selecting {n_layers} layers with minimum spacing of {min_spacing}...")
    
    for layer_idx, score in sorted_layers:
        # Check if this layer conflicts with already selected layers
        conflict = False
        for selected_idx, _ in selected_layers:
            if abs(layer_idx - selected_idx) < min_spacing:
                conflict = True
                break
        
        if not conflict:
            selected_layers.append((layer_idx, score))
            used_indices.add(layer_idx)
            print(f"    Selected layer {layer_idx} (score: {score:.4f})")
            
            if len(selected_layers) >= n_layers:
                break
    
    # Sort selected layers by index for consistent naming
    selected_layers.sort(key=lambda x: x[0])
    
    if len(selected_layers) < n_layers:
        print(f"    ⚠️ Only found {len(selected_layers)} layers that satisfy spacing constraint")
    
    return selected_layers

def extract_selected_layers(data, selected_layers):
    """
    Extract the selected layers
    
    Args:
        data: 3D numpy array
        selected_layers: List of tuples (layer_index, score)
    
    Returns:
        Dictionary of layer indices and their corresponding 2D arrays
    """
    layers = {}
    
    for i, (layer_idx, score) in enumerate(selected_layers):
        layer_key = f"layer_{layer_idx:03d}_rank_{i+1:02d}_score_{score:.3f}"
        layers[layer_key] = data[layer_idx, :, :]
        print(f"  Extracted layer {layer_idx} (rank {i+1}, score: {score:.4f})")
    
    return layers

def save_layer_as_png(layer_data, output_path):
    """
    Save 2D layer as PNG with 3 identical channels
    
    Args:
        layer_data: 2D numpy array (normalized to 0-255)
        output_path: Output file path
    """
    # Create 3-channel image (RGB) with identical values
    rgb_image = np.stack([layer_data, layer_data, layer_data], axis=-1)
    
    # Convert to PIL Image and save
    pil_image = Image.fromarray(rgb_image, mode='RGB')
    pil_image.save(output_path)

def process_nifti_file(nifti_path, output_dir, n_layers, min_spacing, background_value=-250):
    """
    Process a single NIfTI file and extract top N informative layers with spacing
    
    Args:
        nifti_path: Path to .nii.gz file
        output_dir: Output directory for this file's layers
        n_layers: Number of layers to extract
        min_spacing: Minimum spacing between layers
        background_value: Background value
    """
    try:
        print(f"\nProcessing: {nifti_path}")
        
        # Load NIfTI file
        nifti_img = nib.load(nifti_path)
        data = nifti_img.get_fdata()
        
        print(f"  Data shape: {data.shape}")
        print(f"  Data range: [{data.min():.2f}, {data.max():.2f}]")
        
        # Calculate informativeness for all layers
        layer_scores = calculate_layer_informativeness(data, background_value)
        
        # Select top N layers with spacing constraint
        selected_layers = select_top_layers_with_spacing(layer_scores, n_layers, min_spacing)
        
        if not selected_layers:
            print(f"  ⚠️ No suitable layers found")
            return 0
        
        # Extract selected layers
        layers = extract_selected_layers(data, selected_layers)
        
        # Process and save each layer
        filename_base = Path(nifti_path).stem.replace('.nii', '')  # Remove .nii.gz extension
        saved_count = 0
        
        for layer_name, layer_data in layers.items():
            # Normalize the layer
            normalized_layer = normalize_voxel_values(layer_data, background_value)
            
            # Create output filename
            output_filename = f"{filename_base}_{layer_name}.png"
            output_path = os.path.join(output_dir, output_filename)
            
            # Save as PNG
            save_layer_as_png(normalized_layer, output_path)
            saved_count += 1
        
        print(f"  ✅ Saved {saved_count} layers")
        return saved_count
    
    except Exception as e:
        print(f"  ❌ Error processing {nifti_path}: {str(e)}")
        return 0

def process_dataset(input_dataset_dir, output_dataset_dir, n_layers, min_spacing, background_value=-250):
    """
    Process entire dataset
    
    Args:
        input_dataset_dir: Input dataset directory
        output_dataset_dir: Output dataset directory
        n_layers: Number of layers to extract per file
        min_spacing: Minimum spacing between layers
        background_value: Background value
    
    Returns:
        Dictionary with processing statistics
    """
    input_path = Path(input_dataset_dir)
    output_path = Path(output_dataset_dir)
    
    stats = {
        'total_files': 0,
        'processed_files': 0,
        'total_layers_saved': 0,
        'splits': {}
    }
    
    # Iterate through train/val/test folders
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            print(f"\n{'='*50}")
            print(f"Processing split: {split_dir.name}")
            print(f"{'='*50}")
            
            stats['splits'][split_dir.name] = {'classes': {}}
            
            # Iterate through class folders (0, 1)
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    print(f"\n📁 Processing class: {class_dir.name}")
                    
                    # Create output directory
                    output_class_dir = output_path / split_dir.name / class_dir.name
                    output_class_dir.mkdir(parents=True, exist_ok=True)
                    
                    # Process all .nii.gz files in this directory
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    print(f"Found {len(nifti_files)} NIfTI files")
                    
                    class_stats = {
                        'total_files': len(nifti_files),
                        'processed_files': 0,
                        'total_layers': 0
                    }
                    
                    for nifti_file in nifti_files:
                        stats['total_files'] += 1
                        layers_saved = process_nifti_file(nifti_file, output_class_dir, n_layers, min_spacing, background_value)
                        
                        if layers_saved > 0:
                            stats['processed_files'] += 1
                            class_stats['processed_files'] += 1
                            stats['total_layers_saved'] += layers_saved
                            class_stats['total_layers'] += layers_saved
                    
                    stats['splits'][split_dir.name]['classes'][class_dir.name] = class_stats
                    print(f"Class {class_dir.name} summary: {class_stats['processed_files']}/{class_stats['total_files']} files processed, {class_stats['total_layers']} layers saved")
    
    return stats

# =============================================================================
# MAIN PROCESSING
# =============================================================================

# Validate input directory
if not os.path.exists(INPUT_DATASET_DIR):
    print(f"❌ Input dataset directory does not exist: {INPUT_DATASET_DIR}")
    print("Please update the INPUT_DATASET_DIR variable with the correct path")
else:
    print(f"✅ Input dataset found: {INPUT_DATASET_DIR}")
    
    # Validate parameters
    if N_LAYERS <= 0:
        print(f"❌ N_LAYERS must be positive, got: {N_LAYERS}")
    elif MIN_SPACING < 0:
        print(f"❌ MIN_SPACING must be non-negative, got: {MIN_SPACING}")
    else:
        print(f"✅ Starting processing to extract {N_LAYERS} layers with {MIN_SPACING} spacing...")
        
        # Process the dataset
        print(f"\n🚀 Starting dataset processing...")
        stats = process_dataset(INPUT_DATASET_DIR, OUTPUT_DATASET_DIR, N_LAYERS, MIN_SPACING, BACKGROUND_VALUE)
        
        # Print final summary
        print(f"\n{'='*60}")
        print("📊 PROCESSING SUMMARY")
        print(f"{'='*60}")
        print(f"Total files processed: {stats['processed_files']}/{stats['total_files']}")
        print(f"Total layers extracted: {stats['total_layers_saved']}")
        print(f"Average layers per file: {stats['total_layers_saved']/max(stats['processed_files'], 1):.1f}")
        print(f"Output directory: {OUTPUT_DATASET_DIR}")
        
        for split_name, split_data in stats['splits'].items():
            print(f"\n{split_name.upper()}:")
            for class_name, class_data in split_data['classes'].items():
                avg_layers = class_data['total_layers'] / max(class_data['processed_files'], 1)
                print(f"  Class {class_name}: {class_data['processed_files']}/{class_data['total_files']} files → {class_data['total_layers']} layers (avg: {avg_layers:.1f})")
        
        print(f"\n✅ Processing completed successfully!")

# =============================================================================
# OPTIONAL: ANALYZE LAYER SELECTION
# =============================================================================

def analyze_layer_selection(input_dataset_dir, n_layers, min_spacing, background_value=-250):
    """
    Analyze which layers would be selected across the dataset
    This helps you understand the distribution of informative layers
    """
    input_path = Path(input_dataset_dir)
    selected_layer_indices = []
    
    print(f"\n📈 Analyzing layer selection with N={n_layers}, spacing={min_spacing}...")
    
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    
                    for nifti_file in nifti_files[:3]:  # Analyze first 3 files for speed
                        try:
                            nifti_img = nib.load(nifti_file)
                            data = nifti_img.get_fdata()
                            
                            layer_scores = calculate_layer_informativeness(data, background_value)
                            selected_layers = select_top_layers_with_spacing(layer_scores, n_layers, min_spacing)
                            
                            for layer_idx, _ in selected_layers:
                                selected_layer_indices.append(layer_idx)
                        except:
                            continue
    
    if selected_layer_indices:
        selected_layer_indices = np.array(selected_layer_indices)
        print(f"Selected layer statistics:")
        print(f"  Mean position: {selected_layer_indices.mean():.1f}")
        print(f"  Median position: {np.median(selected_layer_indices):.1f}")
        print(f"  Min position: {selected_layer_indices.min()}")
        print(f"  Max position: {selected_layer_indices.max()}")
        print(f"  Most common positions: {np.bincount(selected_layer_indices).argsort()[-5:][::-1]}")

# Uncomment the line below to run the analysis
# analyze_layer_selection(INPUT_DATASET_DIR, N_LAYERS, MIN_SPACING, BACKGROUND_VALUE)
# Out:
# Configuration:
# Input dataset: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D
# Output dataset: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\2D
# Number of layers to extract: 20
# Minimum spacing between layers: 5
# Background value: -250
# ✅ Input dataset found: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D
# ✅ Starting processing to extract 20 layers with 5 spacing...
#
# 🚀 Starting dataset processing...
#
# ==================================================
# Processing split: test
# ==================================================
#
# 📁 Processing class: 0
# Found 8 NIfTI files
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\034_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2380.76]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 155 (score: 0.2873)
#     Selected layer 160 (score: 0.2857)
#     Selected layer 150 (score: 0.2819)
#     Selected layer 165 (score: 0.2756)
#     Selected layer 145 (score: 0.2743)
#     Selected layer 140 (score: 0.2646)
#     Selected layer 170 (score: 0.2569)
#     Selected layer 135 (score: 0.2550)
#     Selected layer 130 (score: 0.2469)
#     Selected layer 125 (score: 0.2364)
#     Selected layer 175 (score: 0.2230)
#     Selected layer 120 (score: 0.2219)
#     Selected layer 115 (score: 0.2021)
#     Selected layer 180 (score: 0.1768)
#     Selected layer 110 (score: 0.1706)
#     Selected layer 105 (score: 0.1471)
#     Selected layer 185 (score: 0.1346)
#     Selected layer 100 (score: 0.1291)
#     Selected layer 95 (score: 0.1148)
#     Selected layer 190 (score: 0.1114)
#   Extracted layer 95 (rank 1, score: 0.1148)
#   Extracted layer 100 (rank 2, score: 0.1291)
#   Extracted layer 105 (rank 3, score: 0.1471)
#   Extracted layer 110 (rank 4, score: 0.1706)
#   Extracted layer 115 (rank 5, score: 0.2021)
#   Extracted layer 120 (rank 6, score: 0.2219)
#   Extracted layer 125 (rank 7, score: 0.2364)
#   Extracted layer 130 (rank 8, score: 0.2469)
#   Extracted layer 135 (rank 9, score: 0.2550)
#   Extracted layer 140 (rank 10, score: 0.2646)
#   Extracted layer 145 (rank 11, score: 0.2743)
#   Extracted layer 150 (rank 12, score: 0.2819)
#   Extracted layer 155 (rank 13, score: 0.2873)
#   Extracted layer 160 (rank 14, score: 0.2857)
#   Extracted layer 165 (rank 15, score: 0.2756)
#   Extracted layer 170 (rank 16, score: 0.2569)
#   Extracted layer 175 (rank 17, score: 0.2230)
#   Extracted layer 180 (rank 18, score: 0.1768)
#   Extracted layer 185 (rank 19, score: 0.1346)
#   Extracted layer 190 (rank 20, score: 0.1114)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\034_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2303.29]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 116 (score: 0.3315)
#     Selected layer 121 (score: 0.3298)
#     Selected layer 111 (score: 0.3252)
#     Selected layer 126 (score: 0.3153)
#     Selected layer 131 (score: 0.2966)
#     Selected layer 106 (score: 0.2879)
#     Selected layer 136 (score: 0.2785)
#     Selected layer 101 (score: 0.2648)
#     Selected layer 141 (score: 0.2618)
#     Selected layer 146 (score: 0.2442)
#     Selected layer 96 (score: 0.2390)
#     Selected layer 151 (score: 0.2227)
#     Selected layer 91 (score: 0.2127)
#     Selected layer 156 (score: 0.1920)
#     Selected layer 86 (score: 0.1780)
#     Selected layer 161 (score: 0.1626)
#     Selected layer 81 (score: 0.1474)
#     Selected layer 166 (score: 0.1427)
#     Selected layer 171 (score: 0.1273)
#     Selected layer 76 (score: 0.1270)
#   Extracted layer 76 (rank 1, score: 0.1270)
#   Extracted layer 81 (rank 2, score: 0.1474)
#   Extracted layer 86 (rank 3, score: 0.1780)
#   Extracted layer 91 (rank 4, score: 0.2127)
#   Extracted layer 96 (rank 5, score: 0.2390)
#   Extracted layer 101 (rank 6, score: 0.2648)
#   Extracted layer 106 (rank 7, score: 0.2879)
#   Extracted layer 111 (rank 8, score: 0.3252)
#   Extracted layer 116 (rank 9, score: 0.3315)
#   Extracted layer 121 (rank 10, score: 0.3298)
#   Extracted layer 126 (rank 11, score: 0.3153)
#   Extracted layer 131 (rank 12, score: 0.2966)
#   Extracted layer 136 (rank 13, score: 0.2785)
#   Extracted layer 141 (rank 14, score: 0.2618)
#   Extracted layer 146 (rank 15, score: 0.2442)
#   Extracted layer 151 (rank 16, score: 0.2227)
#   Extracted layer 156 (rank 17, score: 0.1920)
#   Extracted layer 161 (rank 18, score: 0.1626)
#   Extracted layer 166 (rank 19, score: 0.1427)
#   Extracted layer 171 (rank 20, score: 0.1273)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\040_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2370.64]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 169 (score: 0.3217)
#     Selected layer 164 (score: 0.3199)
#     Selected layer 174 (score: 0.3185)
#     Selected layer 159 (score: 0.3106)
#     Selected layer 179 (score: 0.3092)
#     Selected layer 154 (score: 0.3017)
#     Selected layer 149 (score: 0.2943)
#     Selected layer 144 (score: 0.2867)
#     Selected layer 139 (score: 0.2779)
#     Selected layer 134 (score: 0.2677)
#     Selected layer 129 (score: 0.2531)
#     Selected layer 184 (score: 0.2525)
#     Selected layer 124 (score: 0.2311)
#     Selected layer 189 (score: 0.2226)
#     Selected layer 119 (score: 0.2067)
#     Selected layer 194 (score: 0.1883)
#     Selected layer 114 (score: 0.1863)
#     Selected layer 109 (score: 0.1698)
#     Selected layer 104 (score: 0.1554)
#     Selected layer 99 (score: 0.1411)
#   Extracted layer 99 (rank 1, score: 0.1411)
#   Extracted layer 104 (rank 2, score: 0.1554)
#   Extracted layer 109 (rank 3, score: 0.1698)
#   Extracted layer 114 (rank 4, score: 0.1863)
#   Extracted layer 119 (rank 5, score: 0.2067)
#   Extracted layer 124 (rank 6, score: 0.2311)
#   Extracted layer 129 (rank 7, score: 0.2531)
#   Extracted layer 134 (rank 8, score: 0.2677)
#   Extracted layer 139 (rank 9, score: 0.2779)
#   Extracted layer 144 (rank 10, score: 0.2867)
#   Extracted layer 149 (rank 11, score: 0.2943)
#   Extracted layer 154 (rank 12, score: 0.3017)
#   Extracted layer 159 (rank 13, score: 0.3106)
#   Extracted layer 164 (rank 14, score: 0.3199)
#   Extracted layer 169 (rank 15, score: 0.3217)
#   Extracted layer 174 (rank 16, score: 0.3185)
#   Extracted layer 179 (rank 17, score: 0.3092)
#   Extracted layer 184 (rank 18, score: 0.2525)
#   Extracted layer 189 (rank 19, score: 0.2226)
#   Extracted layer 194 (rank 20, score: 0.1883)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\040_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2241.93]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 90 (score: 0.3047)
#     Selected layer 85 (score: 0.3018)
#     Selected layer 95 (score: 0.3008)
#     Selected layer 100 (score: 0.2957)
#     Selected layer 105 (score: 0.2883)
#     Selected layer 110 (score: 0.2810)
#     Selected layer 80 (score: 0.2778)
#     Selected layer 115 (score: 0.2733)
#     Selected layer 120 (score: 0.2643)
#     Selected layer 125 (score: 0.2540)
#     Selected layer 75 (score: 0.2432)
#     Selected layer 130 (score: 0.2402)
#     Selected layer 135 (score: 0.2225)
#     Selected layer 70 (score: 0.2081)
#     Selected layer 140 (score: 0.1944)
#     Selected layer 145 (score: 0.1717)
#     Selected layer 65 (score: 0.1682)
#     Selected layer 150 (score: 0.1531)
#     Selected layer 60 (score: 0.1388)
#     Selected layer 155 (score: 0.1367)
#   Extracted layer 60 (rank 1, score: 0.1388)
#   Extracted layer 65 (rank 2, score: 0.1682)
#   Extracted layer 70 (rank 3, score: 0.2081)
#   Extracted layer 75 (rank 4, score: 0.2432)
#   Extracted layer 80 (rank 5, score: 0.2778)
#   Extracted layer 85 (rank 6, score: 0.3018)
#   Extracted layer 90 (rank 7, score: 0.3047)
#   Extracted layer 95 (rank 8, score: 0.3008)
#   Extracted layer 100 (rank 9, score: 0.2957)
#   Extracted layer 105 (rank 10, score: 0.2883)
#   Extracted layer 110 (rank 11, score: 0.2810)
#   Extracted layer 115 (rank 12, score: 0.2733)
#   Extracted layer 120 (rank 13, score: 0.2643)
#   Extracted layer 125 (rank 14, score: 0.2540)
#   Extracted layer 130 (rank 15, score: 0.2402)
#   Extracted layer 135 (rank 16, score: 0.2225)
#   Extracted layer 140 (rank 17, score: 0.1944)
#   Extracted layer 145 (rank 18, score: 0.1717)
#   Extracted layer 150 (rank 19, score: 0.1531)
#   Extracted layer 155 (rank 20, score: 0.1367)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\073_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2420.56]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 148 (score: 0.2459)
#     Selected layer 143 (score: 0.2439)
#     Selected layer 153 (score: 0.2399)
#     Selected layer 138 (score: 0.2321)
#     Selected layer 158 (score: 0.2245)
#     Selected layer 133 (score: 0.2171)
#     Selected layer 128 (score: 0.2024)
#     Selected layer 163 (score: 0.1974)
#     Selected layer 123 (score: 0.1880)
#     Selected layer 118 (score: 0.1694)
#     Selected layer 168 (score: 0.1684)
#     Selected layer 113 (score: 0.1454)
#     Selected layer 173 (score: 0.1406)
#     Selected layer 108 (score: 0.1273)
#     Selected layer 103 (score: 0.1137)
#     Selected layer 98 (score: 0.1013)
#     Selected layer 178 (score: 0.1006)
#     Selected layer 93 (score: 0.0911)
#     Selected layer 88 (score: 0.0805)
#     Selected layer 183 (score: 0.0701)
#   Extracted layer 88 (rank 1, score: 0.0805)
#   Extracted layer 93 (rank 2, score: 0.0911)
#   Extracted layer 98 (rank 3, score: 0.1013)
#   Extracted layer 103 (rank 4, score: 0.1137)
#   Extracted layer 108 (rank 5, score: 0.1273)
#   Extracted layer 113 (rank 6, score: 0.1454)
#   Extracted layer 118 (rank 7, score: 0.1694)
#   Extracted layer 123 (rank 8, score: 0.1880)
#   Extracted layer 128 (rank 9, score: 0.2024)
#   Extracted layer 133 (rank 10, score: 0.2171)
#   Extracted layer 138 (rank 11, score: 0.2321)
#   Extracted layer 143 (rank 12, score: 0.2439)
#   Extracted layer 148 (rank 13, score: 0.2459)
#   Extracted layer 153 (rank 14, score: 0.2399)
#   Extracted layer 158 (rank 15, score: 0.2245)
#   Extracted layer 163 (rank 16, score: 0.1974)
#   Extracted layer 168 (rank 17, score: 0.1684)
#   Extracted layer 173 (rank 18, score: 0.1406)
#   Extracted layer 178 (rank 19, score: 0.1006)
#   Extracted layer 183 (rank 20, score: 0.0701)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\073_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2626.06]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 82 (score: 0.2735)
#     Selected layer 87 (score: 0.2703)
#     Selected layer 77 (score: 0.2688)
#     Selected layer 72 (score: 0.2547)
#     Selected layer 92 (score: 0.2517)
#     Selected layer 97 (score: 0.2364)
#     Selected layer 67 (score: 0.2270)
#     Selected layer 102 (score: 0.2244)
#     Selected layer 107 (score: 0.2116)
#     Selected layer 112 (score: 0.1972)
#     Selected layer 62 (score: 0.1895)
#     Selected layer 117 (score: 0.1799)
#     Selected layer 57 (score: 0.1618)
#     Selected layer 122 (score: 0.1543)
#     Selected layer 127 (score: 0.1353)
#     Selected layer 52 (score: 0.1254)
#     Selected layer 132 (score: 0.1243)
#     Selected layer 137 (score: 0.1139)
#     Selected layer 142 (score: 0.1026)
#     Selected layer 147 (score: 0.0909)
#   Extracted layer 52 (rank 1, score: 0.1254)
#   Extracted layer 57 (rank 2, score: 0.1618)
#   Extracted layer 62 (rank 3, score: 0.1895)
#   Extracted layer 67 (rank 4, score: 0.2270)
#   Extracted layer 72 (rank 5, score: 0.2547)
#   Extracted layer 77 (rank 6, score: 0.2688)
#   Extracted layer 82 (rank 7, score: 0.2735)
#   Extracted layer 87 (rank 8, score: 0.2703)
#   Extracted layer 92 (rank 9, score: 0.2517)
#   Extracted layer 97 (rank 10, score: 0.2364)
#   Extracted layer 102 (rank 11, score: 0.2244)
#   Extracted layer 107 (rank 12, score: 0.2116)
#   Extracted layer 112 (rank 13, score: 0.1972)
#   Extracted layer 117 (rank 14, score: 0.1799)
#   Extracted layer 122 (rank 15, score: 0.1543)
#   Extracted layer 127 (rank 16, score: 0.1353)
#   Extracted layer 132 (rank 17, score: 0.1243)
#   Extracted layer 137 (rank 18, score: 0.1139)
#   Extracted layer 142 (rank 19, score: 0.1026)
#   Extracted layer 147 (rank 20, score: 0.0909)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\105_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2288.60]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 163 (score: 0.2908)
#     Selected layer 168 (score: 0.2887)
#     Selected layer 158 (score: 0.2846)
#     Selected layer 173 (score: 0.2802)
#     Selected layer 153 (score: 0.2801)
#     Selected layer 148 (score: 0.2718)
#     Selected layer 143 (score: 0.2645)
#     Selected layer 138 (score: 0.2584)
#     Selected layer 133 (score: 0.2486)
#     Selected layer 128 (score: 0.2381)
#     Selected layer 178 (score: 0.2310)
#     Selected layer 123 (score: 0.2201)
#     Selected layer 118 (score: 0.1961)
#     Selected layer 113 (score: 0.1783)
#     Selected layer 108 (score: 0.1627)
#     Selected layer 183 (score: 0.1566)
#     Selected layer 103 (score: 0.1486)
#     Selected layer 98 (score: 0.1357)
#     Selected layer 93 (score: 0.1238)
#     Selected layer 188 (score: 0.1230)
#   Extracted layer 93 (rank 1, score: 0.1238)
#   Extracted layer 98 (rank 2, score: 0.1357)
#   Extracted layer 103 (rank 3, score: 0.1486)
#   Extracted layer 108 (rank 4, score: 0.1627)
#   Extracted layer 113 (rank 5, score: 0.1783)
#   Extracted layer 118 (rank 6, score: 0.1961)
#   Extracted layer 123 (rank 7, score: 0.2201)
#   Extracted layer 128 (rank 8, score: 0.2381)
#   Extracted layer 133 (rank 9, score: 0.2486)
#   Extracted layer 138 (rank 10, score: 0.2584)
#   Extracted layer 143 (rank 11, score: 0.2645)
#   Extracted layer 148 (rank 12, score: 0.2718)
#   Extracted layer 153 (rank 13, score: 0.2801)
#   Extracted layer 158 (rank 14, score: 0.2846)
#   Extracted layer 163 (rank 15, score: 0.2908)
#   Extracted layer 168 (rank 16, score: 0.2887)
#   Extracted layer 173 (rank 17, score: 0.2802)
#   Extracted layer 178 (rank 18, score: 0.2310)
#   Extracted layer 183 (rank 19, score: 0.1566)
#   Extracted layer 188 (rank 20, score: 0.1230)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\0\105_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2254.51]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 114 (score: 0.3369)
#     Selected layer 119 (score: 0.3347)
#     Selected layer 109 (score: 0.3334)
#     Selected layer 124 (score: 0.3257)
#     Selected layer 104 (score: 0.3253)
#     Selected layer 129 (score: 0.3157)
#     Selected layer 134 (score: 0.3030)
#     Selected layer 139 (score: 0.2861)
#     Selected layer 99 (score: 0.2797)
#     Selected layer 144 (score: 0.2704)
#     Selected layer 149 (score: 0.2380)
#     Selected layer 154 (score: 0.2135)
#     Selected layer 159 (score: 0.1928)
#     Selected layer 94 (score: 0.1813)
#     Selected layer 164 (score: 0.1749)
#     Selected layer 169 (score: 0.1590)
#     Selected layer 174 (score: 0.1434)
#     Selected layer 89 (score: 0.1332)
#     Selected layer 179 (score: 0.1266)
#     Selected layer 184 (score: 0.1095)
#   Extracted layer 89 (rank 1, score: 0.1332)
#   Extracted layer 94 (rank 2, score: 0.1813)
#   Extracted layer 99 (rank 3, score: 0.2797)
#   Extracted layer 104 (rank 4, score: 0.3253)
#   Extracted layer 109 (rank 5, score: 0.3334)
#   Extracted layer 114 (rank 6, score: 0.3369)
#   Extracted layer 119 (rank 7, score: 0.3347)
#   Extracted layer 124 (rank 8, score: 0.3257)
#   Extracted layer 129 (rank 9, score: 0.3157)
#   Extracted layer 134 (rank 10, score: 0.3030)
#   Extracted layer 139 (rank 11, score: 0.2861)
#   Extracted layer 144 (rank 12, score: 0.2704)
#   Extracted layer 149 (rank 13, score: 0.2380)
#   Extracted layer 154 (rank 14, score: 0.2135)
#   Extracted layer 159 (rank 15, score: 0.1928)
#   Extracted layer 164 (rank 16, score: 0.1749)
#   Extracted layer 169 (rank 17, score: 0.1590)
#   Extracted layer 174 (rank 18, score: 0.1434)
#   Extracted layer 179 (rank 19, score: 0.1266)
#   Extracted layer 184 (rank 20, score: 0.1095)
#   ✅ Saved 20 layers
# Class 0 summary: 8/8 files processed, 160 layers saved
#
# 📁 Processing class: 1
# Found 8 NIfTI files
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\010_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2317.50]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 141 (score: 0.2543)
#     Selected layer 136 (score: 0.2458)
#     Selected layer 146 (score: 0.2434)
#     Selected layer 131 (score: 0.2383)
#     Selected layer 126 (score: 0.2335)
#     Selected layer 121 (score: 0.2291)
#     Selected layer 116 (score: 0.2242)
#     Selected layer 151 (score: 0.2233)
#     Selected layer 111 (score: 0.2161)
#     Selected layer 106 (score: 0.2074)
#     Selected layer 156 (score: 0.2045)
#     Selected layer 101 (score: 0.1960)
#     Selected layer 96 (score: 0.1809)
#     Selected layer 161 (score: 0.1698)
#     Selected layer 91 (score: 0.1608)
#     Selected layer 166 (score: 0.1375)
#     Selected layer 86 (score: 0.1314)
#     Selected layer 171 (score: 0.1205)
#     Selected layer 81 (score: 0.1172)
#     Selected layer 176 (score: 0.1094)
#   Extracted layer 81 (rank 1, score: 0.1172)
#   Extracted layer 86 (rank 2, score: 0.1314)
#   Extracted layer 91 (rank 3, score: 0.1608)
#   Extracted layer 96 (rank 4, score: 0.1809)
#   Extracted layer 101 (rank 5, score: 0.1960)
#   Extracted layer 106 (rank 6, score: 0.2074)
#   Extracted layer 111 (rank 7, score: 0.2161)
#   Extracted layer 116 (rank 8, score: 0.2242)
#   Extracted layer 121 (rank 9, score: 0.2291)
#   Extracted layer 126 (rank 10, score: 0.2335)
#   Extracted layer 131 (rank 11, score: 0.2383)
#   Extracted layer 136 (rank 12, score: 0.2458)
#   Extracted layer 141 (rank 13, score: 0.2543)
#   Extracted layer 146 (rank 14, score: 0.2434)
#   Extracted layer 151 (rank 15, score: 0.2233)
#   Extracted layer 156 (rank 16, score: 0.2045)
#   Extracted layer 161 (rank 17, score: 0.1698)
#   Extracted layer 166 (rank 18, score: 0.1375)
#   Extracted layer 171 (rank 19, score: 0.1205)
#   Extracted layer 176 (rank 20, score: 0.1094)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\010_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2268.96]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 120 (score: 0.2596)
#     Selected layer 125 (score: 0.2542)
#     Selected layer 115 (score: 0.2475)
#     Selected layer 130 (score: 0.2409)
#     Selected layer 135 (score: 0.2247)
#     Selected layer 110 (score: 0.2197)
#     Selected layer 140 (score: 0.2079)
#     Selected layer 105 (score: 0.1972)
#     Selected layer 145 (score: 0.1911)
#     Selected layer 100 (score: 0.1784)
#     Selected layer 150 (score: 0.1722)
#     Selected layer 95 (score: 0.1613)
#     Selected layer 155 (score: 0.1491)
#     Selected layer 90 (score: 0.1447)
#     Selected layer 85 (score: 0.1296)
#     Selected layer 160 (score: 0.1195)
#     Selected layer 80 (score: 0.1172)
#     Selected layer 75 (score: 0.1055)
#     Selected layer 165 (score: 0.1013)
#     Selected layer 70 (score: 0.0946)
#   Extracted layer 70 (rank 1, score: 0.0946)
#   Extracted layer 75 (rank 2, score: 0.1055)
#   Extracted layer 80 (rank 3, score: 0.1172)
#   Extracted layer 85 (rank 4, score: 0.1296)
#   Extracted layer 90 (rank 5, score: 0.1447)
#   Extracted layer 95 (rank 6, score: 0.1613)
#   Extracted layer 100 (rank 7, score: 0.1784)
#   Extracted layer 105 (rank 8, score: 0.1972)
#   Extracted layer 110 (rank 9, score: 0.2197)
#   Extracted layer 115 (rank 10, score: 0.2475)
#   Extracted layer 120 (rank 11, score: 0.2596)
#   Extracted layer 125 (rank 12, score: 0.2542)
#   Extracted layer 130 (rank 13, score: 0.2409)
#   Extracted layer 135 (rank 14, score: 0.2247)
#   Extracted layer 140 (rank 15, score: 0.2079)
#   Extracted layer 145 (rank 16, score: 0.1911)
#   Extracted layer 150 (rank 17, score: 0.1722)
#   Extracted layer 155 (rank 18, score: 0.1491)
#   Extracted layer 160 (rank 19, score: 0.1195)
#   Extracted layer 165 (rank 20, score: 0.1013)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\062_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2700.00]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 182 (score: 0.2562)
#     Selected layer 177 (score: 0.2531)
#     Selected layer 172 (score: 0.2463)
#     Selected layer 187 (score: 0.2418)
#     Selected layer 167 (score: 0.2380)
#     Selected layer 162 (score: 0.2306)
#     Selected layer 157 (score: 0.2253)
#     Selected layer 152 (score: 0.2201)
#     Selected layer 147 (score: 0.2155)
#     Selected layer 142 (score: 0.2112)
#     Selected layer 137 (score: 0.2092)
#     Selected layer 132 (score: 0.2062)
#     Selected layer 127 (score: 0.2016)
#     Selected layer 192 (score: 0.1995)
#     Selected layer 122 (score: 0.1935)
#     Selected layer 117 (score: 0.1837)
#     Selected layer 112 (score: 0.1718)
#     Selected layer 197 (score: 0.1614)
#     Selected layer 107 (score: 0.1590)
#     Selected layer 102 (score: 0.1485)
#   Extracted layer 102 (rank 1, score: 0.1485)
#   Extracted layer 107 (rank 2, score: 0.1590)
#   Extracted layer 112 (rank 3, score: 0.1718)
#   Extracted layer 117 (rank 4, score: 0.1837)
#   Extracted layer 122 (rank 5, score: 0.1935)
#   Extracted layer 127 (rank 6, score: 0.2016)
#   Extracted layer 132 (rank 7, score: 0.2062)
#   Extracted layer 137 (rank 8, score: 0.2092)
#   Extracted layer 142 (rank 9, score: 0.2112)
#   Extracted layer 147 (rank 10, score: 0.2155)
#   Extracted layer 152 (rank 11, score: 0.2201)
#   Extracted layer 157 (rank 12, score: 0.2253)
#   Extracted layer 162 (rank 13, score: 0.2306)
#   Extracted layer 167 (rank 14, score: 0.2380)
#   Extracted layer 172 (rank 15, score: 0.2463)
#   Extracted layer 177 (rank 16, score: 0.2531)
#   Extracted layer 182 (rank 17, score: 0.2562)
#   Extracted layer 187 (rank 18, score: 0.2418)
#   Extracted layer 192 (rank 19, score: 0.1995)
#   Extracted layer 197 (rank 20, score: 0.1614)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\062_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2629.49]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 67 (score: 0.2576)
#     Selected layer 72 (score: 0.2569)
#     Selected layer 77 (score: 0.2524)
#     Selected layer 82 (score: 0.2441)
#     Selected layer 62 (score: 0.2427)
#     Selected layer 87 (score: 0.2380)
#     Selected layer 94 (score: 0.2372)
#     Selected layer 111 (score: 0.2354)
#     Selected layer 99 (score: 0.2344)
#     Selected layer 106 (score: 0.2334)
#     Selected layer 116 (score: 0.2326)
#     Selected layer 121 (score: 0.2319)
#     Selected layer 126 (score: 0.2257)
#     Selected layer 131 (score: 0.2197)
#     Selected layer 136 (score: 0.2135)
#     Selected layer 141 (score: 0.2031)
#     Selected layer 57 (score: 0.1995)
#     Selected layer 146 (score: 0.1915)
#     Selected layer 151 (score: 0.1788)
#     Selected layer 156 (score: 0.1670)
#   Extracted layer 57 (rank 1, score: 0.1995)
#   Extracted layer 62 (rank 2, score: 0.2427)
#   Extracted layer 67 (rank 3, score: 0.2576)
#   Extracted layer 72 (rank 4, score: 0.2569)
#   Extracted layer 77 (rank 5, score: 0.2524)
#   Extracted layer 82 (rank 6, score: 0.2441)
#   Extracted layer 87 (rank 7, score: 0.2380)
#   Extracted layer 94 (rank 8, score: 0.2372)
#   Extracted layer 99 (rank 9, score: 0.2344)
#   Extracted layer 106 (rank 10, score: 0.2334)
#   Extracted layer 111 (rank 11, score: 0.2354)
#   Extracted layer 116 (rank 12, score: 0.2326)
#   Extracted layer 121 (rank 13, score: 0.2319)
#   Extracted layer 126 (rank 14, score: 0.2257)
#   Extracted layer 131 (rank 15, score: 0.2197)
#   Extracted layer 136 (rank 16, score: 0.2135)
#   Extracted layer 141 (rank 17, score: 0.2031)
#   Extracted layer 146 (rank 18, score: 0.1915)
#   Extracted layer 151 (rank 19, score: 0.1788)
#   Extracted layer 156 (rank 20, score: 0.1670)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\070_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2410.83]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 170 (score: 0.2798)
#     Selected layer 165 (score: 0.2738)
#     Selected layer 175 (score: 0.2615)
#     Selected layer 160 (score: 0.2498)
#     Selected layer 155 (score: 0.2328)
#     Selected layer 150 (score: 0.2169)
#     Selected layer 180 (score: 0.2141)
#     Selected layer 145 (score: 0.2018)
#     Selected layer 140 (score: 0.1859)
#     Selected layer 135 (score: 0.1679)
#     Selected layer 185 (score: 0.1678)
#     Selected layer 130 (score: 0.1433)
#     Selected layer 190 (score: 0.1340)
#     Selected layer 125 (score: 0.1250)
#     Selected layer 120 (score: 0.1120)
#     Selected layer 195 (score: 0.1115)
#     Selected layer 115 (score: 0.1021)
#     Selected layer 200 (score: 0.0938)
#     Selected layer 110 (score: 0.0934)
#     Selected layer 105 (score: 0.0858)
#   Extracted layer 105 (rank 1, score: 0.0858)
#   Extracted layer 110 (rank 2, score: 0.0934)
#   Extracted layer 115 (rank 3, score: 0.1021)
#   Extracted layer 120 (rank 4, score: 0.1120)
#   Extracted layer 125 (rank 5, score: 0.1250)
#   Extracted layer 130 (rank 6, score: 0.1433)
#   Extracted layer 135 (rank 7, score: 0.1679)
#   Extracted layer 140 (rank 8, score: 0.1859)
#   Extracted layer 145 (rank 9, score: 0.2018)
#   Extracted layer 150 (rank 10, score: 0.2169)
#   Extracted layer 155 (rank 11, score: 0.2328)
#   Extracted layer 160 (rank 12, score: 0.2498)
#   Extracted layer 165 (rank 13, score: 0.2738)
#   Extracted layer 170 (rank 14, score: 0.2798)
#   Extracted layer 175 (rank 15, score: 0.2615)
#   Extracted layer 180 (rank 16, score: 0.2141)
#   Extracted layer 185 (rank 17, score: 0.1678)
#   Extracted layer 190 (rank 18, score: 0.1340)
#   Extracted layer 195 (rank 19, score: 0.1115)
#   Extracted layer 200 (rank 20, score: 0.0938)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\070_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2624.28]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 82 (score: 0.2676)
#     Selected layer 77 (score: 0.2621)
#     Selected layer 87 (score: 0.2560)
#     Selected layer 92 (score: 0.2304)
#     Selected layer 97 (score: 0.2146)
#     Selected layer 72 (score: 0.2145)
#     Selected layer 102 (score: 0.2035)
#     Selected layer 107 (score: 0.1951)
#     Selected layer 112 (score: 0.1855)
#     Selected layer 117 (score: 0.1735)
#     Selected layer 122 (score: 0.1555)
#     Selected layer 67 (score: 0.1484)
#     Selected layer 127 (score: 0.1389)
#     Selected layer 132 (score: 0.1256)
#     Selected layer 137 (score: 0.1148)
#     Selected layer 142 (score: 0.1046)
#     Selected layer 62 (score: 0.1032)
#     Selected layer 147 (score: 0.0959)
#     Selected layer 152 (score: 0.0881)
#     Selected layer 57 (score: 0.0817)
#   Extracted layer 57 (rank 1, score: 0.0817)
#   Extracted layer 62 (rank 2, score: 0.1032)
#   Extracted layer 67 (rank 3, score: 0.1484)
#   Extracted layer 72 (rank 4, score: 0.2145)
#   Extracted layer 77 (rank 5, score: 0.2621)
#   Extracted layer 82 (rank 6, score: 0.2676)
#   Extracted layer 87 (rank 7, score: 0.2560)
#   Extracted layer 92 (rank 8, score: 0.2304)
#   Extracted layer 97 (rank 9, score: 0.2146)
#   Extracted layer 102 (rank 10, score: 0.2035)
#   Extracted layer 107 (rank 11, score: 0.1951)
#   Extracted layer 112 (rank 12, score: 0.1855)
#   Extracted layer 117 (rank 13, score: 0.1735)
#   Extracted layer 122 (rank 14, score: 0.1555)
#   Extracted layer 127 (rank 15, score: 0.1389)
#   Extracted layer 132 (rank 16, score: 0.1256)
#   Extracted layer 137 (rank 17, score: 0.1148)
#   Extracted layer 142 (rank 18, score: 0.1046)
#   Extracted layer 147 (rank 19, score: 0.0959)
#   Extracted layer 152 (rank 20, score: 0.0881)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\087_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2363.03]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 162 (score: 0.3009)
#     Selected layer 157 (score: 0.2947)
#     Selected layer 152 (score: 0.2878)
#     Selected layer 147 (score: 0.2807)
#     Selected layer 167 (score: 0.2757)
#     Selected layer 142 (score: 0.2722)
#     Selected layer 137 (score: 0.2645)
#     Selected layer 132 (score: 0.2584)
#     Selected layer 127 (score: 0.2525)
#     Selected layer 122 (score: 0.2449)
#     Selected layer 117 (score: 0.2368)
#     Selected layer 112 (score: 0.2285)
#     Selected layer 172 (score: 0.2181)
#     Selected layer 107 (score: 0.2160)
#     Selected layer 102 (score: 0.2025)
#     Selected layer 97 (score: 0.1820)
#     Selected layer 92 (score: 0.1617)
#     Selected layer 177 (score: 0.1614)
#     Selected layer 87 (score: 0.1440)
#     Selected layer 82 (score: 0.1268)
#   Extracted layer 82 (rank 1, score: 0.1268)
#   Extracted layer 87 (rank 2, score: 0.1440)
#   Extracted layer 92 (rank 3, score: 0.1617)
#   Extracted layer 97 (rank 4, score: 0.1820)
#   Extracted layer 102 (rank 5, score: 0.2025)
#   Extracted layer 107 (rank 6, score: 0.2160)
#   Extracted layer 112 (rank 7, score: 0.2285)
#   Extracted layer 117 (rank 8, score: 0.2368)
#   Extracted layer 122 (rank 9, score: 0.2449)
#   Extracted layer 127 (rank 10, score: 0.2525)
#   Extracted layer 132 (rank 11, score: 0.2584)
#   Extracted layer 137 (rank 12, score: 0.2645)
#   Extracted layer 142 (rank 13, score: 0.2722)
#   Extracted layer 147 (rank 14, score: 0.2807)
#   Extracted layer 152 (rank 15, score: 0.2878)
#   Extracted layer 157 (rank 16, score: 0.2947)
#   Extracted layer 162 (rank 17, score: 0.3009)
#   Extracted layer 167 (rank 18, score: 0.2757)
#   Extracted layer 172 (rank 19, score: 0.2181)
#   Extracted layer 177 (rank 20, score: 0.1614)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\test\1\087_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2611.83]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 98 (score: 0.3252)
#     Selected layer 103 (score: 0.3189)
#     Selected layer 93 (score: 0.3124)
#     Selected layer 108 (score: 0.3056)
#     Selected layer 113 (score: 0.2909)
#     Selected layer 88 (score: 0.2878)
#     Selected layer 118 (score: 0.2746)
#     Selected layer 123 (score: 0.2611)
#     Selected layer 128 (score: 0.2500)
#     Selected layer 83 (score: 0.2463)
#     Selected layer 133 (score: 0.2376)
#     Selected layer 138 (score: 0.2242)
#     Selected layer 143 (score: 0.2078)
#     Selected layer 78 (score: 0.2025)
#     Selected layer 148 (score: 0.1835)
#     Selected layer 73 (score: 0.1772)
#     Selected layer 153 (score: 0.1601)
#     Selected layer 68 (score: 0.1548)
#     Selected layer 158 (score: 0.1423)
#     Selected layer 63 (score: 0.1305)
#   Extracted layer 63 (rank 1, score: 0.1305)
#   Extracted layer 68 (rank 2, score: 0.1548)
#   Extracted layer 73 (rank 3, score: 0.1772)
#   Extracted layer 78 (rank 4, score: 0.2025)
#   Extracted layer 83 (rank 5, score: 0.2463)
#   Extracted layer 88 (rank 6, score: 0.2878)
#   Extracted layer 93 (rank 7, score: 0.3124)
#   Extracted layer 98 (rank 8, score: 0.3252)
#   Extracted layer 103 (rank 9, score: 0.3189)
#   Extracted layer 108 (rank 10, score: 0.3056)
#   Extracted layer 113 (rank 11, score: 0.2909)
#   Extracted layer 118 (rank 12, score: 0.2746)
#   Extracted layer 123 (rank 13, score: 0.2611)
#   Extracted layer 128 (rank 14, score: 0.2500)
#   Extracted layer 133 (rank 15, score: 0.2376)
#   Extracted layer 138 (rank 16, score: 0.2242)
#   Extracted layer 143 (rank 17, score: 0.2078)
#   Extracted layer 148 (rank 18, score: 0.1835)
#   Extracted layer 153 (rank 19, score: 0.1601)
#   Extracted layer 158 (rank 20, score: 0.1423)
#   ✅ Saved 20 layers
# Class 1 summary: 8/8 files processed, 160 layers saved
#
# ==================================================
# Processing split: train
# ==================================================
#
# 📁 Processing class: 0
# Found 52 NIfTI files
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\013_baseline_left_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2271.21]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 143 (score: 0.2365)
#     Selected layer 148 (score: 0.2364)
#     Selected layer 138 (score: 0.2341)
#     Selected layer 133 (score: 0.2322)
#     Selected layer 153 (score: 0.2320)
#     Selected layer 128 (score: 0.2285)
#     Selected layer 123 (score: 0.2227)
#     Selected layer 158 (score: 0.2213)
#     Selected layer 118 (score: 0.2179)
#     Selected layer 113 (score: 0.2117)
#     Selected layer 108 (score: 0.2094)
#     Selected layer 103 (score: 0.2046)
#     Selected layer 98 (score: 0.1995)
#     Selected layer 93 (score: 0.1920)
#     Selected layer 88 (score: 0.1824)
#     Selected layer 83 (score: 0.1657)
#     Selected layer 163 (score: 0.1619)
#     Selected layer 78 (score: 0.1538)
#     Selected layer 73 (score: 0.1445)
#     Selected layer 68 (score: 0.1353)
#   Extracted layer 68 (rank 1, score: 0.1353)
#   Extracted layer 73 (rank 2, score: 0.1445)
#   Extracted layer 78 (rank 3, score: 0.1538)
#   Extracted layer 83 (rank 4, score: 0.1657)
#   Extracted layer 88 (rank 5, score: 0.1824)
#   Extracted layer 93 (rank 6, score: 0.1920)
#   Extracted layer 98 (rank 7, score: 0.1995)
#   Extracted layer 103 (rank 8, score: 0.2046)
#   Extracted layer 108 (rank 9, score: 0.2094)
#   Extracted layer 113 (rank 10, score: 0.2117)
#   Extracted layer 118 (rank 11, score: 0.2179)
#   Extracted layer 123 (rank 12, score: 0.2227)
#   Extracted layer 128 (rank 13, score: 0.2285)
#   Extracted layer 133 (rank 14, score: 0.2322)
#   Extracted layer 138 (rank 15, score: 0.2341)
#   Extracted layer 143 (rank 16, score: 0.2365)
#   Extracted layer 148 (rank 17, score: 0.2364)
#   Extracted layer 153 (rank 18, score: 0.2320)
#   Extracted layer 158 (rank 19, score: 0.2213)
#   Extracted layer 163 (rank 20, score: 0.1619)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\013_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2260.32]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 98 (score: 0.3112)
#     Selected layer 93 (score: 0.3102)
#     Selected layer 103 (score: 0.3061)
#     Selected layer 108 (score: 0.2961)
#     Selected layer 113 (score: 0.2860)
#     Selected layer 118 (score: 0.2735)
#     Selected layer 88 (score: 0.2696)
#     Selected layer 123 (score: 0.2648)
#     Selected layer 128 (score: 0.2546)
#     Selected layer 133 (score: 0.2459)
#     Selected layer 138 (score: 0.2370)
#     Selected layer 143 (score: 0.2274)
#     Selected layer 148 (score: 0.2154)
#     Selected layer 83 (score: 0.2035)
#     Selected layer 153 (score: 0.2003)
#     Selected layer 158 (score: 0.1819)
#     Selected layer 78 (score: 0.1626)
#     Selected layer 163 (score: 0.1536)
#     Selected layer 168 (score: 0.1366)
#     Selected layer 73 (score: 0.1286)
#   Extracted layer 73 (rank 1, score: 0.1286)
#   Extracted layer 78 (rank 2, score: 0.1626)
#   Extracted layer 83 (rank 3, score: 0.2035)
#   Extracted layer 88 (rank 4, score: 0.2696)
#   Extracted layer 93 (rank 5, score: 0.3102)
#   Extracted layer 98 (rank 6, score: 0.3112)
#   Extracted layer 103 (rank 7, score: 0.3061)
#   Extracted layer 108 (rank 8, score: 0.2961)
#   Extracted layer 113 (rank 9, score: 0.2860)
#   Extracted layer 118 (rank 10, score: 0.2735)
#   Extracted layer 123 (rank 11, score: 0.2648)
#   Extracted layer 128 (rank 12, score: 0.2546)
#   Extracted layer 133 (rank 13, score: 0.2459)
#   Extracted layer 138 (rank 14, score: 0.2370)
#   Extracted layer 143 (rank 15, score: 0.2274)
#   Extracted layer 148 (rank 16, score: 0.2154)
#   Extracted layer 153 (rank 17, score: 0.2003)
#   Extracted layer 158 (rank 18, score: 0.1819)
#   Extracted layer 163 (rank 19, score: 0.1536)
#   Extracted layer 168 (rank 20, score: 0.1366)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\017_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2493.57]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 107 (score: 0.2239)
#     Selected layer 112 (score: 0.2231)
#     Selected layer 117 (score: 0.2217)
#     Selected layer 102 (score: 0.2211)
#     Selected layer 122 (score: 0.2186)
#     Selected layer 97 (score: 0.2154)
#     Selected layer 127 (score: 0.2134)
#     Selected layer 132 (score: 0.2055)
#     Selected layer 92 (score: 0.2022)
#     Selected layer 137 (score: 0.1936)
#     Selected layer 142 (score: 0.1722)
#     Selected layer 87 (score: 0.1667)
#     Selected layer 147 (score: 0.1499)
#     Selected layer 82 (score: 0.1353)
#     Selected layer 152 (score: 0.1317)
#     Selected layer 157 (score: 0.1160)
#     Selected layer 162 (score: 0.1027)
#     Selected layer 77 (score: 0.1012)
#     Selected layer 167 (score: 0.0909)
#     Selected layer 172 (score: 0.0791)
#   Extracted layer 77 (rank 1, score: 0.1012)
#   Extracted layer 82 (rank 2, score: 0.1353)
#   Extracted layer 87 (rank 3, score: 0.1667)
#   Extracted layer 92 (rank 4, score: 0.2022)
#   Extracted layer 97 (rank 5, score: 0.2154)
#   Extracted layer 102 (rank 6, score: 0.2211)
#   Extracted layer 107 (rank 7, score: 0.2239)
#   Extracted layer 112 (rank 8, score: 0.2231)
#   Extracted layer 117 (rank 9, score: 0.2217)
#   Extracted layer 122 (rank 10, score: 0.2186)
#   Extracted layer 127 (rank 11, score: 0.2134)
#   Extracted layer 132 (rank 12, score: 0.2055)
#   Extracted layer 137 (rank 13, score: 0.1936)
#   Extracted layer 142 (rank 14, score: 0.1722)
#   Extracted layer 147 (rank 15, score: 0.1499)
#   Extracted layer 152 (rank 16, score: 0.1317)
#   Extracted layer 157 (rank 17, score: 0.1160)
#   Extracted layer 162 (rank 18, score: 0.1027)
#   Extracted layer 167 (rank 19, score: 0.0909)
#   Extracted layer 172 (rank 20, score: 0.0791)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\017_scan_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2505.71]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 121 (score: 0.2438)
#     Selected layer 126 (score: 0.2405)
#     Selected layer 116 (score: 0.2400)
#     Selected layer 131 (score: 0.2358)
#     Selected layer 111 (score: 0.2318)
#     Selected layer 136 (score: 0.2297)
#     Selected layer 141 (score: 0.2213)
#     Selected layer 106 (score: 0.2171)
#     Selected layer 146 (score: 0.2107)
#     Selected layer 101 (score: 0.1980)
#     Selected layer 151 (score: 0.1976)
#     Selected layer 156 (score: 0.1826)
#     Selected layer 96 (score: 0.1748)
#     Selected layer 161 (score: 0.1489)
#     Selected layer 91 (score: 0.1466)
#     Selected layer 86 (score: 0.1170)
#     Selected layer 166 (score: 0.1116)
#     Selected layer 81 (score: 0.0884)
#     Selected layer 171 (score: 0.0662)
#     Selected layer 76 (score: 0.0647)
#   Extracted layer 76 (rank 1, score: 0.0647)
#   Extracted layer 81 (rank 2, score: 0.0884)
#   Extracted layer 86 (rank 3, score: 0.1170)
#   Extracted layer 91 (rank 4, score: 0.1466)
#   Extracted layer 96 (rank 5, score: 0.1748)
#   Extracted layer 101 (rank 6, score: 0.1980)
#   Extracted layer 106 (rank 7, score: 0.2171)
#   Extracted layer 111 (rank 8, score: 0.2318)
#   Extracted layer 116 (rank 9, score: 0.2400)
#   Extracted layer 121 (rank 10, score: 0.2438)
#   Extracted layer 126 (rank 11, score: 0.2405)
#   Extracted layer 131 (rank 12, score: 0.2358)
#   Extracted layer 136 (rank 13, score: 0.2297)
#   Extracted layer 141 (rank 14, score: 0.2213)
#   Extracted layer 146 (rank 15, score: 0.2107)
#   Extracted layer 151 (rank 16, score: 0.1976)
#   Extracted layer 156 (rank 17, score: 0.1826)
#   Extracted layer 161 (rank 18, score: 0.1489)
#   Extracted layer 166 (rank 19, score: 0.1116)
#   Extracted layer 171 (rank 20, score: 0.0662)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\019_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2629.09]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 154 (score: 0.2991)
#     Selected layer 159 (score: 0.2950)
#     Selected layer 149 (score: 0.2931)
#     Selected layer 144 (score: 0.2798)
#     Selected layer 139 (score: 0.2664)
#     Selected layer 134 (score: 0.2536)
#     Selected layer 129 (score: 0.2406)
#     Selected layer 164 (score: 0.2370)
#     Selected layer 124 (score: 0.2240)
#     Selected layer 119 (score: 0.2056)
#     Selected layer 169 (score: 0.2030)
#     Selected layer 114 (score: 0.1849)
#     Selected layer 174 (score: 0.1743)
#     Selected layer 109 (score: 0.1612)
#     Selected layer 179 (score: 0.1537)
#     Selected layer 104 (score: 0.1454)
#     Selected layer 184 (score: 0.1376)
#     Selected layer 99 (score: 0.1351)
#     Selected layer 94 (score: 0.1261)
#     Selected layer 189 (score: 0.1241)
#   Extracted layer 94 (rank 1, score: 0.1261)
#   Extracted layer 99 (rank 2, score: 0.1351)
#   Extracted layer 104 (rank 3, score: 0.1454)
#   Extracted layer 109 (rank 4, score: 0.1612)
#   Extracted layer 114 (rank 5, score: 0.1849)
#   Extracted layer 119 (rank 6, score: 0.2056)
#   Extracted layer 124 (rank 7, score: 0.2240)
#   Extracted layer 129 (rank 8, score: 0.2406)
#   Extracted layer 134 (rank 9, score: 0.2536)
#   Extracted layer 139 (rank 10, score: 0.2664)
#   Extracted layer 144 (rank 11, score: 0.2798)
#   Extracted layer 149 (rank 12, score: 0.2931)
#   Extracted layer 154 (rank 13, score: 0.2991)
#   Extracted layer 159 (rank 14, score: 0.2950)
#   Extracted layer 164 (rank 15, score: 0.2370)
#   Extracted layer 169 (rank 16, score: 0.2030)
#   Extracted layer 174 (rank 17, score: 0.1743)
#   Extracted layer 179 (rank 18, score: 0.1537)
#   Extracted layer 184 (rank 19, score: 0.1376)
#   Extracted layer 189 (rank 20, score: 0.1241)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\019_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2209.60]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 99 (score: 0.3011)
#     Selected layer 104 (score: 0.2968)
#     Selected layer 109 (score: 0.2878)
#     Selected layer 114 (score: 0.2784)
#     Selected layer 94 (score: 0.2737)
#     Selected layer 119 (score: 0.2723)
#     Selected layer 124 (score: 0.2654)
#     Selected layer 129 (score: 0.2565)
#     Selected layer 134 (score: 0.2427)
#     Selected layer 89 (score: 0.2265)
#     Selected layer 139 (score: 0.2260)
#     Selected layer 144 (score: 0.2059)
#     Selected layer 84 (score: 0.1837)
#     Selected layer 149 (score: 0.1701)
#     Selected layer 79 (score: 0.1542)
#     Selected layer 154 (score: 0.1473)
#     Selected layer 74 (score: 0.1334)
#     Selected layer 159 (score: 0.1309)
#     Selected layer 69 (score: 0.1207)
#     Selected layer 164 (score: 0.1186)
#   Extracted layer 69 (rank 1, score: 0.1207)
#   Extracted layer 74 (rank 2, score: 0.1334)
#   Extracted layer 79 (rank 3, score: 0.1542)
#   Extracted layer 84 (rank 4, score: 0.1837)
#   Extracted layer 89 (rank 5, score: 0.2265)
#   Extracted layer 94 (rank 6, score: 0.2737)
#   Extracted layer 99 (rank 7, score: 0.3011)
#   Extracted layer 104 (rank 8, score: 0.2968)
#   Extracted layer 109 (rank 9, score: 0.2878)
#   Extracted layer 114 (rank 10, score: 0.2784)
#   Extracted layer 119 (rank 11, score: 0.2723)
#   Extracted layer 124 (rank 12, score: 0.2654)
#   Extracted layer 129 (rank 13, score: 0.2565)
#   Extracted layer 134 (rank 14, score: 0.2427)
#   Extracted layer 139 (rank 15, score: 0.2260)
#   Extracted layer 144 (rank 16, score: 0.2059)
#   Extracted layer 149 (rank 17, score: 0.1701)
#   Extracted layer 154 (rank 18, score: 0.1473)
#   Extracted layer 159 (rank 19, score: 0.1309)
#   Extracted layer 164 (rank 20, score: 0.1186)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\030_baseline_left_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2427.01]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 136 (score: 0.2953)
#     Selected layer 131 (score: 0.2878)
#     Selected layer 141 (score: 0.2861)
#     Selected layer 146 (score: 0.2702)
#     Selected layer 126 (score: 0.2701)
#     Selected layer 151 (score: 0.2535)
#     Selected layer 156 (score: 0.2355)
#     Selected layer 121 (score: 0.2315)
#     Selected layer 161 (score: 0.2148)
#     Selected layer 116 (score: 0.1964)
#     Selected layer 166 (score: 0.1900)
#     Selected layer 111 (score: 0.1800)
#     Selected layer 171 (score: 0.1677)
#     Selected layer 106 (score: 0.1656)
#     Selected layer 176 (score: 0.1518)
#     Selected layer 101 (score: 0.1513)
#     Selected layer 181 (score: 0.1393)
#     Selected layer 96 (score: 0.1320)
#     Selected layer 186 (score: 0.1291)
#     Selected layer 91 (score: 0.1193)
#   Extracted layer 91 (rank 1, score: 0.1193)
#   Extracted layer 96 (rank 2, score: 0.1320)
#   Extracted layer 101 (rank 3, score: 0.1513)
#   Extracted layer 106 (rank 4, score: 0.1656)
#   Extracted layer 111 (rank 5, score: 0.1800)
#   Extracted layer 116 (rank 6, score: 0.1964)
#   Extracted layer 121 (rank 7, score: 0.2315)
#   Extracted layer 126 (rank 8, score: 0.2701)
#   Extracted layer 131 (rank 9, score: 0.2878)
#   Extracted layer 136 (rank 10, score: 0.2953)
#   Extracted layer 141 (rank 11, score: 0.2861)
#   Extracted layer 146 (rank 12, score: 0.2702)
#   Extracted layer 151 (rank 13, score: 0.2535)
#   Extracted layer 156 (rank 14, score: 0.2355)
#   Extracted layer 161 (rank 15, score: 0.2148)
#   Extracted layer 166 (rank 16, score: 0.1900)
#   Extracted layer 171 (rank 17, score: 0.1677)
#   Extracted layer 176 (rank 18, score: 0.1518)
#   Extracted layer 181 (rank 19, score: 0.1393)
#   Extracted layer 186 (rank 20, score: 0.1291)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\train\0\030_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2692.99]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 129 (score: 0.2651)
#     Selected layer 124 (score: 0.2625)
#     Selected layer 134 (score: 0.2622)
#     Selected layer 119 (score: 0.2577)
#     Selected layer 139 (score: 0.2542)
#     Selected layer 114 (score: 0.2522)
#     Selected layer 109 (score: 0.2454)
#     Selected layer 144 (score: 0.2384)
#     Selected layer 104 (score: 0.2372)
#     Selected layer 99 (score: 0.2269)
#     Selected layer 149 (score: 0.2191)
#     Selected layer 94 (score: 0.2152)
#     Selected layer 154 (score: 0.2055)
#     Selected layer 89 (score: 0.1999)
#     Selected layer 159 (score: 0.1898)
#     Selected layer 84 (score: 0.1828)
#     Selected layer 79 (score: 0.1699)
#     Selected layer 164 (score: 0.1627)
#     Selected layer 74 (score: 0.1594)
#     Selected layer 69 (score: 0.1528)
#   Extracted layer 69 (rank 1, score: 0.1528)
#   Extracted layer 74 (rank 2, score: 0.1594)
#   Extracted layer 79 (rank 3, score: 0.1699)
#   Extracted layer 84 (rank 4, score: 0.1828)
#   Extracted layer 89 (rank 5, score: 0.1999)
#   Extracted layer 94 (rank 6, score: 0.2152)
#   Extracted layer 99 (rank 7, score: 0.2269)
#   Extracted layer 104 (rank 8, score: 0.2372)
#   Extracted layer 109 (rank 9, score: 0.2454)
# ...
#     Selected layer 164 (score: 0.1496)
#     Selected layer 119 (score: 0.1489)
#     Selected layer 114 (score: 0.1434)
#     Selected layer 109 (score: 0.1371)
#     Selected layer 104 (score: 0.1315)
#     Selected layer 99 (score: 0.1247)
#     Selected layer 94 (score: 0.1172)
#     Selected layer 89 (score: 0.1047)
#     Selected layer 169 (score: 0.0928)
#     Selected layer 84 (score: 0.0896)
#     Selected layer 79 (score: 0.0795)
#     Selected layer 74 (score: 0.0726)
#   Extracted layer 74 (rank 1, score: 0.0726)
#   Extracted layer 79 (rank 2, score: 0.0795)
#   Extracted layer 84 (rank 3, score: 0.0896)
#   Extracted layer 89 (rank 4, score: 0.1047)
#   Extracted layer 94 (rank 5, score: 0.1172)
#   Extracted layer 99 (rank 6, score: 0.1247)
#   Extracted layer 104 (rank 7, score: 0.1315)
#   Extracted layer 109 (rank 8, score: 0.1371)
#   Extracted layer 114 (rank 9, score: 0.1434)
#   Extracted layer 119 (rank 10, score: 0.1489)
#   Extracted layer 124 (rank 11, score: 0.1556)
#   Extracted layer 129 (rank 12, score: 0.1635)
#   Extracted layer 134 (rank 13, score: 0.1748)
#   Extracted layer 139 (rank 14, score: 0.1859)
#   Extracted layer 144 (rank 15, score: 0.1978)
#   Extracted layer 149 (rank 16, score: 0.2092)
#   Extracted layer 154 (rank 17, score: 0.2145)
#   Extracted layer 159 (rank 18, score: 0.2089)
#   Extracted layer 164 (rank 19, score: 0.1496)
#   Extracted layer 169 (rank 20, score: 0.0928)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\029_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2350.11]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 100 (score: 0.2000)
#     Selected layer 95 (score: 0.1986)
#     Selected layer 105 (score: 0.1968)
#     Selected layer 110 (score: 0.1913)
#     Selected layer 90 (score: 0.1906)
#     Selected layer 115 (score: 0.1842)
#     Selected layer 120 (score: 0.1769)
#     Selected layer 125 (score: 0.1709)
#     Selected layer 130 (score: 0.1656)
#     Selected layer 135 (score: 0.1596)
#     Selected layer 140 (score: 0.1538)
#     Selected layer 85 (score: 0.1501)
#     Selected layer 145 (score: 0.1478)
#     Selected layer 150 (score: 0.1412)
#     Selected layer 155 (score: 0.1318)
#     Selected layer 160 (score: 0.1183)
#     Selected layer 80 (score: 0.1043)
#     Selected layer 165 (score: 0.1006)
#     Selected layer 170 (score: 0.0887)
#     Selected layer 75 (score: 0.0817)
#   Extracted layer 75 (rank 1, score: 0.0817)
#   Extracted layer 80 (rank 2, score: 0.1043)
#   Extracted layer 85 (rank 3, score: 0.1501)
#   Extracted layer 90 (rank 4, score: 0.1906)
#   Extracted layer 95 (rank 5, score: 0.1986)
#   Extracted layer 100 (rank 6, score: 0.2000)
#   Extracted layer 105 (rank 7, score: 0.1968)
#   Extracted layer 110 (rank 8, score: 0.1913)
#   Extracted layer 115 (rank 9, score: 0.1842)
#   Extracted layer 120 (rank 10, score: 0.1769)
#   Extracted layer 125 (rank 11, score: 0.1709)
#   Extracted layer 130 (rank 12, score: 0.1656)
#   Extracted layer 135 (rank 13, score: 0.1596)
#   Extracted layer 140 (rank 14, score: 0.1538)
#   Extracted layer 145 (rank 15, score: 0.1478)
#   Extracted layer 150 (rank 16, score: 0.1412)
#   Extracted layer 155 (rank 17, score: 0.1318)
#   Extracted layer 160 (rank 18, score: 0.1183)
#   Extracted layer 165 (rank 19, score: 0.1006)
#   Extracted layer 170 (rank 20, score: 0.0887)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\051_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2384.98]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 135 (score: 0.2403)
#     Selected layer 130 (score: 0.2391)
#     Selected layer 140 (score: 0.2330)
#     Selected layer 125 (score: 0.2255)
#     Selected layer 120 (score: 0.2211)
#     Selected layer 115 (score: 0.2162)
#     Selected layer 145 (score: 0.2158)
#     Selected layer 110 (score: 0.2092)
#     Selected layer 105 (score: 0.2002)
#     Selected layer 150 (score: 0.1998)
#     Selected layer 100 (score: 0.1874)
#     Selected layer 155 (score: 0.1840)
#     Selected layer 95 (score: 0.1696)
#     Selected layer 160 (score: 0.1687)
#     Selected layer 90 (score: 0.1552)
#     Selected layer 165 (score: 0.1519)
#     Selected layer 85 (score: 0.1430)
#     Selected layer 80 (score: 0.1322)
#     Selected layer 170 (score: 0.1317)
#     Selected layer 75 (score: 0.1237)
#   Extracted layer 75 (rank 1, score: 0.1237)
#   Extracted layer 80 (rank 2, score: 0.1322)
#   Extracted layer 85 (rank 3, score: 0.1430)
#   Extracted layer 90 (rank 4, score: 0.1552)
#   Extracted layer 95 (rank 5, score: 0.1696)
#   Extracted layer 100 (rank 6, score: 0.1874)
#   Extracted layer 105 (rank 7, score: 0.2002)
#   Extracted layer 110 (rank 8, score: 0.2092)
#   Extracted layer 115 (rank 9, score: 0.2162)
#   Extracted layer 120 (rank 10, score: 0.2211)
#   Extracted layer 125 (rank 11, score: 0.2255)
#   Extracted layer 130 (rank 12, score: 0.2391)
#   Extracted layer 135 (rank 13, score: 0.2403)
#   Extracted layer 140 (rank 14, score: 0.2330)
#   Extracted layer 145 (rank 15, score: 0.2158)
#   Extracted layer 150 (rank 16, score: 0.1998)
#   Extracted layer 155 (rank 17, score: 0.1840)
#   Extracted layer 160 (rank 18, score: 0.1687)
#   Extracted layer 165 (rank 19, score: 0.1519)
#   Extracted layer 170 (rank 20, score: 0.1317)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\051_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2347.87]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 98 (score: 0.2509)
#     Selected layer 93 (score: 0.2464)
#     Selected layer 103 (score: 0.2442)
#     Selected layer 108 (score: 0.2181)
#     Selected layer 88 (score: 0.2176)
#     Selected layer 113 (score: 0.2125)
#     Selected layer 118 (score: 0.2083)
#     Selected layer 83 (score: 0.2034)
#     Selected layer 123 (score: 0.2029)
#     Selected layer 128 (score: 0.1925)
#     Selected layer 78 (score: 0.1911)
#     Selected layer 73 (score: 0.1783)
#     Selected layer 133 (score: 0.1736)
#     Selected layer 68 (score: 0.1638)
#     Selected layer 138 (score: 0.1577)
#     Selected layer 63 (score: 0.1465)
#     Selected layer 143 (score: 0.1447)
#     Selected layer 148 (score: 0.1341)
#     Selected layer 58 (score: 0.1254)
#     Selected layer 153 (score: 0.1244)
#   Extracted layer 58 (rank 1, score: 0.1254)
#   Extracted layer 63 (rank 2, score: 0.1465)
#   Extracted layer 68 (rank 3, score: 0.1638)
#   Extracted layer 73 (rank 4, score: 0.1783)
#   Extracted layer 78 (rank 5, score: 0.1911)
#   Extracted layer 83 (rank 6, score: 0.2034)
#   Extracted layer 88 (rank 7, score: 0.2176)
#   Extracted layer 93 (rank 8, score: 0.2464)
#   Extracted layer 98 (rank 9, score: 0.2509)
#   Extracted layer 103 (rank 10, score: 0.2442)
#   Extracted layer 108 (rank 11, score: 0.2181)
#   Extracted layer 113 (rank 12, score: 0.2125)
#   Extracted layer 118 (rank 13, score: 0.2083)
#   Extracted layer 123 (rank 14, score: 0.2029)
#   Extracted layer 128 (rank 15, score: 0.1925)
#   Extracted layer 133 (rank 16, score: 0.1736)
#   Extracted layer 138 (rank 17, score: 0.1577)
#   Extracted layer 143 (rank 18, score: 0.1447)
#   Extracted layer 148 (rank 19, score: 0.1341)
#   Extracted layer 153 (rank 20, score: 0.1244)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\085_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2374.53]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 138 (score: 0.1603)
#     Selected layer 143 (score: 0.1579)
#     Selected layer 133 (score: 0.1560)
#     Selected layer 148 (score: 0.1525)
#     Selected layer 153 (score: 0.1455)
#     Selected layer 158 (score: 0.1368)
#     Selected layer 128 (score: 0.1300)
#     Selected layer 163 (score: 0.1265)
#     Selected layer 168 (score: 0.1122)
#     Selected layer 123 (score: 0.1069)
#     Selected layer 118 (score: 0.0947)
#     Selected layer 113 (score: 0.0862)
#     Selected layer 108 (score: 0.0784)
#     Selected layer 173 (score: 0.0727)
#     Selected layer 103 (score: 0.0699)
#     Selected layer 98 (score: 0.0613)
#     Selected layer 93 (score: 0.0523)
#     Selected layer 88 (score: 0.0442)
#     Selected layer 178 (score: 0.0417)
#     Selected layer 83 (score: 0.0373)
#   Extracted layer 83 (rank 1, score: 0.0373)
#   Extracted layer 88 (rank 2, score: 0.0442)
#   Extracted layer 93 (rank 3, score: 0.0523)
#   Extracted layer 98 (rank 4, score: 0.0613)
#   Extracted layer 103 (rank 5, score: 0.0699)
#   Extracted layer 108 (rank 6, score: 0.0784)
#   Extracted layer 113 (rank 7, score: 0.0862)
#   Extracted layer 118 (rank 8, score: 0.0947)
#   Extracted layer 123 (rank 9, score: 0.1069)
#   Extracted layer 128 (rank 10, score: 0.1300)
#   Extracted layer 133 (rank 11, score: 0.1560)
#   Extracted layer 138 (rank 12, score: 0.1603)
#   Extracted layer 143 (rank 13, score: 0.1579)
#   Extracted layer 148 (rank 14, score: 0.1525)
#   Extracted layer 153 (rank 15, score: 0.1455)
#   Extracted layer 158 (rank 16, score: 0.1368)
#   Extracted layer 163 (rank 17, score: 0.1265)
#   Extracted layer 168 (rank 18, score: 0.1122)
#   Extracted layer 173 (rank 19, score: 0.0727)
#   Extracted layer 178 (rank 20, score: 0.0417)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\085_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2409.71]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 115 (score: 0.1923)
#     Selected layer 120 (score: 0.1917)
#     Selected layer 110 (score: 0.1914)
#     Selected layer 125 (score: 0.1908)
#     Selected layer 105 (score: 0.1882)
#     Selected layer 130 (score: 0.1878)
#     Selected layer 100 (score: 0.1831)
#     Selected layer 135 (score: 0.1813)
#     Selected layer 95 (score: 0.1745)
#     Selected layer 140 (score: 0.1708)
#     Selected layer 90 (score: 0.1588)
#     Selected layer 145 (score: 0.1543)
#     Selected layer 150 (score: 0.1320)
#     Selected layer 85 (score: 0.1296)
#     Selected layer 155 (score: 0.1081)
#     Selected layer 80 (score: 0.0968)
#     Selected layer 160 (score: 0.0931)
#     Selected layer 165 (score: 0.0808)
#     Selected layer 170 (score: 0.0706)
#     Selected layer 75 (score: 0.0681)
#   Extracted layer 75 (rank 1, score: 0.0681)
#   Extracted layer 80 (rank 2, score: 0.0968)
#   Extracted layer 85 (rank 3, score: 0.1296)
#   Extracted layer 90 (rank 4, score: 0.1588)
#   Extracted layer 95 (rank 5, score: 0.1745)
#   Extracted layer 100 (rank 6, score: 0.1831)
#   Extracted layer 105 (rank 7, score: 0.1882)
#   Extracted layer 110 (rank 8, score: 0.1914)
#   Extracted layer 115 (rank 9, score: 0.1923)
#   Extracted layer 120 (rank 10, score: 0.1917)
#   Extracted layer 125 (rank 11, score: 0.1908)
#   Extracted layer 130 (rank 12, score: 0.1878)
#   Extracted layer 135 (rank 13, score: 0.1813)
#   Extracted layer 140 (rank 14, score: 0.1708)
#   Extracted layer 145 (rank 15, score: 0.1543)
#   Extracted layer 150 (rank 16, score: 0.1320)
#   Extracted layer 155 (rank 17, score: 0.1081)
#   Extracted layer 160 (rank 18, score: 0.0931)
#   Extracted layer 165 (rank 19, score: 0.0808)
#   Extracted layer 170 (rank 20, score: 0.0706)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\090_left_baseline_mirrored_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2325.14]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 156 (score: 0.2361)
#     Selected layer 161 (score: 0.2337)
#     Selected layer 151 (score: 0.2314)
#     Selected layer 146 (score: 0.2231)
#     Selected layer 166 (score: 0.2172)
#     Selected layer 141 (score: 0.2128)
#     Selected layer 136 (score: 0.2028)
#     Selected layer 131 (score: 0.1928)
#     Selected layer 126 (score: 0.1814)
#     Selected layer 121 (score: 0.1682)
#     Selected layer 171 (score: 0.1653)
#     Selected layer 116 (score: 0.1513)
#     Selected layer 176 (score: 0.1318)
#     Selected layer 111 (score: 0.1314)
#     Selected layer 106 (score: 0.1164)
#     Selected layer 181 (score: 0.1081)
#     Selected layer 101 (score: 0.1043)
#     Selected layer 96 (score: 0.0934)
#     Selected layer 186 (score: 0.0884)
#     Selected layer 91 (score: 0.0832)
#   Extracted layer 91 (rank 1, score: 0.0832)
#   Extracted layer 96 (rank 2, score: 0.0934)
#   Extracted layer 101 (rank 3, score: 0.1043)
#   Extracted layer 106 (rank 4, score: 0.1164)
#   Extracted layer 111 (rank 5, score: 0.1314)
#   Extracted layer 116 (rank 6, score: 0.1513)
#   Extracted layer 121 (rank 7, score: 0.1682)
#   Extracted layer 126 (rank 8, score: 0.1814)
#   Extracted layer 131 (rank 9, score: 0.1928)
#   Extracted layer 136 (rank 10, score: 0.2028)
#   Extracted layer 141 (rank 11, score: 0.2128)
#   Extracted layer 146 (rank 12, score: 0.2231)
#   Extracted layer 151 (rank 13, score: 0.2314)
#   Extracted layer 156 (rank 14, score: 0.2361)
#   Extracted layer 161 (rank 15, score: 0.2337)
#   Extracted layer 166 (rank 16, score: 0.2172)
#   Extracted layer 171 (rank 17, score: 0.1653)
#   Extracted layer 176 (rank 18, score: 0.1318)
#   Extracted layer 181 (rank 19, score: 0.1081)
#   Extracted layer 186 (rank 20, score: 0.0884)
#   ✅ Saved 20 layers
#
# Processing: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\3D\val\1\090_right_baseline_preprocessed.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-700.00, 2379.76]
#   Selecting 20 layers with minimum spacing of 5...
#     Selected layer 102 (score: 0.2766)
#     Selected layer 97 (score: 0.2730)
#     Selected layer 107 (score: 0.2702)
#     Selected layer 112 (score: 0.2592)
#     Selected layer 117 (score: 0.2500)
#     Selected layer 122 (score: 0.2394)
#     Selected layer 127 (score: 0.2286)
#     Selected layer 132 (score: 0.2160)
#     Selected layer 92 (score: 0.2154)
#     Selected layer 137 (score: 0.1967)
#     Selected layer 142 (score: 0.1711)
#     Selected layer 87 (score: 0.1507)
#     Selected layer 147 (score: 0.1399)
#     Selected layer 152 (score: 0.1210)
#     Selected layer 82 (score: 0.1198)
#     Selected layer 157 (score: 0.1053)
#     Selected layer 77 (score: 0.0983)
#     Selected layer 162 (score: 0.0920)
#     Selected layer 167 (score: 0.0801)
#     Selected layer 72 (score: 0.0789)
#   Extracted layer 72 (rank 1, score: 0.0789)
#   Extracted layer 77 (rank 2, score: 0.0983)
#   Extracted layer 82 (rank 3, score: 0.1198)
#   Extracted layer 87 (rank 4, score: 0.1507)
#   Extracted layer 92 (rank 5, score: 0.2154)
#   Extracted layer 97 (rank 6, score: 0.2730)
#   Extracted layer 102 (rank 7, score: 0.2766)
#   Extracted layer 107 (rank 8, score: 0.2702)
#   Extracted layer 112 (rank 9, score: 0.2592)
#   Extracted layer 117 (rank 10, score: 0.2500)
#   Extracted layer 122 (rank 11, score: 0.2394)
#   Extracted layer 127 (rank 12, score: 0.2286)
#   Extracted layer 132 (rank 13, score: 0.2160)
#   Extracted layer 137 (rank 14, score: 0.1967)
#   Extracted layer 142 (rank 15, score: 0.1711)
#   Extracted layer 147 (rank 16, score: 0.1399)
#   Extracted layer 152 (rank 17, score: 0.1210)
#   Extracted layer 157 (rank 18, score: 0.1053)
#   Extracted layer 162 (rank 19, score: 0.0920)
#   Extracted layer 167 (rank 20, score: 0.0801)
#   ✅ Saved 20 layers
# Class 1 summary: 12/12 files processed, 240 layers saved
#
# ============================================================
# 📊 PROCESSING SUMMARY
# ============================================================
# Total files processed: 144/144
# Total layers extracted: 2880
# Average layers per file: 20.0
# Output directory: D:\Kananat\Data\raw_Data_and_extra\Open access data\Baseline\Baseline_dataset\2D
#
# TEST:
#   Class 0: 8/8 files → 160 layers (avg: 20.0)
#   Class 1: 8/8 files → 160 layers (avg: 20.0)
#
# TRAIN:
#   Class 0: 52/52 files → 1040 layers (avg: 20.0)
#   Class 1: 48/48 files → 960 layers (avg: 20.0)
#
# VAL:
#   Class 0: 16/16 files → 320 layers (avg: 20.0)
#   Class 1: 12/12 files → 240 layers (avg: 20.0)
#
# ✅ Processing completed successfully!
