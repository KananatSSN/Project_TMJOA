# %%
import torch
from torch.utils.data import DataLoader
import time

# Your dataset and dataloader
train_loader = DataLoader(dataset, batch_size=32, num_workers=4)

# Benchmark
start_time = time.time()
for i, batch in enumerate(train_loader):
    if i >= 100:  # Test first 100 batches
        break
    # Just iterate, don't do anything
    pass

elapsed = time.time() - start_time
print(f"Time for 100 batches: {elapsed:.2f} seconds")
print(f"Batches per second: {100/elapsed:.2f}")
print(f"Samples per second: {100 * 32 / elapsed:.2f}")  # batch_size=32
