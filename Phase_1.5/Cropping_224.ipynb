# %%
import os
import nibabel as nib
import numpy as np

def resize_nifti(input_file, output_file, target_shape=(224, 224, 224), padding_value=-4000, background_threshold=-3000):
    # Load the NIfTI file
    img = nib.load(input_file)
    data = img.get_fdata()
    
    # Get the current shape
    current_shape = data.shape
    
    # Initialize the output array with the padding value
    output_data = np.full(target_shape, padding_value)
    
    # Dimension 0: Cropping and padding while preserving non-background voxels in [:, 0:100, :]
    if current_shape[0] > target_shape[0]:
        # Find the range of non-background voxels in [:, 0:100, :]
        non_bg_indices = np.where(data[:, 0:100, :] > background_threshold)[0]
        if len(non_bg_indices) > 0:
            start_preserve = non_bg_indices.min()
            end_preserve = non_bg_indices.max() + 1
            
            # Calculate potential crop
            total_crop = current_shape[0] - target_shape[0]
            start_crop = max(0, start_preserve - (total_crop // 2))
            end_crop = min(current_shape[0], start_crop + target_shape[0])
            
            # Adjust if end_crop removes non-background voxels
            if end_crop < end_preserve:
                end_crop = min(current_shape[0], end_preserve)
                start_crop = max(0, end_crop - target_shape[0])
            
            # Perform cropping
            dim0_data = data[start_crop:end_crop, :, :]
            
            # Pad if necessary (in case we couldn't crop fully)
            if dim0_data.shape[0] < target_shape[0]:
                pad_before = (target_shape[0] - dim0_data.shape[0]) // 2
                pad_after = target_shape[0] - dim0_data.shape[0] - pad_before
                dim0_data = np.pad(dim0_data, ((pad_before, pad_after), (0, 0), (0, 0)), 
                                   mode='constant', constant_values=padding_value)
        else:
            # If no non-background voxels, crop from center
            start = (current_shape[0] - target_shape[0]) // 2
            end = start + target_shape[0]
            dim0_data = data[start:end, :, :]
    else:
        # Pad if smaller
        pad_before = (target_shape[0] - current_shape[0]) // 2
        pad_after = target_shape[0] - current_shape[0] - pad_before
        dim0_data = np.pad(data, ((pad_before, pad_after), (0, 0), (0, 0)), 
                           mode='constant', constant_values=padding_value)

    # Dimension 1: Cropping and padding at the end
    if dim0_data.shape[1] > target_shape[1]:
        dim1_data = dim0_data[:, :target_shape[1], :]
    else:
        pad_width = target_shape[1] - dim0_data.shape[1]
        dim1_data = np.pad(dim0_data, ((0, 0), (0, pad_width), (0, 0)), 
                           mode='constant', constant_values=padding_value)

    # Dimension 2: Same as dimension 1
    if dim1_data.shape[2] > target_shape[2]:
        output_data = dim1_data[:, :, :target_shape[2]]
    else:
        pad_width = target_shape[2] - dim1_data.shape[2]
        output_data = np.pad(dim1_data, ((0, 0), (0, 0), (0, pad_width)), 
                             mode='constant', constant_values=padding_value)

    # Create a new NIfTI image with the resized data
    new_img = nib.Nifti1Image(output_data, img.affine, img.header)
    
    # Save the resized image
    nib.save(new_img, output_file)

# The process_folder function remains the same
def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.nii') or filename.endswith('.nii.gz'):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)
            resize_nifti(input_path, output_path)
            print(f"Processed: {filename}")

# Usage
input_folder = r"C:\Users\acer\Desktop\Data_0\Nii_flipped"
output_folder = r"C:\Users\acer\Desktop\Data_0\Nii_cropped_224"
process_folder(input_folder, output_folder)
# Out:
# Processed: 47-16872 L_masked_squeezed.nii.gz
# Processed: 47-16872 R_masked_squeezed_flipped.nii.gz
# Processed: 47-22136 L_masked_squeezed.nii.gz
# Processed: 47-22136 R_masked_squeezed_flipped.nii.gz
# Processed: 47-4881 L 2014_masked_squeezed.nii.gz
# Processed: 47-4881 L 2018_masked_squeezed.nii.gz
# Processed: 47-4881 R 2014_masked_squeezed_flipped.nii.gz
# Processed: 47-4881 R 2018_masked_squeezed_flipped.nii.gz
# Processed: 48-26453 L_masked_squeezed.nii.gz
# Processed: 48-5955 L_masked_squeezed.nii.gz
# Processed: 48-5955 R_masked_squeezed_flipped.nii.gz
# Processed: 49-18165 L_masked_squeezed.nii.gz
# Processed: 49-18165 R_masked_squeezed_flipped.nii.gz
# Processed: 49-3614 L_masked_squeezed.nii.gz
# Processed: 49-3614 R_masked_squeezed_flipped.nii.gz
# Processed: 50-30909 R_masked_squeezed_flipped.nii.gz
# Processed: 51-26987 L_masked_squeezed.nii.gz
# Processed: 51-26987 R_masked_squeezed_flipped.nii.gz
# Processed: 51-28114 L_masked_squeezed.nii.gz
# Processed: 51-28114 R_masked_squeezed_flipped.nii.gz
# Processed: 51-3282 L_masked_squeezed.nii.gz
# Processed: 51-3282 R_masked_squeezed_flipped.nii.gz
# Processed: 52-11116 L_masked_squeezed.nii.gz
# Processed: 52-11116 R_masked_squeezed_flipped.nii.gz
# Processed: 52-15073 L_masked_squeezed.nii.gz
# Processed: 52-15073 R_masked_squeezed_flipped.nii.gz
# Processed: 52-15242 L_masked_squeezed.nii.gz
# Processed: 52-15242 R_masked_squeezed_flipped.nii.gz
# Processed: 52-18852 L_masked_squeezed.nii.gz
# Processed: 52-18852 R_masked_squeezed_flipped.nii.gz
# Processed: 52-27708 R_masked_squeezed_flipped.nii.gz
# Processed: 52-37193 L_masked_squeezed.nii.gz
# Processed: 52-37193 R_masked_squeezed_flipped.nii.gz
# Processed: 53-12918 L_masked_squeezed.nii.gz
# Processed: 53-12918 R_masked_squeezed_flipped.nii.gz
# Processed: 53-13011 L_masked_squeezed.nii.gz
# Processed: 53-13011 R_masked_squeezed_flipped.nii.gz
# Processed: 53-22559 L_masked_squeezed.nii.gz
# Processed: 53-22559 R_masked_squeezed_flipped.nii.gz
# Processed: 53-24700 L_masked_squeezed.nii.gz
# Processed: 53-24700 R_masked_squeezed_flipped.nii.gz
# Processed: 53-26507 L_masked_squeezed.nii.gz
# Processed: 53-26507 R_masked_squeezed_flipped.nii.gz
# Processed: 54-1411 L_masked_squeezed.nii.gz
# Processed: 54-1411 R_masked_squeezed_flipped.nii.gz
# Processed: 54-17099 L_masked_squeezed.nii.gz
# Processed: 54-17099 R_masked_squeezed_flipped.nii.gz
# Processed: 54-21497 L 2014_masked_squeezed.nii.gz
# Processed: 54-21497 L 2016_masked_squeezed.nii.gz
# Processed: 54-21497 R 2014_masked_squeezed_flipped.nii.gz
# Processed: 54-21497 R 2016_masked_squeezed_flipped.nii.gz
# Processed: 54-25927 L_masked_squeezed.nii.gz
# Processed: 54-25927 R_masked_squeezed_flipped.nii.gz
# Processed: 54-50 L_masked_squeezed.nii.gz
# Processed: 54-50 R_masked_squeezed_flipped.nii.gz
# Processed: 55-15078 L_masked_squeezed.nii.gz
# Processed: 55-15078 R_masked_squeezed_flipped.nii.gz
# Processed: 55-1648 L_masked_squeezed.nii.gz
# Processed: 55-1648 R_masked_squeezed_flipped.nii.gz
# Processed: 55-17177 L 2018_masked_squeezed.nii.gz
# Processed: 55-17177 L 2020_masked_squeezed.nii.gz
# Processed: 55-17177 R 2018_masked_squeezed_flipped.nii.gz
# Processed: 55-17177 R 2020_masked_squeezed_flipped.nii.gz
# Processed: 55-27313 L_masked_squeezed.nii.gz
# Processed: 55-9422 L_masked_squeezed.nii.gz
# Processed: 55-9422 R_masked_squeezed_flipped.nii.gz
# Processed: 56-14343 L_masked_squeezed.nii.gz
# Processed: 56-18364 L_masked_squeezed.nii.gz
# Processed: 56-18364 R_masked_squeezed_flipped.nii.gz
# Processed: 56-19232 L_masked_squeezed.nii.gz
# Processed: 56-24221 L_masked_squeezed.nii.gz
# Processed: 56-24221 R_masked_squeezed_flipped.nii.gz
# Processed: 56-26683 L_masked_squeezed.nii.gz
# Processed: 56-27847 L_masked_squeezed.nii.gz
# Processed: 56-27847 R_masked_squeezed_flipped.nii.gz
# Processed: 56-9695 L_masked_squeezed.nii.gz
# Processed: 56-9695 R_masked_squeezed_flipped.nii.gz
# Processed: 57-10397 L 2015_masked_squeezed.nii.gz
# Processed: 57-10397 L 2018_masked_squeezed.nii.gz
# Processed: 57-10397 R 2015_masked_squeezed_flipped.nii.gz
# Processed: 57-10397 R 2018_masked_squeezed_flipped.nii.gz
# Processed: 57-12957 L_masked_squeezed.nii.gz
# Processed: 57-12957 R_masked_squeezed_flipped.nii.gz
# Processed: 57-16393 L_masked_squeezed.nii.gz
# Processed: 57-16393 R_masked_squeezed_flipped.nii.gz
# Processed: 57-24048 L_masked_squeezed.nii.gz
# Processed: 57-24983 L_masked_squeezed.nii.gz
# Processed: 57-24983 R_masked_squeezed_flipped.nii.gz
# Processed: 57-28760 L_masked_squeezed.nii.gz
# Processed: 57-28760 R_masked_squeezed_flipped.nii.gz
# Processed: 57-29097 L_masked_squeezed.nii.gz
# Processed: 57-29097 R_masked_squeezed_flipped.nii.gz
# Processed: 57-30513 L_masked_squeezed.nii.gz
# Processed: 57-30513 R_masked_squeezed_flipped.nii.gz
# Processed: 57-34770 L_masked_squeezed.nii.gz
# Processed: 57-34770 R_masked_squeezed_flipped.nii.gz
# Processed: 57-36050 L_masked_squeezed.nii.gz
# Processed: 57-36050 R_masked_squeezed_flipped.nii.gz
# Processed: 58-15574 L_masked_squeezed.nii.gz
# Processed: 58-15574 R_masked_squeezed_flipped.nii.gz
# Processed: 58-23240 L_masked_squeezed.nii.gz
# Processed: 58-23240 R_masked_squeezed_flipped.nii.gz
# Processed: 58-32020 R_masked_squeezed_flipped.nii.gz
# Processed: 58-38918 L_masked_squeezed.nii.gz
# Processed: 58-38918 R_masked_squeezed_flipped.nii.gz
# Processed: 58-42016 L_masked_squeezed.nii.gz
# Processed: 58-42016 R_masked_squeezed_flipped.nii.gz
# Processed: 58-43911 L_masked_squeezed.nii.gz
# Processed: 58-43911 R_masked_squeezed_flipped.nii.gz
# Processed: 58-651 L_masked_squeezed.nii.gz
# Processed: 58-651 R_masked_squeezed_flipped.nii.gz
# Processed: 58-9834 L_masked_squeezed.nii.gz
# Processed: 58-9834 R_masked_squeezed_flipped.nii.gz
# Processed: 59-14284 L_masked_squeezed.nii.gz
# Processed: 59-14284 R_masked_squeezed_flipped.nii.gz
# Processed: 59-23032 R_masked_squeezed_flipped.nii.gz
# Processed: 59-24008 L_masked_squeezed.nii.gz
# Processed: 59-27051 L_masked_squeezed.nii.gz
# Processed: 59-27051 R_masked_squeezed_flipped.nii.gz
# Processed: 59-31824 L_masked_squeezed.nii.gz
# Processed: 59-31824 R_masked_squeezed_flipped.nii.gz
# Processed: 59-33496 L_masked_squeezed.nii.gz
# Processed: 59-33496 R_masked_squeezed_flipped.nii.gz
# Processed: 59-35009 L_masked_squeezed.nii.gz
# Processed: 59-35009 R_masked_squeezed_flipped.nii.gz
# Processed: 59-36616 L_masked_squeezed.nii.gz
# Processed: 59-36616 R_masked_squeezed_flipped.nii.gz
# Processed: 59-38408 L_masked_squeezed.nii.gz
# Processed: 59-39978 L_masked_squeezed.nii.gz
# Processed: 59-39978 R_masked_squeezed_flipped.nii.gz
# Processed: 59-6269 L_masked_squeezed.nii.gz
# Processed: 60-16447 L_masked_squeezed.nii.gz
# Processed: 60-16447 R_masked_squeezed_flipped.nii.gz
# Processed: 60-21851 L_masked_squeezed.nii.gz
# Processed: 60-21851 R_masked_squeezed_flipped.nii.gz
# Processed: 60-24908 L 2017_masked_squeezed.nii.gz
# Processed: 60-24908 L 2023_masked_squeezed.nii.gz
# Processed: 60-24908 R 2017_masked_squeezed_flipped.nii.gz
# Processed: 60-24908 R 2023_masked_squeezed_flipped.nii.gz
# Processed: 60-25232 L_masked_squeezed.nii.gz
# Processed: 60-25232 R_masked_squeezed_flipped.nii.gz
# Processed: 60-2688 L_masked_squeezed.nii.gz
# Processed: 60-2688 R_masked_squeezed_flipped.nii.gz
# Processed: 60-2918 L_masked_squeezed.nii.gz
# Processed: 60-30757 R_masked_squeezed_flipped.nii.gz
# Processed: 60-33107 L_masked_squeezed.nii.gz
# Processed: 60-33107 R_masked_squeezed_flipped.nii.gz
# Processed: 60-33597 L 2017_masked_squeezed.nii.gz
# Processed: 60-33597 L 2019 03 11_masked_squeezed.nii.gz
# Processed: 60-33597 L 2019 09 02_masked_squeezed.nii.gz
# Processed: 60-34373 L 2017_masked_squeezed.nii.gz
# Processed: 60-34373 L 2019_masked_squeezed.nii.gz
# Processed: 60-34373 R 2017_masked_squeezed_flipped.nii.gz
# Processed: 60-34373 R 2019_masked_squeezed_flipped.nii.gz
# Processed: 60-38868 R_masked_squeezed_flipped.nii.gz
# Processed: 60-39505 L_masked_squeezed.nii.gz
# Processed: 60-39505 R_masked_squeezed_flipped.nii.gz
# Processed: 60-4194 L_masked_squeezed.nii.gz
# Processed: 60-4194 R_masked_squeezed_flipped.nii.gz
# Processed: 60-700759 L_masked_squeezed.nii.gz
# Processed: 60-700759 R_masked_squeezed_flipped.nii.gz
# Processed: 60-700919 L_masked_squeezed.nii.gz
# Processed: 60-700919 R_masked_squeezed_flipped.nii.gz
# Processed: 60-701005 L 2017_masked_squeezed.nii.gz
# Processed: 60-701005 L 2021_masked_squeezed.nii.gz
# Processed: 60-701005 R 2017_masked_squeezed_flipped.nii.gz
# Processed: 60-701005 R 2021_masked_squeezed_flipped.nii.gz
# Processed: 60-701042 L_masked_squeezed.nii.gz
# Processed: 60-701042 R_masked_squeezed_flipped.nii.gz
# Processed: 60-701142 L_masked_squeezed.nii.gz
# Processed: 60-701142 R_masked_squeezed_flipped.nii.gz
# Processed: 60-701166 L_masked_squeezed.nii.gz
# Processed: 60-701166 R_masked_squeezed_flipped.nii.gz
# Processed: 60-701195 L_masked_squeezed.nii.gz
# Processed: 60-7166 L_masked_squeezed.nii.gz
# Processed: 60-7166 R_masked_squeezed_flipped.nii.gz
# Processed: 60-9722 L_masked_squeezed.nii.gz
# Processed: 60-9722 R_masked_squeezed_flipped.nii.gz
# Processed: 61-13344 L_masked_squeezed.nii.gz
# Processed: 61-13344 R_masked_squeezed_flipped.nii.gz
# Processed: 61-14198 L_masked_squeezed.nii.gz
# Processed: 61-14198 R_masked_squeezed_flipped.nii.gz
# Processed: 61-16015 L_masked_squeezed.nii.gz
# Processed: 61-16015 R 2022_masked_squeezed_flipped.nii.gz
# Processed: 61-18860 L_masked_squeezed.nii.gz
# Processed: 61-18860 R_masked_squeezed_flipped.nii.gz
# Processed: 61-20310 L_masked_squeezed.nii.gz
# Processed: 61-20310 R_masked_squeezed_flipped.nii.gz
# Processed: 61-21027 L_masked_squeezed.nii.gz
# Processed: 61-21027 R_masked_squeezed_flipped.nii.gz
# Processed: 61-21564 L_masked_squeezed.nii.gz
# Processed: 61-21564 R_masked_squeezed_flipped.nii.gz
# Processed: 61-25724 L_masked_squeezed.nii.gz
# Processed: 61-25724 R_masked_squeezed_flipped.nii.gz
# Processed: 61-32062 L_masked_squeezed.nii.gz
# Processed: 61-32062 R_masked_squeezed_flipped.nii.gz
# Processed: 61-33141 L_masked_squeezed.nii.gz
# Processed: 61-33141 R_masked_squeezed_flipped.nii.gz
# Processed: 61-34247 L_masked_squeezed.nii.gz
# Processed: 61-34247 R_masked_squeezed_flipped.nii.gz
# Processed: 61-5225 L_masked_squeezed.nii.gz
# Processed: 61-5586 L_masked_squeezed.nii.gz
# Processed: 61-5586 R_masked_squeezed_flipped.nii.gz
# Processed: 61-6974 L_masked_squeezed.nii.gz
# Processed: 61-6974 R_masked_squeezed_flipped.nii.gz
# Processed: 61-700034 L_masked_squeezed.nii.gz
# Processed: 61-700034 R_masked_squeezed_flipped.nii.gz
# Processed: 61-700101 L_masked_squeezed.nii.gz
# Processed: 61-700101 R_masked_squeezed_flipped.nii.gz
# Processed: 61-700554 L_masked_squeezed.nii.gz
# Processed: 61-700554 R_masked_squeezed_flipped.nii.gz
# Processed: 61-700847 L_masked_squeezed.nii.gz
# Processed: 61-700847 R_masked_squeezed_flipped.nii.gz
# Processed: 61-701246 L_masked_squeezed.nii.gz
# Processed: 61-701246 R_masked_squeezed_flipped.nii.gz
# Processed: 62-12734 R_masked_squeezed_flipped.nii.gz
# Processed: 62-12908 R_masked_squeezed_flipped.nii.gz
# Processed: 62-13410 L_masked_squeezed.nii.gz
# Processed: 62-13410 R_masked_squeezed_flipped.nii.gz
# Processed: 62-1401 L_masked_squeezed.nii.gz
# Processed: 62-14053 L_masked_squeezed.nii.gz
# Processed: 62-14053 R_masked_squeezed_flipped.nii.gz
# Processed: 62-21678 L_masked_squeezed.nii.gz
# Processed: 62-2274 R 2019_masked_squeezed_flipped.nii.gz
# Processed: 62-2274 R 2021_masked_squeezed_flipped.nii.gz
# Processed: 62-23102 L_masked_squeezed.nii.gz
# Processed: 62-23102 R_masked_squeezed_flipped.nii.gz
# Processed: 62-24379 R_masked_squeezed_flipped.nii.gz
# Processed: 62-24749 L_masked_squeezed.nii.gz
# Processed: 62-24749 R_masked_squeezed_flipped.nii.gz
# Processed: 62-25311 R_masked_squeezed_flipped.nii.gz
# Processed: 62-25333 L_masked_squeezed.nii.gz
# Processed: 62-25333 R_masked_squeezed_flipped.nii.gz
# Processed: 62-26639 L_masked_squeezed.nii.gz
# Processed: 62-26639 R_masked_squeezed_flipped.nii.gz
# Processed: 62-27556 L_masked_squeezed.nii.gz
# Processed: 62-27556 R_masked_squeezed_flipped.nii.gz
# Processed: 62-30049 L_masked_squeezed.nii.gz
# Processed: 62-30049 R_masked_squeezed_flipped.nii.gz
# Processed: 62-330 L_masked_squeezed.nii.gz
# Processed: 62-330 R_masked_squeezed_flipped.nii.gz
# Processed: 62-34626 R_masked_squeezed_flipped.nii.gz
# Processed: 62-435 L_masked_squeezed.nii.gz
# Processed: 62-435 R_masked_squeezed_flipped.nii.gz
# Processed: 62-700605 R_masked_squeezed_flipped.nii.gz
# Processed: 62-700851 L_masked_squeezed.nii.gz
# Processed: 62-700851 R_masked_squeezed_flipped.nii.gz
# Processed: 62-701148 L_masked_squeezed.nii.gz
# Processed: 62-701148 R_masked_squeezed_flipped.nii.gz
# Processed: 62-701248 R_masked_squeezed_flipped.nii.gz
# Processed: 62-701261 L_masked_squeezed.nii.gz
# Processed: 62-701261 R_masked_squeezed_flipped.nii.gz
# Processed: 62-7533 L 2021_masked_squeezed.nii.gz
# Processed: 62-7533 R 2020_masked_squeezed_flipped.nii.gz
# Processed: 62-7533 R 2021_masked_squeezed_flipped.nii.gz
# Processed: 62-8585 L_masked_squeezed.nii.gz
# Processed: 62-8585 R_masked_squeezed_flipped.nii.gz
# Processed: 63-12252 L_masked_squeezed.nii.gz
# Processed: 63-12252 R_masked_squeezed_flipped.nii.gz
# Processed: 63-1330 L_masked_squeezed.nii.gz
# Processed: 63-1330 R_masked_squeezed_flipped.nii.gz
# Processed: 63-15359 L_masked_squeezed.nii.gz
# Processed: 63-15359 R_masked_squeezed_flipped.nii.gz
# Processed: 63-17862 L_masked_squeezed.nii.gz
# Processed: 63-17862 R_masked_squeezed_flipped.nii.gz
# Processed: 63-17877 L_masked_squeezed.nii.gz
# Processed: 63-17877 R_masked_squeezed_flipped.nii.gz
# Processed: 63-17957 L_masked_squeezed.nii.gz
# Processed: 63-17957 R_masked_squeezed_flipped.nii.gz
# Processed: 63-20205 L_masked_squeezed.nii.gz
# Processed: 63-20205 R_masked_squeezed_flipped.nii.gz
# Processed: 63-2829 L_masked_squeezed.nii.gz
# Processed: 63-700223 L_masked_squeezed.nii.gz
# Processed: 63-700223 R_masked_squeezed_flipped.nii.gz
# Processed: 63-700385 L_masked_squeezed.nii.gz
# Processed: 63-700385 R_masked_squeezed_flipped.nii.gz
# Processed: 63-700449 L_masked_squeezed.nii.gz
# Processed: 63-700449 R_masked_squeezed_flipped.nii.gz
# Processed: 63-7894 L_masked_squeezed.nii.gz
# Processed: 63-7894 R_masked_squeezed_flipped.nii.gz
# Processed: 64-10402 L 2023 02 08_masked_squeezed.nii.gz
# Processed: 64-10402 R 2023 02 08_masked_squeezed_flipped.nii.gz
# Processed: 64-10402 R 2023 11 21_masked_squeezed_flipped.nii.gz
# Processed: 64-10902 L_masked_squeezed.nii.gz
# Processed: 64-10902 R_masked_squeezed_flipped.nii.gz
# Processed: 64-3795 L_masked_squeezed.nii.gz
# Processed: 64-6935 L_masked_squeezed.nii.gz
# Processed: 64-6935 R_masked_squeezed_flipped.nii.gz
# Processed: 64-700092 L_masked_squeezed.nii.gz
# Processed: 64-700178 L_masked_squeezed.nii.gz
# Processed: 64-700383 L_masked_squeezed.nii.gz
# Processed: 64-7881 L_masked_squeezed.nii.gz
# Processed: 64-7881 R_masked_squeezed_flipped.nii.gz
# Processed: 64-7936 L_masked_squeezed.nii.gz
# Processed: 64-7936 R_masked_squeezed_flipped.nii.gz
# Processed: 64-7980 L_masked_squeezed.nii.gz
# Processed: 64-7980 R_masked_squeezed_flipped.nii.gz
# Processed: 64-8619 L 2021_masked_squeezed.nii.gz
# Processed: 64-8619 L 2022_masked_squeezed.nii.gz
# Processed: 64-8619 R 2021_masked_squeezed_flipped.nii.gz
# Processed: 65-11496 L_masked_squeezed.nii.gz
# Processed: 65-14582 R 2022_masked_squeezed_flipped.nii.gz
# Processed: 65-14582 R 2023_masked_squeezed_flipped.nii.gz
# Processed: 65-14920 L_masked_squeezed.nii.gz
# Processed: 65-14920 R_masked_squeezed_flipped.nii.gz
# Processed: 65-1579 L_masked_squeezed.nii.gz
# Processed: 65-1579 R_masked_squeezed_flipped.nii.gz
# Processed: 65-20101 L_masked_squeezed.nii.gz
# Processed: 65-20101 R_masked_squeezed_flipped.nii.gz
# Processed: 65-20231 L_masked_squeezed.nii.gz
# Processed: 65-20231 R_masked_squeezed_flipped.nii.gz
# Processed: 65-23331 L_masked_squeezed.nii.gz
# Processed: 65-23331 R_masked_squeezed_flipped.nii.gz
# Processed: 65-24090 L 2023 11 17_masked_squeezed.nii.gz
# Processed: 65-24090 R 2023 11 17_masked_squeezed_flipped.nii.gz
# Processed: 65-24090 R 2023 11 29_masked_squeezed_flipped.nii.gz
# Processed: 65-2425 L 2022 02 17_masked_squeezed.nii.gz
# Processed: 65-2425 L 2022 10 03_masked_squeezed.nii.gz
# Processed: 65-2425 L 2023_masked_squeezed.nii.gz
# Processed: 65-2425 R 2022 02 17_masked_squeezed_flipped.nii.gz
# Processed: 65-2425 R 2022 10 03_masked_squeezed_flipped.nii.gz
# Processed: 65-2425 R 2023_masked_squeezed_flipped.nii.gz
# Processed: 65-25886 R_masked_squeezed_flipped.nii.gz
# Processed: 65-26867 L_masked_squeezed.nii.gz
# Processed: 65-26867 R_masked_squeezed_flipped.nii.gz
# Processed: 65-27050 R_masked_squeezed_flipped.nii.gz
# Processed: 65-27889 L_masked_squeezed.nii.gz
# Processed: 65-4483 L_masked_squeezed.nii.gz
# Processed: 65-4998 L_masked_squeezed.nii.gz
# Processed: 65-4998 R_masked_squeezed_flipped.nii.gz
# Processed: 65-700003 L_masked_squeezed.nii.gz
# Processed: 65-700003 R_masked_squeezed_flipped.nii.gz
# Processed: 65-700131 L_masked_squeezed.nii.gz
# Processed: 65-700131 R_masked_squeezed_flipped.nii.gz
# Processed: 65-700197 L_masked_squeezed.nii.gz
# Processed: 65-700197 R_masked_squeezed_flipped.nii.gz
# Processed: 65-700405 L_masked_squeezed.nii.gz
# Processed: 65-700405 R_masked_squeezed_flipped.nii.gz
# Processed: 65-8582 R_masked_squeezed_flipped.nii.gz
# Processed: 66-12948 R_masked_squeezed_flipped.nii.gz
# Processed: 66-13889 R_masked_squeezed_flipped.nii.gz
# Processed: 66-18213 L_masked_squeezed.nii.gz
# Processed: 66-18213 R_masked_squeezed_flipped.nii.gz
# Processed: 66-20679 L_masked_squeezed.nii.gz
# Processed: 66-21702 L_masked_squeezed.nii.gz
# Processed: 66-2177 L_masked_squeezed.nii.gz
# Processed: 66-2177 R_masked_squeezed_flipped.nii.gz
# Processed: 66-218 L 2023 06 16_masked_squeezed.nii.gz
# Processed: 66-218 R 2023 06 16_masked_squeezed_flipped.nii.gz
# Processed: 66-23248 L 2023 11 29_masked_squeezed.nii.gz
# Processed: 66-23248 R 2023 11 29_masked_squeezed_flipped.nii.gz
# Processed: 66-4559 L_masked_squeezed.nii.gz
# Processed: 66-4559 R_masked_squeezed_flipped.nii.gz
# Processed: 66-59 L_masked_squeezed.nii.gz
# Processed: 66-59 R_masked_squeezed_flipped.nii.gz
# Processed: 66-700261 L_masked_squeezed.nii.gz
# Processed: 66-700261 R_masked_squeezed_flipped.nii.gz
# Processed: 66-700314 L_masked_squeezed.nii.gz
# Processed: 66-700314 R_masked_squeezed_flipped.nii.gz
# Processed: 66-700362 L_masked_squeezed.nii.gz
# Processed: 66-700362 R_masked_squeezed_flipped.nii.gz
# Processed: 66-700404 L_masked_squeezed.nii.gz
# Processed: 66-700404 R_masked_squeezed_flipped.nii.gz
# Processed: 66-700681 L_masked_squeezed.nii.gz
# Processed: 66-700681 R_masked_squeezed_flipped.nii.gz
