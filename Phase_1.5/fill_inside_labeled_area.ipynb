# %%
import nibabel as nib
from matplotlib import pyplot as plt
import numpy as np
import cv2
from skimage.segmentation import expand_labels

# %%
def array2cv(array) :
    slice = (array * 255).astype(np.uint8)
    return slice

# %%
def fillhole(img):

    contours, _ = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) == 0:
        return cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    else:
        # Assuming the smallest contour is the hole (this might need adjustment based on your image)
        contours = sorted(contours, key=cv2.contourArea)
        hole = contours[0]  # Change the index based on your specific image

        # Create a color version of the binary image if you want to fill the hole in color or visualize
        color_image = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

        # Draw the contour to fill the hole
        cv2.drawContours(color_image, [hole], 0, (255, 255, 255), -1)
    
    return color_image

# %%
def cv2array(cv_img):
    gray_image = cv2.cvtColor(cv_img, cv2.COLOR_BGR2GRAY)
    _, binary_image_final = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
    return binary_image_final

# %%
import os

input_folder = r"C:\Users\acer\Desktop\Data_Prep_1\labelsTr"
output_folder = r"C:\Users\acer\Desktop\Data_Prep_1\labelsTr\Output"

nii_count = len([filename for filename in os.listdir(input_folder) if filename.endswith('.nii.gz')])
print(f"There are {nii_count} .nii.gz files in the {input_folder}")

progress_count = 0

files = sorted(os.listdir(input_folder))

for input_name in files :
    if input_name.endswith('.nii.gz'):
        progress_count += 1
        print(f"[Processing {progress_count} out of {nii_count}]")
        
        input_path = os.path.join(input_folder, input_name)

        output_name = os.path.basename(input_path)
        output_name, _ = os.path.splitext(output_name)
        output_name, _ = os.path.splitext(output_name)
        output_name = f"{output_name}_filled.nii.gz"

        output_path = os.path.join(output_folder, output_name)

        img = nib.load(input_path)
        data = img.get_fdata()
        new_data = np.zeros_like(data)

        for slice_number in range(new_data.shape[2]):
            slice = data[:,:,slice_number]
            slice = expand_labels(slice, distance=5)
            cv_img = array2cv(slice)
            filled_cv_img = fillhole(cv_img)
            array_img = cv2array(filled_cv_img)
            new_data[:,:,slice_number] = array_img

        result_img = nib.Nifti1Image(new_data, img.affine, img.header)
        nib.save(result_img, output_path)
# Out:
# There are 375 .nii.gz files in the C:\Users\acer\Desktop\Data_Prep_1\labelsTr
# [Processing 1 out of 375]
# [Processing 2 out of 375]
# [Processing 3 out of 375]
# [Processing 4 out of 375]
# [Processing 5 out of 375]
# [Processing 6 out of 375]
# [Processing 7 out of 375]
# [Processing 8 out of 375]
# [Processing 9 out of 375]
# [Processing 10 out of 375]
# [Processing 11 out of 375]
# [Processing 12 out of 375]
# [Processing 13 out of 375]
# [Processing 14 out of 375]
# [Processing 15 out of 375]
# [Processing 16 out of 375]
# [Processing 17 out of 375]
# [Processing 18 out of 375]
# [Processing 19 out of 375]
# [Processing 20 out of 375]
# [Processing 21 out of 375]
# [Processing 22 out of 375]
# [Processing 23 out of 375]
# [Processing 24 out of 375]
# [Processing 25 out of 375]
# [Processing 26 out of 375]
# [Processing 27 out of 375]
# [Processing 28 out of 375]
# [Processing 29 out of 375]
# [Processing 30 out of 375]
# [Processing 31 out of 375]
# [Processing 32 out of 375]
# [Processing 33 out of 375]
# [Processing 34 out of 375]
# [Processing 35 out of 375]
# [Processing 36 out of 375]
# [Processing 37 out of 375]
# [Processing 38 out of 375]
# [Processing 39 out of 375]
# [Processing 40 out of 375]
# [Processing 41 out of 375]
# [Processing 42 out of 375]
# [Processing 43 out of 375]
# [Processing 282 out of 375]
# [Processing 283 out of 375]
# [Processing 284 out of 375]
# [Processing 285 out of 375]
# [Processing 286 out of 375]
# [Processing 287 out of 375]
# [Processing 288 out of 375]
# [Processing 289 out of 375]
# [Processing 290 out of 375]
# [Processing 291 out of 375]
# [Processing 292 out of 375]
# [Processing 293 out of 375]
# [Processing 294 out of 375]
# [Processing 295 out of 375]
# [Processing 296 out of 375]
# [Processing 297 out of 375]
# [Processing 298 out of 375]
# [Processing 299 out of 375]
# [Processing 300 out of 375]
# [Processing 301 out of 375]
# [Processing 302 out of 375]
# [Processing 303 out of 375]
# [Processing 304 out of 375]
# [Processing 305 out of 375]
# [Processing 306 out of 375]
# [Processing 307 out of 375]
# [Processing 308 out of 375]
# [Processing 309 out of 375]
# [Processing 310 out of 375]
# [Processing 311 out of 375]
# [Processing 312 out of 375]
# [Processing 313 out of 375]
# [Processing 314 out of 375]
# [Processing 315 out of 375]
# [Processing 316 out of 375]
# [Processing 317 out of 375]
# [Processing 318 out of 375]
# [Processing 319 out of 375]
# [Processing 320 out of 375]
# [Processing 321 out of 375]
# [Processing 322 out of 375]
# [Processing 323 out of 375]
# [Processing 324 out of 375]
# [Processing 325 out of 375]
# [Processing 326 out of 375]
# [Processing 327 out of 375]
# [Processing 328 out of 375]
# [Processing 329 out of 375]
# [Processing 330 out of 375]
# [Processing 331 out of 375]
# [Processing 332 out of 375]
# [Processing 333 out of 375]
# [Processing 334 out of 375]
# [Processing 335 out of 375]
# [Processing 336 out of 375]
# [Processing 337 out of 375]
# [Processing 338 out of 375]
# [Processing 339 out of 375]
# [Processing 340 out of 375]
# [Processing 341 out of 375]
# [Processing 342 out of 375]
# [Processing 343 out of 375]
# [Processing 344 out of 375]
# [Processing 345 out of 375]
# [Processing 346 out of 375]
# [Processing 347 out of 375]
# [Processing 348 out of 375]
# [Processing 349 out of 375]
# [Processing 350 out of 375]
# [Processing 351 out of 375]
# [Processing 352 out of 375]
# [Processing 353 out of 375]
# [Processing 354 out of 375]
# [Processing 355 out of 375]
# [Processing 356 out of 375]
# [Processing 357 out of 375]
# [Processing 358 out of 375]
# [Processing 359 out of 375]
# [Processing 360 out of 375]
# [Processing 361 out of 375]
# [Processing 362 out of 375]
# [Processing 363 out of 375]
# [Processing 364 out of 375]
# [Processing 365 out of 375]
# [Processing 366 out of 375]
# [Processing 367 out of 375]
# [Processing 368 out of 375]
# [Processing 369 out of 375]
# [Processing 370 out of 375]
# [Processing 371 out of 375]
# [Processing 372 out of 375]
# [Processing 373 out of 375]
# [Processing 374 out of 375]
# [Processing 375 out of 375]

# %%
# Result Example

file_path = r"C:\Users\acer\Desktop\Data_Prep_1\labelsTr\5450_2016_02_26_L_segmented.nii.gz"
img = nib.load(file_path)
data = img.get_fdata()
print(data.shape)

slice_number = 260

slice = data[:,:,slice_number]

#expand the edge of the segmentation a little
slice = expand_labels(slice, distance=5)

#fill the hole if there are holes
cv_img = array2cv(slice)
filled_cv_img = fillhole(cv_img)
array_img = cv2array(filled_cv_img)

#display result
f, axarr = plt.subplots(1,2)
axarr[0].set_title("Input")
axarr[0].imshow(data[:,:,slice_number], cmap = 'grey')
axarr[1].set_title("Output")
axarr[1].imshow(array_img, cmap = 'grey')
# Out:
# (417, 477, 481)
