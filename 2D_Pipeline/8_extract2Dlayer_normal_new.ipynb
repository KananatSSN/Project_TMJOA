# %%
import os
import argparse
import numpy as np
import nibabel as nib
from PIL import Image
from pathlib import Path
import logging

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def normalize_voxel_values(data, background_value=-250):
    """
    Normalize voxel values from [-250, max_value] to [0, 255]
    
    Args:
        data: 3D numpy array
        background_value: Background value (default: -250)
    
    Returns:
        Normalized data as uint8
    """
    # Clip values to ensure minimum is background_value
    data = np.clip(data, background_value, None)
    
    # Get min and max values
    min_val = data.min()
    max_val = data.max()
    
    if max_val == min_val:
        # Handle case where all values are the same
        return np.zeros_like(data, dtype=np.uint8)
    
    # Normalize to [0, 255]
    normalized = ((data - min_val) / (max_val - min_val)) * 255
    return normalized.astype(np.uint8)

def find_max_non_background_layer(data, background_value=-250):
    """
    Find the layer (along axis 0) with maximum number of non-background voxels
    
    Args:
        data: 3D numpy array
        background_value: Background value to exclude
    
    Returns:
        Layer index with maximum non-background voxels
    """
    non_background_counts = []
    
    for i in range(data.shape[0]):
        layer = data[i, :, :]
        non_background_count = np.sum(layer != background_value)
        non_background_counts.append(non_background_count)
    
    max_layer_idx = np.argmax(non_background_counts)
    logger.info(f"Max non-background layer: {max_layer_idx} with {non_background_counts[max_layer_idx]} non-background voxels")
    
    return max_layer_idx

def extract_layers(data, center_layer, n, background_value=-250):
    """
    Extract layers: center, center±n, center±2n
    
    Args:
        data: 3D numpy array
        center_layer: Index of the center layer
        n: Distance parameter
        background_value: Background value
    
    Returns:
        Dictionary of layer indices and their corresponding 2D arrays
    """
    layers = {}
    max_layer = data.shape[0] - 1
    
    # Define layer indices to extract
    layer_offsets = [0, n, 2*n, -n, -2*n]
    layer_names = ['center', 'plus_n', 'plus_2n', 'minus_n', 'minus_2n']
    
    for offset, name in zip(layer_offsets, layer_names):
        layer_idx = center_layer + offset
        
        # Check bounds
        if 0 <= layer_idx <= max_layer:
            layers[f"{name}_{layer_idx:03d}"] = data[layer_idx, :, :]
            logger.info(f"Extracted layer {layer_idx} ({name})")
        else:
            logger.warning(f"Layer {layer_idx} ({name}) is out of bounds [0, {max_layer}], skipping")
    
    return layers

def save_layer_as_png(layer_data, output_path):
    """
    Save 2D layer as PNG with 3 identical channels
    
    Args:
        layer_data: 2D numpy array (normalized to 0-255)
        output_path: Output file path
    """
    # Create 3-channel image (RGB) with identical values
    rgb_image = np.stack([layer_data, layer_data, layer_data], axis=-1)
    
    # Convert to PIL Image and save
    pil_image = Image.fromarray(rgb_image, mode='RGB')
    pil_image.save(output_path)

def process_nifti_file(nifti_path, output_dir, n, background_value=-250):
    """
    Process a single NIfTI file and extract layers
    
    Args:
        nifti_path: Path to .nii.gz file
        output_dir: Output directory for this file's layers
        n: Distance parameter
        background_value: Background value
    """
    try:
        logger.info(f"Processing: {nifti_path}")
        
        # Load NIfTI file
        nifti_img = nib.load(nifti_path)
        data = nifti_img.get_fdata()
        
        logger.info(f"Data shape: {data.shape}")
        logger.info(f"Data range: [{data.min():.2f}, {data.max():.2f}]")
        
        # Find layer with maximum non-background voxels
        center_layer = find_max_non_background_layer(data, background_value)
        
        # Extract layers
        layers = extract_layers(data, center_layer, n, background_value)
        
        # Process and save each layer
        filename_base = Path(nifti_path).stem.replace('.nii', '')  # Remove .nii.gz extension
        
        for layer_name, layer_data in layers.items():
            # Normalize the layer
            normalized_layer = normalize_voxel_values(layer_data, background_value)
            
            # Create output filename
            output_filename = f"{filename_base}_{layer_name}.png"
            output_path = os.path.join(output_dir, output_filename)
            
            # Save as PNG
            save_layer_as_png(normalized_layer, output_path)
            logger.info(f"Saved: {output_path}")
    
    except Exception as e:
        logger.error(f"Error processing {nifti_path}: {str(e)}")

def process_dataset(input_dataset_dir, output_dataset_dir, n, background_value=-250):
    """
    Process entire dataset
    
    Args:
        input_dataset_dir: Input dataset directory
        output_dataset_dir: Output dataset directory
        n: Distance parameter
        background_value: Background value
    """
    input_path = Path(input_dataset_dir)
    output_path = Path(output_dataset_dir)
    
    # Iterate through train/val/test folders
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            logger.info(f"Processing split: {split_dir.name}")
            
            # Iterate through class folders (0, 1)
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    logger.info(f"Processing class: {class_dir.name}")
                    
                    # Create output directory
                    output_class_dir = output_path / split_dir.name / class_dir.name
                    output_class_dir.mkdir(parents=True, exist_ok=True)
                    
                    # Process all .nii.gz files in this directory
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    logger.info(f"Found {len(nifti_files)} NIfTI files")
                    
                    for nifti_file in nifti_files:
                        process_nifti_file(nifti_file, output_class_dir, n, background_value)

# %% [markdown]
# # Extract layer around the most informative layer

# %%
input_dataset = r'C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D'  # Replace with actual input dataset path
output_dataset = r'C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_2D'  # Replace with actual output dataset path
n = 5  # Replace with actual distance parameter (n)
background_value = -250

logger.info(f"Input dataset: {input_dataset}")
logger.info(f"Output dataset: {output_dataset}")
logger.info(f"Distance parameter (n): {n}")
logger.info(f"Background value: {background_value}")

# Validate input directory
if not os.path.exists(input_dataset):
    logger.error(f"Input dataset directory does not exist: {input_dataset}")

# Process the dataset
process_dataset(input_dataset, output_dataset, n, background_value)

logger.info("Processing completed!")

# %% [markdown]
# # Extract all layers with more than n percent non background

# %%
# 3D NIfTI to 2D PNG Layer Extractor - Top N Informative Layers
# Extracts the N most informative layers with minimum spacing between them

import os
import numpy as np
import nibabel as nib
from PIL import Image
from pathlib import Path
import logging

# Set up logging for Jupyter
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# =============================================================================
# CONFIGURATION - Modify these parameters
# =============================================================================

# Dataset paths
INPUT_DATASET_DIR = r'C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D'  # Update this path
OUTPUT_DATASET_DIR = r'C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_2D'  # Update this path

# Processing parameters
N_LAYERS = 10          # Number of most informative layers to extract
MIN_SPACING = 5       # Minimum spacing between selected layers (k parameter)
BACKGROUND_VALUE = -250   # Background value to exclude

print("Configuration:")
print(f"Input dataset: {INPUT_DATASET_DIR}")
print(f"Output dataset: {OUTPUT_DATASET_DIR}")
print(f"Number of layers to extract: {N_LAYERS}")
print(f"Minimum spacing between layers: {MIN_SPACING}")
print(f"Background value: {BACKGROUND_VALUE}")

# =============================================================================
# HELPER FUNCTIONS
# =============================================================================

def normalize_voxel_values(data, background_value=-250):
    """
    Normalize voxel values from [-250, max_value] to [0, 255]
    
    Args:
        data: 3D numpy array
        background_value: Background value (default: -250)
    
    Returns:
        Normalized data as uint8
    """
    # Clip values to ensure minimum is background_value
    data = np.clip(data, background_value, None)
    
    # Get min and max values
    min_val = data.min()
    max_val = data.max()
    
    if max_val == min_val:
        # Handle case where all values are the same
        return np.zeros_like(data, dtype=np.uint8)
    
    # Normalize to [0, 255]
    normalized = ((data - min_val) / (max_val - min_val)) * 255
    return normalized.astype(np.uint8)

def calculate_layer_informativeness(data, background_value=-250):
    """
    Calculate informativeness score for each layer
    Uses non-background ratio as the primary metric
    
    Args:
        data: 3D numpy array
        background_value: Background value to exclude
    
    Returns:
        List of tuples: (layer_index, informativeness_score)
    """
    layer_scores = []
    total_voxels_per_layer = data.shape[1] * data.shape[2]
    
    for i in range(data.shape[0]):
        layer = data[i, :, :]
        
        # Calculate non-background ratio
        non_background_count = np.sum(layer > background_value)
        non_background_ratio = non_background_count / total_voxels_per_layer
        
        # Additional informativeness metrics can be added here:
        # - Variance of non-background voxels
        # - Edge content
        # - Texture measures
        
        # For now, using non-background ratio as informativeness score
        informativeness_score = non_background_ratio
        
        layer_scores.append((i, informativeness_score))
    
    return layer_scores

def select_top_layers_with_spacing(layer_scores, n_layers, min_spacing):
    """
    Select top N layers ensuring minimum spacing between them
    
    Args:
        layer_scores: List of tuples (layer_index, score)
        n_layers: Number of layers to select
        min_spacing: Minimum spacing between selected layers
    
    Returns:
        List of tuples: (layer_index, score) for selected layers
    """
    # Sort by score in descending order
    sorted_layers = sorted(layer_scores, key=lambda x: x[1], reverse=True)
    
    selected_layers = []
    used_indices = set()
    
    print(f"  Selecting {n_layers} layers with minimum spacing of {min_spacing}...")
    
    for layer_idx, score in sorted_layers:
        # Check if this layer conflicts with already selected layers
        conflict = False
        for selected_idx, _ in selected_layers:
            if abs(layer_idx - selected_idx) < min_spacing:
                conflict = True
                break
        
        if not conflict:
            selected_layers.append((layer_idx, score))
            used_indices.add(layer_idx)
            print(f"    Selected layer {layer_idx} (score: {score:.4f})")
            
            if len(selected_layers) >= n_layers:
                break
    
    # Sort selected layers by index for consistent naming
    selected_layers.sort(key=lambda x: x[0])
    
    if len(selected_layers) < n_layers:
        print(f"    ⚠️ Only found {len(selected_layers)} layers that satisfy spacing constraint")
    
    return selected_layers

def extract_selected_layers(data, selected_layers):
    """
    Extract the selected layers
    
    Args:
        data: 3D numpy array
        selected_layers: List of tuples (layer_index, score)
    
    Returns:
        Dictionary of layer indices and their corresponding 2D arrays
    """
    layers = {}
    
    for i, (layer_idx, score) in enumerate(selected_layers):
        layer_key = f"layer_{layer_idx:03d}_rank_{i+1:02d}_score_{score:.3f}"
        layers[layer_key] = data[layer_idx, :, :]
        print(f"  Extracted layer {layer_idx} (rank {i+1}, score: {score:.4f})")
    
    return layers

def save_layer_as_png(layer_data, output_path):
    """
    Save 2D layer as PNG with 3 identical channels
    
    Args:
        layer_data: 2D numpy array (normalized to 0-255)
        output_path: Output file path
    """
    # Create 3-channel image (RGB) with identical values
    rgb_image = np.stack([layer_data, layer_data, layer_data], axis=-1)
    
    # Convert to PIL Image and save
    pil_image = Image.fromarray(rgb_image, mode='RGB')
    pil_image.save(output_path)

def process_nifti_file(nifti_path, output_dir, n_layers, min_spacing, background_value=-250):
    """
    Process a single NIfTI file and extract top N informative layers with spacing
    
    Args:
        nifti_path: Path to .nii.gz file
        output_dir: Output directory for this file's layers
        n_layers: Number of layers to extract
        min_spacing: Minimum spacing between layers
        background_value: Background value
    """
    try:
        print(f"\nProcessing: {nifti_path}")
        
        # Load NIfTI file
        nifti_img = nib.load(nifti_path)
        data = nifti_img.get_fdata()
        
        print(f"  Data shape: {data.shape}")
        print(f"  Data range: [{data.min():.2f}, {data.max():.2f}]")
        
        # Calculate informativeness for all layers
        layer_scores = calculate_layer_informativeness(data, background_value)
        
        # Select top N layers with spacing constraint
        selected_layers = select_top_layers_with_spacing(layer_scores, n_layers, min_spacing)
        
        if not selected_layers:
            print(f"  ⚠️ No suitable layers found")
            return 0
        
        # Extract selected layers
        layers = extract_selected_layers(data, selected_layers)
        
        # Process and save each layer
        filename_base = Path(nifti_path).stem.replace('.nii', '')  # Remove .nii.gz extension
        saved_count = 0
        
        for layer_name, layer_data in layers.items():
            # Normalize the layer
            normalized_layer = normalize_voxel_values(layer_data, background_value)
            
            # Create output filename
            output_filename = f"{filename_base}_{layer_name}.png"
            output_path = os.path.join(output_dir, output_filename)
            
            # Save as PNG
            save_layer_as_png(normalized_layer, output_path)
            saved_count += 1
        
        print(f"  ✅ Saved {saved_count} layers")
        return saved_count
    
    except Exception as e:
        print(f"  ❌ Error processing {nifti_path}: {str(e)}")
        return 0

def process_dataset(input_dataset_dir, output_dataset_dir, n_layers, min_spacing, background_value=-250):
    """
    Process entire dataset
    
    Args:
        input_dataset_dir: Input dataset directory
        output_dataset_dir: Output dataset directory
        n_layers: Number of layers to extract per file
        min_spacing: Minimum spacing between layers
        background_value: Background value
    
    Returns:
        Dictionary with processing statistics
    """
    input_path = Path(input_dataset_dir)
    output_path = Path(output_dataset_dir)
    
    stats = {
        'total_files': 0,
        'processed_files': 0,
        'total_layers_saved': 0,
        'splits': {}
    }
    
    # Iterate through train/val/test folders
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            print(f"\n{'='*50}")
            print(f"Processing split: {split_dir.name}")
            print(f"{'='*50}")
            
            stats['splits'][split_dir.name] = {'classes': {}}
            
            # Iterate through class folders (0, 1)
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    print(f"\n📁 Processing class: {class_dir.name}")
                    
                    # Create output directory
                    output_class_dir = output_path / split_dir.name / class_dir.name
                    output_class_dir.mkdir(parents=True, exist_ok=True)
                    
                    # Process all .nii.gz files in this directory
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    print(f"Found {len(nifti_files)} NIfTI files")
                    
                    class_stats = {
                        'total_files': len(nifti_files),
                        'processed_files': 0,
                        'total_layers': 0
                    }
                    
                    for nifti_file in nifti_files:
                        stats['total_files'] += 1
                        layers_saved = process_nifti_file(nifti_file, output_class_dir, n_layers, min_spacing, background_value)
                        
                        if layers_saved > 0:
                            stats['processed_files'] += 1
                            class_stats['processed_files'] += 1
                            stats['total_layers_saved'] += layers_saved
                            class_stats['total_layers'] += layers_saved
                    
                    stats['splits'][split_dir.name]['classes'][class_dir.name] = class_stats
                    print(f"Class {class_dir.name} summary: {class_stats['processed_files']}/{class_stats['total_files']} files processed, {class_stats['total_layers']} layers saved")
    
    return stats

# =============================================================================
# MAIN PROCESSING
# =============================================================================

# Validate input directory
if not os.path.exists(INPUT_DATASET_DIR):
    print(f"❌ Input dataset directory does not exist: {INPUT_DATASET_DIR}")
    print("Please update the INPUT_DATASET_DIR variable with the correct path")
else:
    print(f"✅ Input dataset found: {INPUT_DATASET_DIR}")
    
    # Validate parameters
    if N_LAYERS <= 0:
        print(f"❌ N_LAYERS must be positive, got: {N_LAYERS}")
    elif MIN_SPACING < 0:
        print(f"❌ MIN_SPACING must be non-negative, got: {MIN_SPACING}")
    else:
        print(f"✅ Starting processing to extract {N_LAYERS} layers with {MIN_SPACING} spacing...")
        
        # Process the dataset
        print(f"\n🚀 Starting dataset processing...")
        stats = process_dataset(INPUT_DATASET_DIR, OUTPUT_DATASET_DIR, N_LAYERS, MIN_SPACING, BACKGROUND_VALUE)
        
        # Print final summary
        print(f"\n{'='*60}")
        print("📊 PROCESSING SUMMARY")
        print(f"{'='*60}")
        print(f"Total files processed: {stats['processed_files']}/{stats['total_files']}")
        print(f"Total layers extracted: {stats['total_layers_saved']}")
        print(f"Average layers per file: {stats['total_layers_saved']/max(stats['processed_files'], 1):.1f}")
        print(f"Output directory: {OUTPUT_DATASET_DIR}")
        
        for split_name, split_data in stats['splits'].items():
            print(f"\n{split_name.upper()}:")
            for class_name, class_data in split_data['classes'].items():
                avg_layers = class_data['total_layers'] / max(class_data['processed_files'], 1)
                print(f"  Class {class_name}: {class_data['processed_files']}/{class_data['total_files']} files → {class_data['total_layers']} layers (avg: {avg_layers:.1f})")
        
        print(f"\n✅ Processing completed successfully!")

# =============================================================================
# OPTIONAL: ANALYZE LAYER SELECTION
# =============================================================================

def analyze_layer_selection(input_dataset_dir, n_layers, min_spacing, background_value=-250):
    """
    Analyze which layers would be selected across the dataset
    This helps you understand the distribution of informative layers
    """
    input_path = Path(input_dataset_dir)
    selected_layer_indices = []
    
    print(f"\n📈 Analyzing layer selection with N={n_layers}, spacing={min_spacing}...")
    
    for split_dir in input_path.iterdir():
        if split_dir.is_dir() and split_dir.name in ['train', 'val', 'test']:
            for class_dir in split_dir.iterdir():
                if class_dir.is_dir() and class_dir.name in ['0', '1']:
                    nifti_files = list(class_dir.glob('*.nii.gz'))
                    
                    for nifti_file in nifti_files[:3]:  # Analyze first 3 files for speed
                        try:
                            nifti_img = nib.load(nifti_file)
                            data = nifti_img.get_fdata()
                            
                            layer_scores = calculate_layer_informativeness(data, background_value)
                            selected_layers = select_top_layers_with_spacing(layer_scores, n_layers, min_spacing)
                            
                            for layer_idx, _ in selected_layers:
                                selected_layer_indices.append(layer_idx)
                        except:
                            continue
    
    if selected_layer_indices:
        selected_layer_indices = np.array(selected_layer_indices)
        print(f"Selected layer statistics:")
        print(f"  Mean position: {selected_layer_indices.mean():.1f}")
        print(f"  Median position: {np.median(selected_layer_indices):.1f}")
        print(f"  Min position: {selected_layer_indices.min()}")
        print(f"  Max position: {selected_layer_indices.max()}")
        print(f"  Most common positions: {np.bincount(selected_layer_indices).argsort()[-5:][::-1]}")

# Uncomment the line below to run the analysis
# analyze_layer_selection(INPUT_DATASET_DIR, N_LAYERS, MIN_SPACING, BACKGROUND_VALUE)
# Out:
# Configuration:
# Input dataset: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D
# Output dataset: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_2D
# Number of layers to extract: 30
# Minimum spacing between layers: 5
# Background value: -250
# ✅ Input dataset found: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D
# ✅ Starting processing to extract 30 layers with 5 spacing...
#
# 🚀 Starting dataset processing...
#
# ==================================================
# Processing split: test
# ==================================================
#
# 📁 Processing class: 0
# Found 16 NIfTI files
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\50-30909 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1088.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 61 (score: 0.2076)
#     Selected layer 66 (score: 0.2039)
#     Selected layer 56 (score: 0.2029)
#     Selected layer 71 (score: 0.1984)
#     Selected layer 76 (score: 0.1906)
#     Selected layer 51 (score: 0.1896)
#     Selected layer 81 (score: 0.1820)
#     Selected layer 46 (score: 0.1755)
#     Selected layer 86 (score: 0.1739)
#     Selected layer 91 (score: 0.1653)
#     Selected layer 41 (score: 0.1620)
#     Selected layer 96 (score: 0.1572)
#     Selected layer 101 (score: 0.1491)
#     Selected layer 36 (score: 0.1451)
#     Selected layer 106 (score: 0.1409)
#     Selected layer 111 (score: 0.1324)
#     Selected layer 31 (score: 0.1280)
#     Selected layer 116 (score: 0.1174)
#     Selected layer 26 (score: 0.1145)
#     Selected layer 121 (score: 0.1056)
#     Selected layer 21 (score: 0.1028)
#     Selected layer 126 (score: 0.0940)
#     Selected layer 16 (score: 0.0911)
#     Selected layer 131 (score: 0.0829)
#     Selected layer 11 (score: 0.0797)
#     Selected layer 136 (score: 0.0708)
#     Selected layer 6 (score: 0.0679)
#     Selected layer 141 (score: 0.0580)
#     Selected layer 1 (score: 0.0561)
#     Selected layer 146 (score: 0.0468)
#   Extracted layer 1 (rank 1, score: 0.0561)
#   Extracted layer 6 (rank 2, score: 0.0679)
#   Extracted layer 11 (rank 3, score: 0.0797)
#   Extracted layer 16 (rank 4, score: 0.0911)
#   Extracted layer 21 (rank 5, score: 0.1028)
#   Extracted layer 26 (rank 6, score: 0.1145)
#   Extracted layer 31 (rank 7, score: 0.1280)
#   Extracted layer 36 (rank 8, score: 0.1451)
#   Extracted layer 41 (rank 9, score: 0.1620)
#   Extracted layer 46 (rank 10, score: 0.1755)
#   Extracted layer 51 (rank 11, score: 0.1896)
#   Extracted layer 56 (rank 12, score: 0.2029)
#   Extracted layer 61 (rank 13, score: 0.2076)
#   Extracted layer 66 (rank 14, score: 0.2039)
#   Extracted layer 71 (rank 15, score: 0.1984)
#   Extracted layer 76 (rank 16, score: 0.1906)
#   Extracted layer 81 (rank 17, score: 0.1820)
#   Extracted layer 86 (rank 18, score: 0.1739)
#   Extracted layer 91 (rank 19, score: 0.1653)
#   Extracted layer 96 (rank 20, score: 0.1572)
#   Extracted layer 101 (rank 21, score: 0.1491)
#   Extracted layer 106 (rank 22, score: 0.1409)
#   Extracted layer 111 (rank 23, score: 0.1324)
#   Extracted layer 116 (rank 24, score: 0.1174)
#   Extracted layer 121 (rank 25, score: 0.1056)
#   Extracted layer 126 (rank 26, score: 0.0940)
#   Extracted layer 131 (rank 27, score: 0.0829)
#   Extracted layer 136 (rank 28, score: 0.0708)
#   Extracted layer 141 (rank 29, score: 0.0580)
#   Extracted layer 146 (rank 30, score: 0.0468)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\53-13011 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1325.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 91 (score: 0.2655)
#     Selected layer 96 (score: 0.2630)
#     Selected layer 86 (score: 0.2597)
#     Selected layer 101 (score: 0.2562)
#     Selected layer 81 (score: 0.2489)
#     Selected layer 106 (score: 0.2444)
#     Selected layer 76 (score: 0.2362)
#     Selected layer 111 (score: 0.2271)
#     Selected layer 71 (score: 0.2195)
#     Selected layer 116 (score: 0.2082)
#     Selected layer 66 (score: 0.2017)
#     Selected layer 121 (score: 0.1854)
#     Selected layer 61 (score: 0.1823)
#     Selected layer 56 (score: 0.1597)
#     Selected layer 126 (score: 0.1501)
#     Selected layer 51 (score: 0.1364)
#     Selected layer 46 (score: 0.1159)
#     Selected layer 41 (score: 0.0981)
#     Selected layer 131 (score: 0.0891)
#     Selected layer 36 (score: 0.0833)
#     Selected layer 31 (score: 0.0687)
#     Selected layer 136 (score: 0.0650)
#     Selected layer 141 (score: 0.0533)
#     Selected layer 26 (score: 0.0519)
#     Selected layer 146 (score: 0.0416)
#     Selected layer 21 (score: 0.0372)
#     Selected layer 151 (score: 0.0294)
#     Selected layer 16 (score: 0.0229)
#     Selected layer 156 (score: 0.0159)
#     Selected layer 11 (score: 0.0087)
#   Extracted layer 11 (rank 1, score: 0.0087)
#   Extracted layer 16 (rank 2, score: 0.0229)
#   Extracted layer 21 (rank 3, score: 0.0372)
#   Extracted layer 26 (rank 4, score: 0.0519)
#   Extracted layer 31 (rank 5, score: 0.0687)
#   Extracted layer 36 (rank 6, score: 0.0833)
#   Extracted layer 41 (rank 7, score: 0.0981)
#   Extracted layer 46 (rank 8, score: 0.1159)
#   Extracted layer 51 (rank 9, score: 0.1364)
#   Extracted layer 56 (rank 10, score: 0.1597)
#   Extracted layer 61 (rank 11, score: 0.1823)
#   Extracted layer 66 (rank 12, score: 0.2017)
#   Extracted layer 71 (rank 13, score: 0.2195)
#   Extracted layer 76 (rank 14, score: 0.2362)
#   Extracted layer 81 (rank 15, score: 0.2489)
#   Extracted layer 86 (rank 16, score: 0.2597)
#   Extracted layer 91 (rank 17, score: 0.2655)
#   Extracted layer 96 (rank 18, score: 0.2630)
#   Extracted layer 101 (rank 19, score: 0.2562)
#   Extracted layer 106 (rank 20, score: 0.2444)
#   Extracted layer 111 (rank 21, score: 0.2271)
#   Extracted layer 116 (rank 22, score: 0.2082)
#   Extracted layer 121 (rank 23, score: 0.1854)
#   Extracted layer 126 (rank 24, score: 0.1501)
#   Extracted layer 131 (rank 25, score: 0.0891)
#   Extracted layer 136 (rank 26, score: 0.0650)
#   Extracted layer 141 (rank 27, score: 0.0533)
#   Extracted layer 146 (rank 28, score: 0.0416)
#   Extracted layer 151 (rank 29, score: 0.0294)
#   Extracted layer 156 (rank 30, score: 0.0159)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\53-26507 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1426.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 107 (score: 0.2196)
#     Selected layer 102 (score: 0.2176)
#     Selected layer 112 (score: 0.2169)
#     Selected layer 117 (score: 0.2111)
#     Selected layer 97 (score: 0.2102)
#     Selected layer 122 (score: 0.2016)
#     Selected layer 92 (score: 0.2003)
#     Selected layer 127 (score: 0.1896)
#     Selected layer 87 (score: 0.1873)
#     Selected layer 132 (score: 0.1756)
#     Selected layer 82 (score: 0.1699)
#     Selected layer 137 (score: 0.1605)
#     Selected layer 77 (score: 0.1463)
#     Selected layer 142 (score: 0.1437)
#     Selected layer 147 (score: 0.1230)
#     Selected layer 72 (score: 0.1199)
#     Selected layer 152 (score: 0.1101)
#     Selected layer 67 (score: 0.0990)
#     Selected layer 157 (score: 0.0971)
#     Selected layer 162 (score: 0.0831)
#     Selected layer 62 (score: 0.0812)
#     Selected layer 167 (score: 0.0672)
#     Selected layer 57 (score: 0.0665)
#     Selected layer 52 (score: 0.0548)
#     Selected layer 172 (score: 0.0488)
#     Selected layer 47 (score: 0.0442)
#     Selected layer 42 (score: 0.0317)
#     Selected layer 177 (score: 0.0284)
#     Selected layer 37 (score: 0.0190)
#     Selected layer 32 (score: 0.0050)
#   Extracted layer 32 (rank 1, score: 0.0050)
#   Extracted layer 37 (rank 2, score: 0.0190)
#   Extracted layer 42 (rank 3, score: 0.0317)
#   Extracted layer 47 (rank 4, score: 0.0442)
#   Extracted layer 52 (rank 5, score: 0.0548)
#   Extracted layer 57 (rank 6, score: 0.0665)
#   Extracted layer 62 (rank 7, score: 0.0812)
#   Extracted layer 67 (rank 8, score: 0.0990)
#   Extracted layer 72 (rank 9, score: 0.1199)
#   Extracted layer 77 (rank 10, score: 0.1463)
#   Extracted layer 82 (rank 11, score: 0.1699)
#   Extracted layer 87 (rank 12, score: 0.1873)
#   Extracted layer 92 (rank 13, score: 0.2003)
#   Extracted layer 97 (rank 14, score: 0.2102)
#   Extracted layer 102 (rank 15, score: 0.2176)
#   Extracted layer 107 (rank 16, score: 0.2196)
#   Extracted layer 112 (rank 17, score: 0.2169)
#   Extracted layer 117 (rank 18, score: 0.2111)
#   Extracted layer 122 (rank 19, score: 0.2016)
#   Extracted layer 127 (rank 20, score: 0.1896)
#   Extracted layer 132 (rank 21, score: 0.1756)
#   Extracted layer 137 (rank 22, score: 0.1605)
#   Extracted layer 142 (rank 23, score: 0.1437)
#   Extracted layer 147 (rank 24, score: 0.1230)
#   Extracted layer 152 (rank 25, score: 0.1101)
#   Extracted layer 157 (rank 26, score: 0.0971)
#   Extracted layer 162 (rank 27, score: 0.0831)
#   Extracted layer 167 (rank 28, score: 0.0672)
#   Extracted layer 172 (rank 29, score: 0.0488)
#   Extracted layer 177 (rank 30, score: 0.0284)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\55-1648 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1333.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 113 (score: 0.2055)
#     Selected layer 108 (score: 0.2039)
#     Selected layer 118 (score: 0.2029)
#     Selected layer 123 (score: 0.1987)
#     Selected layer 103 (score: 0.1969)
#     Selected layer 128 (score: 0.1939)
#     Selected layer 133 (score: 0.1868)
#     Selected layer 138 (score: 0.1767)
#     Selected layer 98 (score: 0.1644)
#     Selected layer 143 (score: 0.1600)
#     Selected layer 148 (score: 0.1244)
#     Selected layer 93 (score: 0.1187)
#     Selected layer 153 (score: 0.1052)
#     Selected layer 158 (score: 0.0883)
#     Selected layer 88 (score: 0.0772)
#     Selected layer 163 (score: 0.0708)
#     Selected layer 83 (score: 0.0548)
#     Selected layer 168 (score: 0.0510)
#     Selected layer 78 (score: 0.0385)
#     Selected layer 173 (score: 0.0334)
#     Selected layer 73 (score: 0.0252)
#     Selected layer 178 (score: 0.0183)
#     Selected layer 68 (score: 0.0136)
#     Selected layer 183 (score: 0.0036)
#     Selected layer 63 (score: 0.0033)
#     Selected layer 0 (score: 0.0000)
#     Selected layer 5 (score: 0.0000)
#     Selected layer 10 (score: 0.0000)
#     Selected layer 15 (score: 0.0000)
#     Selected layer 20 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 5 (rank 2, score: 0.0000)
#   Extracted layer 10 (rank 3, score: 0.0000)
#   Extracted layer 15 (rank 4, score: 0.0000)
#   Extracted layer 20 (rank 5, score: 0.0000)
#   Extracted layer 63 (rank 6, score: 0.0033)
#   Extracted layer 68 (rank 7, score: 0.0136)
#   Extracted layer 73 (rank 8, score: 0.0252)
#   Extracted layer 78 (rank 9, score: 0.0385)
#   Extracted layer 83 (rank 10, score: 0.0548)
#   Extracted layer 88 (rank 11, score: 0.0772)
#   Extracted layer 93 (rank 12, score: 0.1187)
#   Extracted layer 98 (rank 13, score: 0.1644)
#   Extracted layer 103 (rank 14, score: 0.1969)
#   Extracted layer 108 (rank 15, score: 0.2039)
#   Extracted layer 113 (rank 16, score: 0.2055)
#   Extracted layer 118 (rank 17, score: 0.2029)
#   Extracted layer 123 (rank 18, score: 0.1987)
#   Extracted layer 128 (rank 19, score: 0.1939)
#   Extracted layer 133 (rank 20, score: 0.1868)
#   Extracted layer 138 (rank 21, score: 0.1767)
#   Extracted layer 143 (rank 22, score: 0.1600)
#   Extracted layer 148 (rank 23, score: 0.1244)
#   Extracted layer 153 (rank 24, score: 0.1052)
#   Extracted layer 158 (rank 25, score: 0.0883)
#   Extracted layer 163 (rank 26, score: 0.0708)
#   Extracted layer 168 (rank 27, score: 0.0510)
#   Extracted layer 173 (rank 28, score: 0.0334)
#   Extracted layer 178 (rank 29, score: 0.0183)
#   Extracted layer 183 (rank 30, score: 0.0036)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\55-9422 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1437.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 147 (score: 0.2082)
#     Selected layer 142 (score: 0.2054)
#     Selected layer 152 (score: 0.2039)
#     Selected layer 137 (score: 0.1990)
#     Selected layer 157 (score: 0.1943)
#     Selected layer 132 (score: 0.1880)
#     Selected layer 162 (score: 0.1807)
#     Selected layer 127 (score: 0.1771)
#     Selected layer 122 (score: 0.1640)
#     Selected layer 167 (score: 0.1624)
#     Selected layer 117 (score: 0.1481)
#     Selected layer 172 (score: 0.1381)
#     Selected layer 112 (score: 0.1261)
#     Selected layer 107 (score: 0.1104)
#     Selected layer 177 (score: 0.1085)
#     Selected layer 102 (score: 0.0967)
#     Selected layer 97 (score: 0.0842)
#     Selected layer 92 (score: 0.0725)
#     Selected layer 182 (score: 0.0720)
#     Selected layer 87 (score: 0.0622)
#     Selected layer 82 (score: 0.0513)
#     Selected layer 187 (score: 0.0439)
#     Selected layer 77 (score: 0.0397)
#     Selected layer 72 (score: 0.0287)
#     Selected layer 67 (score: 0.0195)
#     Selected layer 192 (score: 0.0187)
#     Selected layer 62 (score: 0.0112)
#     Selected layer 57 (score: 0.0035)
#     Selected layer 0 (score: 0.0000)
#     Selected layer 5 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 5 (rank 2, score: 0.0000)
#   Extracted layer 57 (rank 3, score: 0.0035)
#   Extracted layer 62 (rank 4, score: 0.0112)
#   Extracted layer 67 (rank 5, score: 0.0195)
#   Extracted layer 72 (rank 6, score: 0.0287)
#   Extracted layer 77 (rank 7, score: 0.0397)
#   Extracted layer 82 (rank 8, score: 0.0513)
#   Extracted layer 87 (rank 9, score: 0.0622)
#   Extracted layer 92 (rank 10, score: 0.0725)
#   Extracted layer 97 (rank 11, score: 0.0842)
#   Extracted layer 102 (rank 12, score: 0.0967)
#   Extracted layer 107 (rank 13, score: 0.1104)
#   Extracted layer 112 (rank 14, score: 0.1261)
#   Extracted layer 117 (rank 15, score: 0.1481)
#   Extracted layer 122 (rank 16, score: 0.1640)
#   Extracted layer 127 (rank 17, score: 0.1771)
#   Extracted layer 132 (rank 18, score: 0.1880)
#   Extracted layer 137 (rank 19, score: 0.1990)
#   Extracted layer 142 (rank 20, score: 0.2054)
#   Extracted layer 147 (rank 21, score: 0.2082)
#   Extracted layer 152 (rank 22, score: 0.2039)
#   Extracted layer 157 (rank 23, score: 0.1943)
#   Extracted layer 162 (rank 24, score: 0.1807)
#   Extracted layer 167 (rank 25, score: 0.1624)
#   Extracted layer 172 (rank 26, score: 0.1381)
#   Extracted layer 177 (rank 27, score: 0.1085)
#   Extracted layer 182 (rank 28, score: 0.0720)
#   Extracted layer 187 (rank 29, score: 0.0439)
#   Extracted layer 192 (rank 30, score: 0.0187)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\57-24983 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1391.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 76 (score: 0.2870)
#     Selected layer 81 (score: 0.2860)
#     Selected layer 71 (score: 0.2860)
#     Selected layer 66 (score: 0.2838)
#     Selected layer 86 (score: 0.2826)
#     Selected layer 61 (score: 0.2804)
#     Selected layer 56 (score: 0.2764)
#     Selected layer 91 (score: 0.2736)
#     Selected layer 51 (score: 0.2701)
#     Selected layer 46 (score: 0.2619)
#     Selected layer 96 (score: 0.2545)
#     Selected layer 41 (score: 0.2503)
#     Selected layer 101 (score: 0.2380)
#     Selected layer 36 (score: 0.2344)
#     Selected layer 106 (score: 0.2201)
#     Selected layer 31 (score: 0.2114)
#     Selected layer 111 (score: 0.2007)
#     Selected layer 116 (score: 0.1851)
#     Selected layer 26 (score: 0.1800)
#     Selected layer 121 (score: 0.1732)
#     Selected layer 126 (score: 0.1634)
#     Selected layer 131 (score: 0.1552)
#     Selected layer 136 (score: 0.1479)
#     Selected layer 141 (score: 0.1413)
#     Selected layer 146 (score: 0.1329)
#     Selected layer 21 (score: 0.1261)
#     Selected layer 151 (score: 0.1236)
#     Selected layer 156 (score: 0.1114)
#     Selected layer 161 (score: 0.0965)
#     Selected layer 16 (score: 0.0893)
#   Extracted layer 16 (rank 1, score: 0.0893)
#   Extracted layer 21 (rank 2, score: 0.1261)
#   Extracted layer 26 (rank 3, score: 0.1800)
#   Extracted layer 31 (rank 4, score: 0.2114)
#   Extracted layer 36 (rank 5, score: 0.2344)
#   Extracted layer 41 (rank 6, score: 0.2503)
#   Extracted layer 46 (rank 7, score: 0.2619)
#   Extracted layer 51 (rank 8, score: 0.2701)
#   Extracted layer 56 (rank 9, score: 0.2764)
#   Extracted layer 61 (rank 10, score: 0.2804)
#   Extracted layer 66 (rank 11, score: 0.2838)
#   Extracted layer 71 (rank 12, score: 0.2860)
#   Extracted layer 76 (rank 13, score: 0.2870)
#   Extracted layer 81 (rank 14, score: 0.2860)
#   Extracted layer 86 (rank 15, score: 0.2826)
#   Extracted layer 91 (rank 16, score: 0.2736)
#   Extracted layer 96 (rank 17, score: 0.2545)
#   Extracted layer 101 (rank 18, score: 0.2380)
#   Extracted layer 106 (rank 19, score: 0.2201)
#   Extracted layer 111 (rank 20, score: 0.2007)
#   Extracted layer 116 (rank 21, score: 0.1851)
#   Extracted layer 121 (rank 22, score: 0.1732)
#   Extracted layer 126 (rank 23, score: 0.1634)
#   Extracted layer 131 (rank 24, score: 0.1552)
#   Extracted layer 136 (rank 25, score: 0.1479)
#   Extracted layer 141 (rank 26, score: 0.1413)
#   Extracted layer 146 (rank 27, score: 0.1329)
#   Extracted layer 151 (rank 28, score: 0.1236)
#   Extracted layer 156 (rank 29, score: 0.1114)
#   Extracted layer 161 (rank 30, score: 0.0965)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\59-39978 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1371.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 109 (score: 0.2460)
#     Selected layer 114 (score: 0.2441)
#     Selected layer 104 (score: 0.2418)
#     Selected layer 119 (score: 0.2333)
#     Selected layer 99 (score: 0.2315)
#     Selected layer 94 (score: 0.2204)
#     Selected layer 89 (score: 0.2104)
#     Selected layer 84 (score: 0.1991)
#     Selected layer 79 (score: 0.1873)
#     Selected layer 74 (score: 0.1748)
#     Selected layer 124 (score: 0.1714)
#     Selected layer 69 (score: 0.1596)
#     Selected layer 64 (score: 0.1406)
#     Selected layer 129 (score: 0.1266)
#     Selected layer 59 (score: 0.1039)
#     Selected layer 134 (score: 0.0987)
#     Selected layer 139 (score: 0.0794)
#     Selected layer 54 (score: 0.0756)
#     Selected layer 49 (score: 0.0642)
#     Selected layer 144 (score: 0.0641)
#     Selected layer 44 (score: 0.0565)
#     Selected layer 39 (score: 0.0514)
#     Selected layer 149 (score: 0.0513)
#     Selected layer 34 (score: 0.0476)
#     Selected layer 29 (score: 0.0444)
#     Selected layer 154 (score: 0.0415)
#     Selected layer 24 (score: 0.0409)
#     Selected layer 19 (score: 0.0370)
#     Selected layer 159 (score: 0.0336)
#     Selected layer 14 (score: 0.0330)
#   Extracted layer 14 (rank 1, score: 0.0330)
#   Extracted layer 19 (rank 2, score: 0.0370)
#   Extracted layer 24 (rank 3, score: 0.0409)
#   Extracted layer 29 (rank 4, score: 0.0444)
#   Extracted layer 34 (rank 5, score: 0.0476)
#   Extracted layer 39 (rank 6, score: 0.0514)
#   Extracted layer 44 (rank 7, score: 0.0565)
#   Extracted layer 49 (rank 8, score: 0.0642)
#   Extracted layer 54 (rank 9, score: 0.0756)
#   Extracted layer 59 (rank 10, score: 0.1039)
#   Extracted layer 64 (rank 11, score: 0.1406)
#   Extracted layer 69 (rank 12, score: 0.1596)
#   Extracted layer 74 (rank 13, score: 0.1748)
#   Extracted layer 79 (rank 14, score: 0.1873)
#   Extracted layer 84 (rank 15, score: 0.1991)
#   Extracted layer 89 (rank 16, score: 0.2104)
#   Extracted layer 94 (rank 17, score: 0.2204)
#   Extracted layer 99 (rank 18, score: 0.2315)
#   Extracted layer 104 (rank 19, score: 0.2418)
#   Extracted layer 109 (rank 20, score: 0.2460)
#   Extracted layer 114 (rank 21, score: 0.2441)
#   Extracted layer 119 (rank 22, score: 0.2333)
#   Extracted layer 124 (rank 23, score: 0.1714)
#   Extracted layer 129 (rank 24, score: 0.1266)
#   Extracted layer 134 (rank 25, score: 0.0987)
#   Extracted layer 139 (rank 26, score: 0.0794)
#   Extracted layer 144 (rank 27, score: 0.0641)
#   Extracted layer 149 (rank 28, score: 0.0513)
#   Extracted layer 154 (rank 29, score: 0.0415)
#   Extracted layer 159 (rank 30, score: 0.0336)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\60-700759 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1280.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 137 (score: 0.2812)
#     Selected layer 132 (score: 0.2773)
#     Selected layer 142 (score: 0.2750)
#     Selected layer 127 (score: 0.2616)
#     Selected layer 147 (score: 0.2585)
#     Selected layer 122 (score: 0.2333)
#     Selected layer 117 (score: 0.2006)
#     Selected layer 152 (score: 0.1904)
#     Selected layer 112 (score: 0.1768)
#     Selected layer 107 (score: 0.1629)
#     Selected layer 157 (score: 0.1510)
#     Selected layer 102 (score: 0.1461)
#     Selected layer 97 (score: 0.1207)
#     Selected layer 162 (score: 0.1153)
#     Selected layer 92 (score: 0.1079)
#     Selected layer 87 (score: 0.0987)
#     Selected layer 82 (score: 0.0907)
#     Selected layer 77 (score: 0.0837)
#     Selected layer 72 (score: 0.0755)
#     Selected layer 67 (score: 0.0669)
#     Selected layer 167 (score: 0.0668)
#     Selected layer 62 (score: 0.0570)
#     Selected layer 172 (score: 0.0500)
#     Selected layer 57 (score: 0.0443)
#     Selected layer 177 (score: 0.0359)
#     Selected layer 52 (score: 0.0298)
#     Selected layer 182 (score: 0.0223)
#     Selected layer 47 (score: 0.0148)
#     Selected layer 187 (score: 0.0107)
#     Selected layer 42 (score: 0.0017)
#   Extracted layer 42 (rank 1, score: 0.0017)
#   Extracted layer 47 (rank 2, score: 0.0148)
#   Extracted layer 52 (rank 3, score: 0.0298)
#   Extracted layer 57 (rank 4, score: 0.0443)
#   Extracted layer 62 (rank 5, score: 0.0570)
#   Extracted layer 67 (rank 6, score: 0.0669)
#   Extracted layer 72 (rank 7, score: 0.0755)
#   Extracted layer 77 (rank 8, score: 0.0837)
#   Extracted layer 82 (rank 9, score: 0.0907)
#   Extracted layer 87 (rank 10, score: 0.0987)
#   Extracted layer 92 (rank 11, score: 0.1079)
#   Extracted layer 97 (rank 12, score: 0.1207)
#   Extracted layer 102 (rank 13, score: 0.1461)
#   Extracted layer 107 (rank 14, score: 0.1629)
#   Extracted layer 112 (rank 15, score: 0.1768)
#   Extracted layer 117 (rank 16, score: 0.2006)
#   Extracted layer 122 (rank 17, score: 0.2333)
#   Extracted layer 127 (rank 18, score: 0.2616)
#   Extracted layer 132 (rank 19, score: 0.2773)
#   Extracted layer 137 (rank 20, score: 0.2812)
#   Extracted layer 142 (rank 21, score: 0.2750)
#   Extracted layer 147 (rank 22, score: 0.2585)
#   Extracted layer 152 (rank 23, score: 0.1904)
#   Extracted layer 157 (rank 24, score: 0.1510)
#   Extracted layer 162 (rank 25, score: 0.1153)
#   Extracted layer 167 (rank 26, score: 0.0668)
#   Extracted layer 172 (rank 27, score: 0.0500)
#   Extracted layer 177 (rank 28, score: 0.0359)
#   Extracted layer 182 (rank 29, score: 0.0223)
#   Extracted layer 187 (rank 30, score: 0.0107)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\62-25333 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1322.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 124 (score: 0.2309)
#     Selected layer 119 (score: 0.2281)
#     Selected layer 129 (score: 0.2280)
#     Selected layer 114 (score: 0.2229)
#     Selected layer 134 (score: 0.2179)
#     Selected layer 109 (score: 0.2152)
#     Selected layer 104 (score: 0.2070)
#     Selected layer 139 (score: 0.2026)
#     Selected layer 99 (score: 0.1968)
#     Selected layer 94 (score: 0.1775)
#     Selected layer 144 (score: 0.1746)
#     Selected layer 89 (score: 0.1592)
#     Selected layer 149 (score: 0.1385)
#     Selected layer 84 (score: 0.1356)
#     Selected layer 79 (score: 0.1200)
#     Selected layer 74 (score: 0.1096)
#     Selected layer 154 (score: 0.1056)
#     Selected layer 69 (score: 0.1002)
#     Selected layer 64 (score: 0.0912)
#     Selected layer 159 (score: 0.0845)
#     Selected layer 59 (score: 0.0832)
#     Selected layer 54 (score: 0.0749)
#     Selected layer 164 (score: 0.0685)
#     Selected layer 49 (score: 0.0681)
#     Selected layer 44 (score: 0.0612)
#     Selected layer 169 (score: 0.0554)
#     Selected layer 39 (score: 0.0524)
#     Selected layer 174 (score: 0.0448)
#     Selected layer 34 (score: 0.0424)
#     Selected layer 179 (score: 0.0330)
#   Extracted layer 34 (rank 1, score: 0.0424)
#   Extracted layer 39 (rank 2, score: 0.0524)
#   Extracted layer 44 (rank 3, score: 0.0612)
#   Extracted layer 49 (rank 4, score: 0.0681)
#   Extracted layer 54 (rank 5, score: 0.0749)
#   Extracted layer 59 (rank 6, score: 0.0832)
#   Extracted layer 64 (rank 7, score: 0.0912)
#   Extracted layer 69 (rank 8, score: 0.1002)
#   Extracted layer 74 (rank 9, score: 0.1096)
#   Extracted layer 79 (rank 10, score: 0.1200)
#   Extracted layer 84 (rank 11, score: 0.1356)
#   Extracted layer 89 (rank 12, score: 0.1592)
#   Extracted layer 94 (rank 13, score: 0.1775)
#   Extracted layer 99 (rank 14, score: 0.1968)
#   Extracted layer 104 (rank 15, score: 0.2070)
#   Extracted layer 109 (rank 16, score: 0.2152)
#   Extracted layer 114 (rank 17, score: 0.2229)
#   Extracted layer 119 (rank 18, score: 0.2281)
#   Extracted layer 124 (rank 19, score: 0.2309)
#   Extracted layer 129 (rank 20, score: 0.2280)
#   Extracted layer 134 (rank 21, score: 0.2179)
#   Extracted layer 139 (rank 22, score: 0.2026)
#   Extracted layer 144 (rank 23, score: 0.1746)
#   Extracted layer 149 (rank 24, score: 0.1385)
#   Extracted layer 154 (rank 25, score: 0.1056)
#   Extracted layer 159 (rank 26, score: 0.0845)
#   Extracted layer 164 (rank 27, score: 0.0685)
#   Extracted layer 169 (rank 28, score: 0.0554)
#   Extracted layer 174 (rank 29, score: 0.0448)
#   Extracted layer 179 (rank 30, score: 0.0330)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\63-700449 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1269.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 158 (score: 0.2545)
#     Selected layer 153 (score: 0.2505)
#     Selected layer 163 (score: 0.2504)
#     Selected layer 168 (score: 0.2414)
#     Selected layer 148 (score: 0.2380)
#     Selected layer 173 (score: 0.2282)
#     Selected layer 143 (score: 0.2168)
#     Selected layer 138 (score: 0.1950)
#     Selected layer 133 (score: 0.1752)
#     Selected layer 178 (score: 0.1713)
#     Selected layer 128 (score: 0.1487)
#     Selected layer 123 (score: 0.1298)
#     Selected layer 118 (score: 0.1167)
#     Selected layer 183 (score: 0.1098)
#     Selected layer 113 (score: 0.1056)
#     Selected layer 108 (score: 0.0956)
#     Selected layer 103 (score: 0.0857)
#     Selected layer 98 (score: 0.0760)
#     Selected layer 188 (score: 0.0718)
#     Selected layer 93 (score: 0.0655)
#     Selected layer 88 (score: 0.0525)
#     Selected layer 193 (score: 0.0467)
#     Selected layer 83 (score: 0.0375)
#     Selected layer 198 (score: 0.0236)
#     Selected layer 78 (score: 0.0197)
#     Selected layer 203 (score: 0.0077)
#     Selected layer 0 (score: 0.0000)
#     Selected layer 5 (score: 0.0000)
#     Selected layer 10 (score: 0.0000)
#     Selected layer 15 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 5 (rank 2, score: 0.0000)
#   Extracted layer 10 (rank 3, score: 0.0000)
#   Extracted layer 15 (rank 4, score: 0.0000)
#   Extracted layer 78 (rank 5, score: 0.0197)
#   Extracted layer 83 (rank 6, score: 0.0375)
#   Extracted layer 88 (rank 7, score: 0.0525)
#   Extracted layer 93 (rank 8, score: 0.0655)
#   Extracted layer 98 (rank 9, score: 0.0760)
#   Extracted layer 103 (rank 10, score: 0.0857)
#   Extracted layer 108 (rank 11, score: 0.0956)
#   Extracted layer 113 (rank 12, score: 0.1056)
#   Extracted layer 118 (rank 13, score: 0.1167)
#   Extracted layer 123 (rank 14, score: 0.1298)
#   Extracted layer 128 (rank 15, score: 0.1487)
#   Extracted layer 133 (rank 16, score: 0.1752)
#   Extracted layer 138 (rank 17, score: 0.1950)
#   Extracted layer 143 (rank 18, score: 0.2168)
#   Extracted layer 148 (rank 19, score: 0.2380)
#   Extracted layer 153 (rank 20, score: 0.2505)
#   Extracted layer 158 (rank 21, score: 0.2545)
#   Extracted layer 163 (rank 22, score: 0.2504)
#   Extracted layer 168 (rank 23, score: 0.2414)
#   Extracted layer 173 (rank 24, score: 0.2282)
#   Extracted layer 178 (rank 25, score: 0.1713)
#   Extracted layer 183 (rank 26, score: 0.1098)
#   Extracted layer 188 (rank 27, score: 0.0718)
#   Extracted layer 193 (rank 28, score: 0.0467)
#   Extracted layer 198 (rank 29, score: 0.0236)
#   Extracted layer 203 (rank 30, score: 0.0077)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\64-10402 R 2023 02 08_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1327.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 98 (score: 0.2333)
#     Selected layer 92 (score: 0.2328)
#     Selected layer 104 (score: 0.2305)
#     Selected layer 87 (score: 0.2284)
#     Selected layer 109 (score: 0.2226)
#     Selected layer 82 (score: 0.2205)
#     Selected layer 114 (score: 0.2114)
#     Selected layer 77 (score: 0.2069)
#     Selected layer 119 (score: 0.1978)
#     Selected layer 72 (score: 0.1858)
#     Selected layer 124 (score: 0.1749)
#     Selected layer 67 (score: 0.1590)
#     Selected layer 129 (score: 0.1542)
#     Selected layer 134 (score: 0.1385)
#     Selected layer 139 (score: 0.1230)
#     Selected layer 62 (score: 0.1150)
#     Selected layer 144 (score: 0.1067)
#     Selected layer 149 (score: 0.0942)
#     Selected layer 154 (score: 0.0820)
#     Selected layer 57 (score: 0.0813)
#     Selected layer 159 (score: 0.0694)
#     Selected layer 52 (score: 0.0581)
#     Selected layer 164 (score: 0.0550)
#     Selected layer 169 (score: 0.0400)
#     Selected layer 47 (score: 0.0377)
#     Selected layer 174 (score: 0.0260)
#     Selected layer 42 (score: 0.0187)
#     Selected layer 179 (score: 0.0121)
#     Selected layer 37 (score: 0.0076)
#     Selected layer 0 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 37 (rank 2, score: 0.0076)
#   Extracted layer 42 (rank 3, score: 0.0187)
#   Extracted layer 47 (rank 4, score: 0.0377)
#   Extracted layer 52 (rank 5, score: 0.0581)
#   Extracted layer 57 (rank 6, score: 0.0813)
#   Extracted layer 62 (rank 7, score: 0.1150)
#   Extracted layer 67 (rank 8, score: 0.1590)
#   Extracted layer 72 (rank 9, score: 0.1858)
#   Extracted layer 77 (rank 10, score: 0.2069)
#   Extracted layer 82 (rank 11, score: 0.2205)
#   Extracted layer 87 (rank 12, score: 0.2284)
#   Extracted layer 92 (rank 13, score: 0.2328)
#   Extracted layer 98 (rank 14, score: 0.2333)
#   Extracted layer 104 (rank 15, score: 0.2305)
#   Extracted layer 109 (rank 16, score: 0.2226)
#   Extracted layer 114 (rank 17, score: 0.2114)
#   Extracted layer 119 (rank 18, score: 0.1978)
#   Extracted layer 124 (rank 19, score: 0.1749)
#   Extracted layer 129 (rank 20, score: 0.1542)
#   Extracted layer 134 (rank 21, score: 0.1385)
#   Extracted layer 139 (rank 22, score: 0.1230)
#   Extracted layer 144 (rank 23, score: 0.1067)
#   Extracted layer 149 (rank 24, score: 0.0942)
#   Extracted layer 154 (rank 25, score: 0.0820)
#   Extracted layer 159 (rank 26, score: 0.0694)
#   Extracted layer 164 (rank 27, score: 0.0550)
#   Extracted layer 169 (rank 28, score: 0.0400)
#   Extracted layer 174 (rank 29, score: 0.0260)
#   Extracted layer 179 (rank 30, score: 0.0121)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\64-3795 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1372.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 150 (score: 0.1695)
#     Selected layer 145 (score: 0.1676)
#     Selected layer 155 (score: 0.1659)
#     Selected layer 140 (score: 0.1629)
#     Selected layer 135 (score: 0.1578)
#     Selected layer 130 (score: 0.1519)
#     Selected layer 125 (score: 0.1459)
#     Selected layer 160 (score: 0.1429)
#     Selected layer 120 (score: 0.1400)
#     Selected layer 115 (score: 0.1334)
#     Selected layer 110 (score: 0.1273)
#     Selected layer 165 (score: 0.1236)
#     Selected layer 105 (score: 0.1211)
#     Selected layer 100 (score: 0.1140)
#     Selected layer 170 (score: 0.1095)
#     Selected layer 95 (score: 0.1037)
#     Selected layer 175 (score: 0.0970)
#     Selected layer 90 (score: 0.0867)
#     Selected layer 180 (score: 0.0851)
#     Selected layer 185 (score: 0.0742)
#     Selected layer 85 (score: 0.0738)
#     Selected layer 190 (score: 0.0633)
#     Selected layer 80 (score: 0.0616)
#     Selected layer 195 (score: 0.0525)
#     Selected layer 75 (score: 0.0488)
#     Selected layer 200 (score: 0.0414)
#     Selected layer 70 (score: 0.0366)
#     Selected layer 205 (score: 0.0315)
#     Selected layer 65 (score: 0.0254)
#     Selected layer 210 (score: 0.0208)
#   Extracted layer 65 (rank 1, score: 0.0254)
#   Extracted layer 70 (rank 2, score: 0.0366)
#   Extracted layer 75 (rank 3, score: 0.0488)
#   Extracted layer 80 (rank 4, score: 0.0616)
#   Extracted layer 85 (rank 5, score: 0.0738)
#   Extracted layer 90 (rank 6, score: 0.0867)
#   Extracted layer 95 (rank 7, score: 0.1037)
#   Extracted layer 100 (rank 8, score: 0.1140)
#   Extracted layer 105 (rank 9, score: 0.1211)
#   Extracted layer 110 (rank 10, score: 0.1273)
#   Extracted layer 115 (rank 11, score: 0.1334)
#   Extracted layer 120 (rank 12, score: 0.1400)
#   Extracted layer 125 (rank 13, score: 0.1459)
#   Extracted layer 130 (rank 14, score: 0.1519)
#   Extracted layer 135 (rank 15, score: 0.1578)
#   Extracted layer 140 (rank 16, score: 0.1629)
#   Extracted layer 145 (rank 17, score: 0.1676)
#   Extracted layer 150 (rank 18, score: 0.1695)
#   Extracted layer 155 (rank 19, score: 0.1659)
#   Extracted layer 160 (rank 20, score: 0.1429)
#   Extracted layer 165 (rank 21, score: 0.1236)
#   Extracted layer 170 (rank 22, score: 0.1095)
#   Extracted layer 175 (rank 23, score: 0.0970)
#   Extracted layer 180 (rank 24, score: 0.0851)
#   Extracted layer 185 (rank 25, score: 0.0742)
#   Extracted layer 190 (rank 26, score: 0.0633)
#   Extracted layer 195 (rank 27, score: 0.0525)
#   Extracted layer 200 (rank 28, score: 0.0414)
#   Extracted layer 205 (rank 29, score: 0.0315)
#   Extracted layer 210 (rank 30, score: 0.0208)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\64-700178 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1282.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 175 (score: 0.2192)
#     Selected layer 170 (score: 0.2162)
#     Selected layer 180 (score: 0.2130)
#     Selected layer 165 (score: 0.2090)
#     Selected layer 160 (score: 0.2045)
#     Selected layer 144 (score: 0.2034)
#     Selected layer 155 (score: 0.2031)
#     Selected layer 149 (score: 0.2031)
#     Selected layer 139 (score: 0.2024)
#     Selected layer 134 (score: 0.2010)
#     Selected layer 129 (score: 0.1991)
#     Selected layer 124 (score: 0.1971)
#     Selected layer 119 (score: 0.1944)
#     Selected layer 114 (score: 0.1898)
#     Selected layer 185 (score: 0.1863)
#     Selected layer 109 (score: 0.1836)
#     Selected layer 104 (score: 0.1743)
#     Selected layer 99 (score: 0.1606)
#     Selected layer 94 (score: 0.1460)
#     Selected layer 190 (score: 0.1438)
#     Selected layer 89 (score: 0.1325)
#     Selected layer 84 (score: 0.1194)
#     Selected layer 195 (score: 0.1085)
#     Selected layer 79 (score: 0.1062)
#     Selected layer 74 (score: 0.0941)
#     Selected layer 69 (score: 0.0832)
#     Selected layer 200 (score: 0.0820)
#     Selected layer 64 (score: 0.0707)
#     Selected layer 205 (score: 0.0602)
#     Selected layer 59 (score: 0.0562)
#   Extracted layer 59 (rank 1, score: 0.0562)
#   Extracted layer 64 (rank 2, score: 0.0707)
#   Extracted layer 69 (rank 3, score: 0.0832)
#   Extracted layer 74 (rank 4, score: 0.0941)
#   Extracted layer 79 (rank 5, score: 0.1062)
#   Extracted layer 84 (rank 6, score: 0.1194)
#   Extracted layer 89 (rank 7, score: 0.1325)
#   Extracted layer 94 (rank 8, score: 0.1460)
#   Extracted layer 99 (rank 9, score: 0.1606)
#   Extracted layer 104 (rank 10, score: 0.1743)
#   Extracted layer 109 (rank 11, score: 0.1836)
#   Extracted layer 114 (rank 12, score: 0.1898)
#   Extracted layer 119 (rank 13, score: 0.1944)
#   Extracted layer 124 (rank 14, score: 0.1971)
#   Extracted layer 129 (rank 15, score: 0.1991)
#   Extracted layer 134 (rank 16, score: 0.2010)
#   Extracted layer 139 (rank 17, score: 0.2024)
#   Extracted layer 144 (rank 18, score: 0.2034)
#   Extracted layer 149 (rank 19, score: 0.2031)
#   Extracted layer 155 (rank 20, score: 0.2031)
#   Extracted layer 160 (rank 21, score: 0.2045)
#   Extracted layer 165 (rank 22, score: 0.2090)
#   Extracted layer 170 (rank 23, score: 0.2162)
#   Extracted layer 175 (rank 24, score: 0.2192)
#   Extracted layer 180 (rank 25, score: 0.2130)
#   Extracted layer 185 (rank 26, score: 0.1863)
#   Extracted layer 190 (rank 27, score: 0.1438)
#   Extracted layer 195 (rank 28, score: 0.1085)
#   Extracted layer 200 (rank 29, score: 0.0820)
#   Extracted layer 205 (rank 30, score: 0.0602)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\64-8619 L 2022_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1401.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 79 (score: 0.2116)
#     Selected layer 74 (score: 0.2106)
#     Selected layer 84 (score: 0.2097)
#     Selected layer 69 (score: 0.2066)
#     Selected layer 89 (score: 0.2031)
#     Selected layer 64 (score: 0.1997)
#     Selected layer 59 (score: 0.1913)
#     Selected layer 94 (score: 0.1906)
#     Selected layer 54 (score: 0.1803)
#     Selected layer 49 (score: 0.1638)
#     Selected layer 99 (score: 0.1606)
#     Selected layer 44 (score: 0.1382)
#     Selected layer 104 (score: 0.1289)
#     Selected layer 109 (score: 0.1030)
#     Selected layer 39 (score: 0.0961)
#     Selected layer 114 (score: 0.0883)
#     Selected layer 119 (score: 0.0763)
#     Selected layer 34 (score: 0.0684)
#     Selected layer 124 (score: 0.0665)
#     Selected layer 129 (score: 0.0572)
#     Selected layer 29 (score: 0.0567)
#     Selected layer 24 (score: 0.0501)
#     Selected layer 134 (score: 0.0479)
#     Selected layer 19 (score: 0.0446)
#     Selected layer 14 (score: 0.0392)
#     Selected layer 139 (score: 0.0386)
#     Selected layer 9 (score: 0.0337)
#     Selected layer 4 (score: 0.0292)
#     Selected layer 144 (score: 0.0274)
#     Selected layer 149 (score: 0.0143)
#   Extracted layer 4 (rank 1, score: 0.0292)
#   Extracted layer 9 (rank 2, score: 0.0337)
#   Extracted layer 14 (rank 3, score: 0.0392)
#   Extracted layer 19 (rank 4, score: 0.0446)
#   Extracted layer 24 (rank 5, score: 0.0501)
#   Extracted layer 29 (rank 6, score: 0.0567)
#   Extracted layer 34 (rank 7, score: 0.0684)
#   Extracted layer 39 (rank 8, score: 0.0961)
#   Extracted layer 44 (rank 9, score: 0.1382)
#   Extracted layer 49 (rank 10, score: 0.1638)
#   Extracted layer 54 (rank 11, score: 0.1803)
#   Extracted layer 59 (rank 12, score: 0.1913)
#   Extracted layer 64 (rank 13, score: 0.1997)
#   Extracted layer 69 (rank 14, score: 0.2066)
#   Extracted layer 74 (rank 15, score: 0.2106)
#   Extracted layer 79 (rank 16, score: 0.2116)
#   Extracted layer 84 (rank 17, score: 0.2097)
#   Extracted layer 89 (rank 18, score: 0.2031)
#   Extracted layer 94 (rank 19, score: 0.1906)
#   Extracted layer 99 (rank 20, score: 0.1606)
#   Extracted layer 104 (rank 21, score: 0.1289)
#   Extracted layer 109 (rank 22, score: 0.1030)
#   Extracted layer 114 (rank 23, score: 0.0883)
#   Extracted layer 119 (rank 24, score: 0.0763)
#   Extracted layer 124 (rank 25, score: 0.0665)
#   Extracted layer 129 (rank 26, score: 0.0572)
#   Extracted layer 134 (rank 27, score: 0.0479)
#   Extracted layer 139 (rank 28, score: 0.0386)
#   Extracted layer 144 (rank 29, score: 0.0274)
#   Extracted layer 149 (rank 30, score: 0.0143)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\65-2425 R 2023_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1480.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 121 (score: 0.2128)
#     Selected layer 126 (score: 0.2100)
#     Selected layer 116 (score: 0.2099)
#     Selected layer 131 (score: 0.2040)
#     Selected layer 111 (score: 0.2016)
#     Selected layer 136 (score: 0.1928)
#     Selected layer 106 (score: 0.1902)
#     Selected layer 141 (score: 0.1785)
#     Selected layer 101 (score: 0.1703)
#     Selected layer 146 (score: 0.1594)
#     Selected layer 96 (score: 0.1529)
#     Selected layer 151 (score: 0.1436)
#     Selected layer 91 (score: 0.1346)
#     Selected layer 156 (score: 0.1280)
#     Selected layer 161 (score: 0.1113)
#     Selected layer 86 (score: 0.1099)
#     Selected layer 166 (score: 0.0947)
#     Selected layer 81 (score: 0.0876)
#     Selected layer 171 (score: 0.0797)
#     Selected layer 76 (score: 0.0680)
#     Selected layer 176 (score: 0.0633)
#     Selected layer 71 (score: 0.0494)
#     Selected layer 181 (score: 0.0460)
#     Selected layer 186 (score: 0.0291)
#     Selected layer 66 (score: 0.0286)
#     Selected layer 191 (score: 0.0103)
#     Selected layer 61 (score: 0.0018)
#     Selected layer 0 (score: 0.0000)
#     Selected layer 5 (score: 0.0000)
#     Selected layer 10 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 5 (rank 2, score: 0.0000)
#   Extracted layer 10 (rank 3, score: 0.0000)
#   Extracted layer 61 (rank 4, score: 0.0018)
#   Extracted layer 66 (rank 5, score: 0.0286)
#   Extracted layer 71 (rank 6, score: 0.0494)
#   Extracted layer 76 (rank 7, score: 0.0680)
#   Extracted layer 81 (rank 8, score: 0.0876)
#   Extracted layer 86 (rank 9, score: 0.1099)
#   Extracted layer 91 (rank 10, score: 0.1346)
#   Extracted layer 96 (rank 11, score: 0.1529)
#   Extracted layer 101 (rank 12, score: 0.1703)
#   Extracted layer 106 (rank 13, score: 0.1902)
#   Extracted layer 111 (rank 14, score: 0.2016)
#   Extracted layer 116 (rank 15, score: 0.2099)
#   Extracted layer 121 (rank 16, score: 0.2128)
#   Extracted layer 126 (rank 17, score: 0.2100)
#   Extracted layer 131 (rank 18, score: 0.2040)
#   Extracted layer 136 (rank 19, score: 0.1928)
#   Extracted layer 141 (rank 20, score: 0.1785)
#   Extracted layer 146 (rank 21, score: 0.1594)
#   Extracted layer 151 (rank 22, score: 0.1436)
#   Extracted layer 156 (rank 23, score: 0.1280)
#   Extracted layer 161 (rank 24, score: 0.1113)
#   Extracted layer 166 (rank 25, score: 0.0947)
#   Extracted layer 171 (rank 26, score: 0.0797)
#   Extracted layer 176 (rank 27, score: 0.0633)
#   Extracted layer 181 (rank 28, score: 0.0460)
#   Extracted layer 186 (rank 29, score: 0.0291)
#   Extracted layer 191 (rank 30, score: 0.0103)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\0\66-18213 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1386.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 152 (score: 0.2676)
#     Selected layer 157 (score: 0.2656)
#     Selected layer 147 (score: 0.2641)
#     Selected layer 162 (score: 0.2565)
#     Selected layer 142 (score: 0.2547)
#     Selected layer 137 (score: 0.2394)
#     Selected layer 167 (score: 0.2393)
#     Selected layer 132 (score: 0.2196)
#     Selected layer 172 (score: 0.2090)
#     Selected layer 127 (score: 0.1946)
#     Selected layer 177 (score: 0.1714)
#     Selected layer 122 (score: 0.1526)
#     Selected layer 117 (score: 0.1299)
#     Selected layer 182 (score: 0.1296)
#     Selected layer 112 (score: 0.1168)
#     Selected layer 107 (score: 0.1072)
#     Selected layer 187 (score: 0.1012)
#     Selected layer 102 (score: 0.0986)
#     Selected layer 97 (score: 0.0904)
#     Selected layer 92 (score: 0.0818)
#     Selected layer 192 (score: 0.0790)
#     Selected layer 87 (score: 0.0722)
#     Selected layer 197 (score: 0.0621)
#     Selected layer 82 (score: 0.0606)
#     Selected layer 77 (score: 0.0481)
#     Selected layer 202 (score: 0.0470)
#     Selected layer 72 (score: 0.0343)
#     Selected layer 207 (score: 0.0321)
#     Selected layer 67 (score: 0.0193)
#     Selected layer 212 (score: 0.0178)
#   Extracted layer 67 (rank 1, score: 0.0193)
#   Extracted layer 72 (rank 2, score: 0.0343)
#   Extracted layer 77 (rank 3, score: 0.0481)
#   Extracted layer 82 (rank 4, score: 0.0606)
#   Extracted layer 87 (rank 5, score: 0.0722)
#   Extracted layer 92 (rank 6, score: 0.0818)
#   Extracted layer 97 (rank 7, score: 0.0904)
#   Extracted layer 102 (rank 8, score: 0.0986)
#   Extracted layer 107 (rank 9, score: 0.1072)
#   Extracted layer 112 (rank 10, score: 0.1168)
#   Extracted layer 117 (rank 11, score: 0.1299)
#   Extracted layer 122 (rank 12, score: 0.1526)
#   Extracted layer 127 (rank 13, score: 0.1946)
#   Extracted layer 132 (rank 14, score: 0.2196)
#   Extracted layer 137 (rank 15, score: 0.2394)
#   Extracted layer 142 (rank 16, score: 0.2547)
#   Extracted layer 147 (rank 17, score: 0.2641)
#   Extracted layer 152 (rank 18, score: 0.2676)
#   Extracted layer 157 (rank 19, score: 0.2656)
#   Extracted layer 162 (rank 20, score: 0.2565)
#   Extracted layer 167 (rank 21, score: 0.2393)
#   Extracted layer 172 (rank 22, score: 0.2090)
#   Extracted layer 177 (rank 23, score: 0.1714)
#   Extracted layer 182 (rank 24, score: 0.1296)
#   Extracted layer 187 (rank 25, score: 0.1012)
#   Extracted layer 192 (rank 26, score: 0.0790)
#   Extracted layer 197 (rank 27, score: 0.0621)
#   Extracted layer 202 (rank 28, score: 0.0470)
#   Extracted layer 207 (rank 29, score: 0.0321)
#   Extracted layer 212 (rank 30, score: 0.0178)
#   ✅ Saved 30 layers
# Class 0 summary: 16/16 files processed, 480 layers saved
#
# 📁 Processing class: 1
# Found 21 NIfTI files
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\test\1\47-4881 R 2014_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1436.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 80 (score: 0.1963)
#     Selected layer 85 (score: 0.1940)
#     Selected layer 75 (score: 0.1926)
#     Selected layer 90 (score: 0.1882)
#     Selected layer 95 (score: 0.1807)
#     Selected layer 70 (score: 0.1802)
#     Selected layer 100 (score: 0.1711)
#     Selected layer 105 (score: 0.1575)
#     Selected layer 65 (score: 0.1554)
#     Selected layer 110 (score: 0.1404)
#     Selected layer 60 (score: 0.1250)
#     Selected layer 115 (score: 0.1077)
#     Selected layer 55 (score: 0.0952)
#     Selected layer 120 (score: 0.0744)
#     Selected layer 125 (score: 0.0644)
#     Selected layer 130 (score: 0.0563)
#     Selected layer 50 (score: 0.0556)
#     Selected layer 135 (score: 0.0492)
#     Selected layer 140 (score: 0.0433)
#     Selected layer 145 (score: 0.0387)
#     Selected layer 45 (score: 0.0361)
#     Selected layer 150 (score: 0.0336)
#     Selected layer 155 (score: 0.0271)
#     Selected layer 40 (score: 0.0232)
#     Selected layer 160 (score: 0.0182)
#     Selected layer 35 (score: 0.0123)
#     Selected layer 165 (score: 0.0088)
#     Selected layer 30 (score: 0.0029)
#     Selected layer 0 (score: 0.0000)
#     Selected layer 5 (score: 0.0000)
#   Extracted layer 0 (rank 1, score: 0.0000)
#   Extracted layer 5 (rank 2, score: 0.0000)
#   Extracted layer 30 (rank 3, score: 0.0029)
#   Extracted layer 35 (rank 4, score: 0.0123)
#   Extracted layer 40 (rank 5, score: 0.0232)
#   Extracted layer 45 (rank 6, score: 0.0361)
#   Extracted layer 50 (rank 7, score: 0.0556)
#   Extracted layer 55 (rank 8, score: 0.0952)
#   Extracted layer 60 (rank 9, score: 0.1250)
#   Extracted layer 65 (rank 10, score: 0.1554)
#   Extracted layer 70 (rank 11, score: 0.1802)
#   Extracted layer 75 (rank 12, score: 0.1926)
#   Extracted layer 80 (rank 13, score: 0.1963)
#   Extracted layer 85 (rank 14, score: 0.1940)
#   Extracted layer 90 (rank 15, score: 0.1882)
#   Extracted layer 95 (rank 16, score: 0.1807)
#   Extracted layer 100 (rank 17, score: 0.1711)
#   Extracted layer 105 (rank 18, score: 0.1575)
#   Extracted layer 110 (rank 19, score: 0.1404)
#   Extracted layer 115 (rank 20, score: 0.1077)
#   Extracted layer 120 (rank 21, score: 0.0744)
#   Extracted layer 125 (rank 22, score: 0.0644)
#   Extracted layer 130 (rank 23, score: 0.0563)
#   Extracted layer 135 (rank 24, score: 0.0492)
#   Extracted layer 140 (rank 25, score: 0.0433)
#   Extracted layer 145 (rank 26, score: 0.0387)
#   Extracted layer 150 (rank 27, score: 0.0336)
#   Extracted layer 155 (rank 28, score: 0.0271)
# ...
#     Selected layer 161 (score: 0.1850)
#     Selected layer 106 (score: 0.1848)
#     Selected layer 101 (score: 0.1629)
#     Selected layer 96 (score: 0.1440)
#     Selected layer 166 (score: 0.1410)
#     Selected layer 91 (score: 0.1300)
#     Selected layer 86 (score: 0.1167)
#     Selected layer 171 (score: 0.1146)
#     Selected layer 81 (score: 0.1035)
#     Selected layer 176 (score: 0.0939)
#     Selected layer 76 (score: 0.0905)
#     Selected layer 181 (score: 0.0768)
#     Selected layer 71 (score: 0.0765)
#     Selected layer 66 (score: 0.0627)
#     Selected layer 186 (score: 0.0623)
#     Selected layer 191 (score: 0.0503)
#     Selected layer 61 (score: 0.0472)
#     Selected layer 196 (score: 0.0397)
#     Selected layer 201 (score: 0.0287)
#     Selected layer 56 (score: 0.0285)
#   Extracted layer 56 (rank 1, score: 0.0285)
#   Extracted layer 61 (rank 2, score: 0.0472)
#   Extracted layer 66 (rank 3, score: 0.0627)
#   Extracted layer 71 (rank 4, score: 0.0765)
#   Extracted layer 76 (rank 5, score: 0.0905)
#   Extracted layer 81 (rank 6, score: 0.1035)
#   Extracted layer 86 (rank 7, score: 0.1167)
#   Extracted layer 91 (rank 8, score: 0.1300)
#   Extracted layer 96 (rank 9, score: 0.1440)
#   Extracted layer 101 (rank 10, score: 0.1629)
#   Extracted layer 106 (rank 11, score: 0.1848)
#   Extracted layer 111 (rank 12, score: 0.1970)
#   Extracted layer 116 (rank 13, score: 0.2053)
#   Extracted layer 121 (rank 14, score: 0.2111)
#   Extracted layer 126 (rank 15, score: 0.2166)
#   Extracted layer 131 (rank 16, score: 0.2212)
#   Extracted layer 136 (rank 17, score: 0.2245)
#   Extracted layer 141 (rank 18, score: 0.2257)
#   Extracted layer 146 (rank 19, score: 0.2244)
#   Extracted layer 151 (rank 20, score: 0.2220)
#   Extracted layer 156 (rank 21, score: 0.2158)
#   Extracted layer 161 (rank 22, score: 0.1850)
#   Extracted layer 166 (rank 23, score: 0.1410)
#   Extracted layer 171 (rank 24, score: 0.1146)
#   Extracted layer 176 (rank 25, score: 0.0939)
#   Extracted layer 181 (rank 26, score: 0.0768)
#   Extracted layer 186 (rank 27, score: 0.0623)
#   Extracted layer 191 (rank 28, score: 0.0503)
#   Extracted layer 196 (rank 29, score: 0.0397)
#   Extracted layer 201 (rank 30, score: 0.0287)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\train\0\54-17099 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1372.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 111 (score: 0.1850)
#     Selected layer 116 (score: 0.1843)
#     Selected layer 106 (score: 0.1836)
#     Selected layer 121 (score: 0.1813)
#     Selected layer 101 (score: 0.1791)
#     Selected layer 126 (score: 0.1754)
#     Selected layer 96 (score: 0.1711)
#     Selected layer 131 (score: 0.1652)
#     Selected layer 91 (score: 0.1594)
#     Selected layer 136 (score: 0.1525)
#     Selected layer 86 (score: 0.1441)
#     Selected layer 141 (score: 0.1371)
#     Selected layer 81 (score: 0.1255)
#     Selected layer 146 (score: 0.1209)
#     Selected layer 151 (score: 0.1082)
#     Selected layer 76 (score: 0.1021)
#     Selected layer 156 (score: 0.0946)
#     Selected layer 161 (score: 0.0817)
#     Selected layer 71 (score: 0.0806)
#     Selected layer 166 (score: 0.0694)
#     Selected layer 66 (score: 0.0645)
#     Selected layer 171 (score: 0.0569)
#     Selected layer 61 (score: 0.0519)
#     Selected layer 176 (score: 0.0441)
#     Selected layer 56 (score: 0.0402)
#     Selected layer 181 (score: 0.0325)
#     Selected layer 51 (score: 0.0292)
#     Selected layer 186 (score: 0.0215)
#     Selected layer 46 (score: 0.0180)
#     Selected layer 191 (score: 0.0118)
#   Extracted layer 46 (rank 1, score: 0.0180)
#   Extracted layer 51 (rank 2, score: 0.0292)
#   Extracted layer 56 (rank 3, score: 0.0402)
#   Extracted layer 61 (rank 4, score: 0.0519)
#   Extracted layer 66 (rank 5, score: 0.0645)
#   Extracted layer 71 (rank 6, score: 0.0806)
#   Extracted layer 76 (rank 7, score: 0.1021)
#   Extracted layer 81 (rank 8, score: 0.1255)
#   Extracted layer 86 (rank 9, score: 0.1441)
#   Extracted layer 91 (rank 10, score: 0.1594)
#   Extracted layer 96 (rank 11, score: 0.1711)
#   Extracted layer 101 (rank 12, score: 0.1791)
#   Extracted layer 106 (rank 13, score: 0.1836)
#   Extracted layer 111 (rank 14, score: 0.1850)
#   Extracted layer 116 (rank 15, score: 0.1843)
#   Extracted layer 121 (rank 16, score: 0.1813)
#   Extracted layer 126 (rank 17, score: 0.1754)
#   Extracted layer 131 (rank 18, score: 0.1652)
#   Extracted layer 136 (rank 19, score: 0.1525)
#   Extracted layer 141 (rank 20, score: 0.1371)
#   Extracted layer 146 (rank 21, score: 0.1209)
#   Extracted layer 151 (rank 22, score: 0.1082)
#   Extracted layer 156 (rank 23, score: 0.0946)
#   Extracted layer 161 (rank 24, score: 0.0817)
#   Extracted layer 166 (rank 25, score: 0.0694)
#   Extracted layer 171 (rank 26, score: 0.0569)
#   Extracted layer 176 (rank 27, score: 0.0441)
#   Extracted layer 181 (rank 28, score: 0.0325)
#   Extracted layer 186 (rank 29, score: 0.0215)
#   Extracted layer 191 (rank 30, score: 0.0118)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\train\0\54-21497 R 2014_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1473.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 89 (score: 0.2277)
#     Selected layer 84 (score: 0.2257)
#     Selected layer 94 (score: 0.2240)
#     Selected layer 79 (score: 0.2178)
#     Selected layer 99 (score: 0.2147)
#     Selected layer 74 (score: 0.2048)
#     Selected layer 104 (score: 0.2020)
#     Selected layer 109 (score: 0.1865)
#     Selected layer 69 (score: 0.1862)
#     Selected layer 114 (score: 0.1706)
#     Selected layer 64 (score: 0.1638)
#     Selected layer 119 (score: 0.1548)
#     Selected layer 124 (score: 0.1397)
#     Selected layer 59 (score: 0.1366)
#     Selected layer 129 (score: 0.1255)
#     Selected layer 134 (score: 0.1119)
#     Selected layer 139 (score: 0.1004)
#     Selected layer 54 (score: 0.0982)
#     Selected layer 144 (score: 0.0904)
#     Selected layer 149 (score: 0.0814)
#     Selected layer 154 (score: 0.0725)
#     Selected layer 159 (score: 0.0630)
#     Selected layer 49 (score: 0.0603)
#     Selected layer 164 (score: 0.0528)
#     Selected layer 169 (score: 0.0424)
#     Selected layer 44 (score: 0.0416)
#     Selected layer 174 (score: 0.0282)
#     Selected layer 39 (score: 0.0247)
#     Selected layer 179 (score: 0.0093)
#     Selected layer 34 (score: 0.0088)
#   Extracted layer 34 (rank 1, score: 0.0088)
#   Extracted layer 39 (rank 2, score: 0.0247)
#   Extracted layer 44 (rank 3, score: 0.0416)
#   Extracted layer 49 (rank 4, score: 0.0603)
#   Extracted layer 54 (rank 5, score: 0.0982)
#   Extracted layer 59 (rank 6, score: 0.1366)
#   Extracted layer 64 (rank 7, score: 0.1638)
#   Extracted layer 69 (rank 8, score: 0.1862)
#   Extracted layer 74 (rank 9, score: 0.2048)
#   Extracted layer 79 (rank 10, score: 0.2178)
#   Extracted layer 84 (rank 11, score: 0.2257)
#   Extracted layer 89 (rank 12, score: 0.2277)
#   Extracted layer 94 (rank 13, score: 0.2240)
#   Extracted layer 99 (rank 14, score: 0.2147)
#   Extracted layer 104 (rank 15, score: 0.2020)
#   Extracted layer 109 (rank 16, score: 0.1865)
#   Extracted layer 114 (rank 17, score: 0.1706)
#   Extracted layer 119 (rank 18, score: 0.1548)
#   Extracted layer 124 (rank 19, score: 0.1397)
#   Extracted layer 129 (rank 20, score: 0.1255)
#   Extracted layer 134 (rank 21, score: 0.1119)
#   Extracted layer 139 (rank 22, score: 0.1004)
#   Extracted layer 144 (rank 23, score: 0.0904)
#   Extracted layer 149 (rank 24, score: 0.0814)
#   Extracted layer 154 (rank 25, score: 0.0725)
#   Extracted layer 159 (rank 26, score: 0.0630)
#   Extracted layer 164 (rank 27, score: 0.0528)
#   Extracted layer 169 (rank 28, score: 0.0424)
#   Extracted layer 174 (rank 29, score: 0.0282)
#   Extracted layer 179 (rank 30, score: 0.0093)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\train\0\54-25927 R_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1392.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 113 (score: 0.2871)
#     Selected layer 108 (score: 0.2864)
#     Selected layer 118 (score: 0.2864)
#     Selected layer 103 (score: 0.2843)
#     Selected layer 123 (score: 0.2837)
#     Selected layer 98 (score: 0.2798)
#     Selected layer 128 (score: 0.2797)
#     Selected layer 133 (score: 0.2742)
#     Selected layer 93 (score: 0.2700)
#     Selected layer 138 (score: 0.2659)
#     Selected layer 143 (score: 0.2507)
#     Selected layer 88 (score: 0.2323)
#     Selected layer 148 (score: 0.2159)
#     Selected layer 83 (score: 0.1756)
#     Selected layer 153 (score: 0.1552)
#     Selected layer 78 (score: 0.1471)
#     Selected layer 158 (score: 0.1265)
#     Selected layer 73 (score: 0.1259)
#     Selected layer 68 (score: 0.1078)
#     Selected layer 163 (score: 0.1048)
#     Selected layer 63 (score: 0.0916)
#     Selected layer 168 (score: 0.0843)
#     Selected layer 58 (score: 0.0767)
#     Selected layer 173 (score: 0.0642)
#     Selected layer 53 (score: 0.0637)
#     Selected layer 48 (score: 0.0514)
#     Selected layer 178 (score: 0.0432)
#     Selected layer 43 (score: 0.0397)
#     Selected layer 38 (score: 0.0270)
#     Selected layer 183 (score: 0.0222)
#   Extracted layer 38 (rank 1, score: 0.0270)
#   Extracted layer 43 (rank 2, score: 0.0397)
#   Extracted layer 48 (rank 3, score: 0.0514)
#   Extracted layer 53 (rank 4, score: 0.0637)
#   Extracted layer 58 (rank 5, score: 0.0767)
#   Extracted layer 63 (rank 6, score: 0.0916)
#   Extracted layer 68 (rank 7, score: 0.1078)
#   Extracted layer 73 (rank 8, score: 0.1259)
#   Extracted layer 78 (rank 9, score: 0.1471)
#   Extracted layer 83 (rank 10, score: 0.1756)
#   Extracted layer 88 (rank 11, score: 0.2323)
#   Extracted layer 93 (rank 12, score: 0.2700)
#   Extracted layer 98 (rank 13, score: 0.2798)
#   Extracted layer 103 (rank 14, score: 0.2843)
#   Extracted layer 108 (rank 15, score: 0.2864)
#   Extracted layer 113 (rank 16, score: 0.2871)
#   Extracted layer 118 (rank 17, score: 0.2864)
#   Extracted layer 123 (rank 18, score: 0.2837)
#   Extracted layer 128 (rank 19, score: 0.2797)
#   Extracted layer 133 (rank 20, score: 0.2742)
#   Extracted layer 138 (rank 21, score: 0.2659)
#   Extracted layer 143 (rank 22, score: 0.2507)
#   Extracted layer 148 (rank 23, score: 0.2159)
#   Extracted layer 153 (rank 24, score: 0.1552)
#   Extracted layer 158 (rank 25, score: 0.1265)
#   Extracted layer 163 (rank 26, score: 0.1048)
#   Extracted layer 168 (rank 27, score: 0.0843)
#   Extracted layer 173 (rank 28, score: 0.0642)
#   Extracted layer 178 (rank 29, score: 0.0432)
#   Extracted layer 183 (rank 30, score: 0.0222)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\train\0\54-50 L_adjustedBG.nii.gz
#   Data shape: (255, 255, 255)
#   Data range: [-250.00, 1329.00]
#   Selecting 30 layers with minimum spacing of 5...
#     Selected layer 135 (score: 0.1975)
#     Selected layer 130 (score: 0.1962)
#     Selected layer 140 (score: 0.1958)
#     Selected layer 125 (score: 0.1938)
#     Selected layer 145 (score: 0.1906)
#     Selected layer 120 (score: 0.1899)
#     Selected layer 115 (score: 0.1849)
#     Selected layer 110 (score: 0.1812)
#     Selected layer 150 (score: 0.1809)
#     Selected layer 105 (score: 0.1775)
#     Selected layer 100 (score: 0.1715)
#     Selected layer 155 (score: 0.1650)
#     Selected layer 95 (score: 0.1640)
#     Selected layer 90 (score: 0.1547)
#     Selected layer 160 (score: 0.1427)
#     Selected layer 85 (score: 0.1400)
#     Selected layer 165 (score: 0.1234)
#     Selected layer 80 (score: 0.1176)
#     Selected layer 170 (score: 0.1069)
#     Selected layer 75 (score: 0.0987)
#     Selected layer 175 (score: 0.0912)
#     Selected layer 70 (score: 0.0838)
#     Selected layer 180 (score: 0.0750)
#     Selected layer 65 (score: 0.0704)
#     Selected layer 185 (score: 0.0583)
#     Selected layer 60 (score: 0.0564)
#     Selected layer 55 (score: 0.0424)
#     Selected layer 190 (score: 0.0403)
#     Selected layer 50 (score: 0.0259)
#     Selected layer 195 (score: 0.0212)
#   Extracted layer 50 (rank 1, score: 0.0259)
#   Extracted layer 55 (rank 2, score: 0.0424)
#   Extracted layer 60 (rank 3, score: 0.0564)
#   Extracted layer 65 (rank 4, score: 0.0704)
#   Extracted layer 70 (rank 5, score: 0.0838)
#   Extracted layer 75 (rank 6, score: 0.0987)
#   Extracted layer 80 (rank 7, score: 0.1176)
#   Extracted layer 85 (rank 8, score: 0.1400)
#   Extracted layer 90 (rank 9, score: 0.1547)
#   Extracted layer 95 (rank 10, score: 0.1640)
#   Extracted layer 100 (rank 11, score: 0.1715)
#   Extracted layer 105 (rank 12, score: 0.1775)
#   Extracted layer 110 (rank 13, score: 0.1812)
#   Extracted layer 115 (rank 14, score: 0.1849)
#   Extracted layer 120 (rank 15, score: 0.1899)
#   Extracted layer 125 (rank 16, score: 0.1938)
#   Extracted layer 130 (rank 17, score: 0.1962)
#   Extracted layer 135 (rank 18, score: 0.1975)
#   Extracted layer 140 (rank 19, score: 0.1958)
#   Extracted layer 145 (rank 20, score: 0.1906)
#   Extracted layer 150 (rank 21, score: 0.1809)
#   Extracted layer 155 (rank 22, score: 0.1650)
#   Extracted layer 160 (rank 23, score: 0.1427)
#   Extracted layer 165 (rank 24, score: 0.1234)
#   Extracted layer 170 (rank 25, score: 0.1069)
#   Extracted layer 175 (rank 26, score: 0.0912)
#   Extracted layer 180 (rank 27, score: 0.0750)
#   Extracted layer 185 (rank 28, score: 0.0583)
#   Extracted layer 190 (rank 29, score: 0.0403)
#   Extracted layer 195 (rank 30, score: 0.0212)
#   ✅ Saved 30 layers
#
# Processing: C:\Users\acer\Desktop\Project_TMJOA\Data\training_dataset_3D\train\0\54-50 R_adjustedBG.nii.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 323
#     321 # Process the dataset
#     322 print(f"\n🚀 Starting dataset processing...")
# --> 323 stats = process_dataset(INPUT_DATASET_DIR, OUTPUT_DATASET_DIR, N_LAYERS, MIN_SPACING, BACKGROUND_VALUE)
#     325 # Print final summary
#     326 print(f"\n{'='*60}")
#
# Cell In[6], line 289, in process_dataset(input_dataset_dir, output_dataset_dir, n_layers, min_spacing, background_value)
#     287 for nifti_file in nifti_files:
#     288     stats['total_files'] += 1
# --> 289     layers_saved = process_nifti_file(nifti_file, output_class_dir, n_layers, min_spacing, background_value)
#     291     if layers_saved > 0:
#     292         stats['processed_files'] += 1
#
# Cell In[6], line 194, in process_nifti_file(nifti_path, output_dir, n_layers, min_spacing, background_value)
#     192 # Load NIfTI file
#     193 nifti_img = nib.load(nifti_path)
# --> 194 data = nifti_img.get_fdata()
#     196 print(f"  Data shape: {data.shape}")
#     197 print(f"  Data range: [{data.min():.2f}, {data.max():.2f}]")
#
# File c:\Users\acer\anaconda3\envs\3dmodel\Lib\site-packages\nibabel\dataobj_images.py:374, in DataobjImage.get_fdata(self, caching, dtype)
#     370         return self._fdata_cache
#     371 # Always return requested data type
#     372 # For array proxies, will attempt to confine data array to dtype
#     373 # during scaling
# --> 374 data = np.asanyarray(self._dataobj, dtype=dtype)
#     375 if caching == 'fill':
#     376     self._fdata_cache = data
#
# File c:\Users\acer\anaconda3\envs\3dmodel\Lib\site-packages\nibabel\arrayproxy.py:454, in ArrayProxy.__array__(self, dtype)
#     433 def __array__(self, dtype=None):
#     434     """Read data from file and apply scaling, casting to ``dtype``
#     435
#     436     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)    452         Scaled image data with type `dtype`.
#     453     """
# --> 454     arr = self._get_scaled(dtype=dtype, slicer=())
#     455     if dtype is not None:
#     456         arr = arr.astype(dtype, copy=False)
#
# File c:\Users\acer\anaconda3\envs\3dmodel\Lib\site-packages\nibabel\arrayproxy.py:423, in ArrayProxy._get_scaled(self, dtype, slicer)
#     421 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     422 if dtype is not None:
# --> 423     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#     424 return scaled
#
# KeyboardInterrupt:
