# %%
import os
import pandas as pd
import shutil

def organize_images_by_erosion(csv_path, image_folder, output_base_folder):
    # Read the CSV file
    df = pd.read_csv(csv_path)
    
    # Create output folders
    erosion_0_folder = os.path.join(output_base_folder, 'erosion_0')
    erosion_1_folder = os.path.join(output_base_folder, 'erosion_1')
    os.makedirs(erosion_0_folder, exist_ok=True)
    os.makedirs(erosion_1_folder, exist_ok=True)
    
    # Create a dictionary for quick lookup
    erosion_dict = dict(zip(df['ID'], df['c_erosion']))
    
    # Process image files
    for filename in os.listdir(image_folder):
        if filename.lower().endswith('.nii.gz'):
            # Extract the base name (without _x_[3 digits])
            base_name = filename.split('.')[0]
            
            if base_name in erosion_dict:
                source_path = os.path.join(image_folder, filename)
                
                if erosion_dict[base_name] == 0:
                    dest_path = os.path.join(erosion_0_folder, filename)
                else:
                    dest_path = os.path.join(erosion_1_folder, filename)
                
                # Move the file
                shutil.move(source_path, dest_path)
                print(f"Moved {filename} to {'erosion_0' if erosion_dict[base_name] == 0 else 'erosion_1'}")
            else:
                print(f"No matching entry found for {filename}")
    
    print("File organization complete.")

# Usage
csv_path = r"D:\Kananat\Classification_1.csv"
image_folder = r"D:\Kananat\_dataset\train"
output_base_folder = r"D:\Kananat\_2d_dataset\train"

organize_images_by_erosion(csv_path, image_folder, output_base_folder)
# Out:
# Moved 47-16872 L.nii.gz to erosion_1
# Moved 47-16872 R.nii.gz to erosion_1
# Moved 47-22136 L.nii.gz to erosion_1
# Moved 47-4881 L 2014.nii.gz to erosion_1
# Moved 47-4881 L 2018.nii.gz to erosion_1
# Moved 47-4881 R 2014.nii.gz to erosion_1
# Moved 47-4881 R 2018.nii.gz to erosion_1
# Moved 48-26453 L.nii.gz to erosion_0
# Moved 48-5955 L.nii.gz to erosion_1
# Moved 48-5955 R.nii.gz to erosion_1
# Moved 49-18165 L.nii.gz to erosion_1
# Moved 49-3614 L.nii.gz to erosion_1
# Moved 49-3614 R.nii.gz to erosion_1
# Moved 50-30909 R.nii.gz to erosion_0
# Moved 51-26987 L.nii.gz to erosion_1
# Moved 51-26987 R.nii.gz to erosion_1
# Moved 51-28114 R.nii.gz to erosion_0
# Moved 51-3282 R.nii.gz to erosion_0
# Moved 52-11116 L.nii.gz to erosion_0
# Moved 52-11116 R.nii.gz to erosion_0
# Moved 52-15073 R.nii.gz to erosion_1
# Moved 52-15242 L.nii.gz to erosion_1
# Moved 52-18852 L.nii.gz to erosion_1
# Moved 52-18852 R.nii.gz to erosion_0
# Moved 52-27708 R.nii.gz to erosion_1
# Moved 52-37193 R.nii.gz to erosion_1
# Moved 53-12918 L.nii.gz to erosion_0
# Moved 53-13011 L.nii.gz to erosion_1
# Moved 53-13011 R.nii.gz to erosion_0
# Moved 53-26507 L.nii.gz to erosion_0
# Moved 54-1411 L.nii.gz to erosion_1
# Moved 54-1411 R.nii.gz to erosion_1
# Moved 54-17099 L.nii.gz to erosion_1
# Moved 54-17099 R.nii.gz to erosion_0
# Moved 54-21497 R 2014.nii.gz to erosion_0
# Moved 54-21497 R 2016.nii.gz to erosion_0
# Moved 54-25927 L.nii.gz to erosion_1
# Moved 54-25927 R.nii.gz to erosion_0
# Moved 54-50 R.nii.gz to erosion_0
# Moved 55-15078 L.nii.gz to erosion_0
# Moved 55-15078 R.nii.gz to erosion_1
# Moved 55-17177 L 2018.nii.gz to erosion_1
# Moved 55-17177 L 2020.nii.gz to erosion_1
# Moved 55-17177 R 2018.nii.gz to erosion_1
# Moved 55-17177 R 2020.nii.gz to erosion_1
# Moved 55-27313 L.nii.gz to erosion_0
# Moved 55-9422 L.nii.gz to erosion_0
# Moved 56-14343 L.nii.gz to erosion_1
# Moved 56-18364 L.nii.gz to erosion_0
# Moved 56-24221 L.nii.gz to erosion_0
# Moved 56-24221 R.nii.gz to erosion_0
# Moved 56-26683 L.nii.gz to erosion_1
# Moved 56-9695 L.nii.gz to erosion_1
# Moved 56-9695 R.nii.gz to erosion_1
# Moved 57-10397 L 2015.nii.gz to erosion_0
# Moved 57-10397 L 2018.nii.gz to erosion_0
# Moved 57-10397 R 2015.nii.gz to erosion_0
# Moved 57-12957 L.nii.gz to erosion_1
# Moved 57-12957 R.nii.gz to erosion_1
# Moved 57-16393 L.nii.gz to erosion_0
# Moved 57-16393 R.nii.gz to erosion_0
# Moved 57-24983 L.nii.gz to erosion_0
# Moved 57-28760 L.nii.gz to erosion_1
# Moved 57-28760 R.nii.gz to erosion_1
# Moved 57-29097 L.nii.gz to erosion_1
# Moved 57-29097 R.nii.gz to erosion_1
# Moved 57-30513 L.nii.gz to erosion_1
# Moved 57-30513 R.nii.gz to erosion_1
# Moved 57-34770 L.nii.gz to erosion_0
# Moved 57-36050 R.nii.gz to erosion_0
# Moved 58-15574 L.nii.gz to erosion_0
# Moved 58-23240 L.nii.gz to erosion_1
# Moved 58-38918 R.nii.gz to erosion_1
# Moved 58-42016 R.nii.gz to erosion_0
# Moved 58-43911 L.nii.gz to erosion_1
# Moved 58-43911 R.nii.gz to erosion_0
# Moved 58-9834 L.nii.gz to erosion_1
# Moved 58-9834 R.nii.gz to erosion_1
# Moved 59-14284 L.nii.gz to erosion_0
# Moved 59-14284 R.nii.gz to erosion_1
# Moved 59-27051 L.nii.gz to erosion_0
# Moved 59-31824 L.nii.gz to erosion_1
# Moved 59-33496 L.nii.gz to erosion_1
# Moved 59-33496 R.nii.gz to erosion_1
# Moved 59-35009 L.nii.gz to erosion_1
# Moved 59-36616 L.nii.gz to erosion_0
# Moved 59-36616 R.nii.gz to erosion_0
# Moved 59-38408 L.nii.gz to erosion_1
# Moved 59-39978 R.nii.gz to erosion_1
# Moved 59-6269 L.nii.gz to erosion_0
# Moved 60-16447 L.nii.gz to erosion_1
# Moved 60-16447 R.nii.gz to erosion_1
# Moved 60-21851 L.nii.gz to erosion_0
# Moved 60-24908 L 2017.nii.gz to erosion_1
# Moved 60-24908 L 2023.nii.gz to erosion_1
# Moved 60-24908 R 2023.nii.gz to erosion_1
# Moved 60-25232 R.nii.gz to erosion_1
# Moved 60-2688 R.nii.gz to erosion_1
# Moved 60-2918 L.nii.gz to erosion_1
# Moved 60-30757 R.nii.gz to erosion_0
# Moved 60-33107 L.nii.gz to erosion_1
# Moved 60-33597 L 2017.nii.gz to erosion_1
# Moved 60-33597 L 2019 03 11.nii.gz to erosion_1
# Moved 60-33597 L 2019 09 02.nii.gz to erosion_1
# Moved 60-34373 L 2017.nii.gz to erosion_0
# Moved 60-34373 L 2019.nii.gz to erosion_0
# Moved 60-34373 R 2019.nii.gz to erosion_1
# Moved 60-39505 L.nii.gz to erosion_1
# Moved 60-39505 R.nii.gz to erosion_1
# Moved 60-4194 L.nii.gz to erosion_1
# Moved 60-700759 L.nii.gz to erosion_0
# Moved 60-700759 R.nii.gz to erosion_0
# Moved 60-700919 L.nii.gz to erosion_0
# Moved 60-701005 L 2017.nii.gz to erosion_1
# Moved 60-701005 L 2021.nii.gz to erosion_1
# Moved 60-701042 L.nii.gz to erosion_1
# Moved 60-701042 R.nii.gz to erosion_1
# Moved 60-701142 L.nii.gz to erosion_0
# Moved 60-701166 L.nii.gz to erosion_0
# Moved 60-701166 R.nii.gz to erosion_0
# Moved 60-7166 L.nii.gz to erosion_0
# Moved 60-9722 R.nii.gz to erosion_1
# Moved 61-13344 L.nii.gz to erosion_1
# Moved 61-14198 L.nii.gz to erosion_1
# Moved 61-16015 R 2022.nii.gz to erosion_1
# Moved 61-18860 L.nii.gz to erosion_0
# Moved 61-18860 R.nii.gz to erosion_0
# Moved 61-20310 L.nii.gz to erosion_0
# Moved 61-20310 R.nii.gz to erosion_1
# Moved 61-21027 L.nii.gz to erosion_0
# Moved 61-21027 R.nii.gz to erosion_0
# Moved 61-21564 R.nii.gz to erosion_0
# Moved 61-25724 L.nii.gz to erosion_1
# Moved 61-25724 R.nii.gz to erosion_0
# Moved 61-32062 R.nii.gz to erosion_0
# Moved 61-33141 L.nii.gz to erosion_0
# Moved 61-33141 R.nii.gz to erosion_0
# Moved 61-34247 L.nii.gz to erosion_0
# Moved 61-34247 R.nii.gz to erosion_1
# Moved 61-5225 L.nii.gz to erosion_1
# Moved 61-5586 R.nii.gz to erosion_0
# Moved 61-6974 L.nii.gz to erosion_1
# Moved 61-700034 L.nii.gz to erosion_0
# Moved 61-700034 R.nii.gz to erosion_0
# Moved 61-700101 L.nii.gz to erosion_0
# Moved 61-700554 L.nii.gz to erosion_0
# Moved 61-700554 R.nii.gz to erosion_0
# Moved 61-700847 L.nii.gz to erosion_1
# Moved 61-700847 R.nii.gz to erosion_0
# Moved 61-701246 L.nii.gz to erosion_0
# Moved 61-701246 R.nii.gz to erosion_0
# Moved 62-13410 L.nii.gz to erosion_1
# Moved 62-13410 R.nii.gz to erosion_1
# Moved 62-1401 L.nii.gz to erosion_0
# Moved 62-14053 L.nii.gz to erosion_1
# Moved 62-14053 R.nii.gz to erosion_1
# Moved 62-21678 L.nii.gz to erosion_1
# Moved 62-2274 R 2019.nii.gz to erosion_1
# Moved 62-23102 L.nii.gz to erosion_1
# Moved 62-23102 R.nii.gz to erosion_0
# Moved 62-24379 R.nii.gz to erosion_1
# Moved 62-24749 L.nii.gz to erosion_1
# Moved 62-24749 R.nii.gz to erosion_0
# Moved 62-25311 R.nii.gz to erosion_0
# Moved 62-25333 L.nii.gz to erosion_0
# Moved 62-25333 R.nii.gz to erosion_1
# Moved 62-26639 L.nii.gz to erosion_1
# Moved 62-26639 R.nii.gz to erosion_1
# Moved 62-27556 L.nii.gz to erosion_0
# Moved 62-27556 R.nii.gz to erosion_0
# Moved 62-30049 L.nii.gz to erosion_0
# Moved 62-30049 R.nii.gz to erosion_0
# Moved 62-330 L.nii.gz to erosion_1
# No matching entry found for 62-330 R.nii.gz
# Moved 62-34626 R.nii.gz to erosion_0
# Moved 62-701148 R.nii.gz to erosion_1
# Moved 62-701261 L.nii.gz to erosion_0
# Moved 62-7533 L 2021.nii.gz to erosion_0
# Moved 62-7533 R 2020.nii.gz to erosion_1
# Moved 62-8585 L.nii.gz to erosion_0
# Moved 62-8585 R.nii.gz to erosion_1
# Moved 63-12252 L.nii.gz to erosion_0
# Moved 63-15359 R.nii.gz to erosion_1
# Moved 63-17862 L.nii.gz to erosion_1
# Moved 63-17862 R.nii.gz to erosion_1
# Moved 63-17877 L.nii.gz to erosion_0
# Moved 63-17957 L.nii.gz to erosion_0
# Moved 63-17957 R.nii.gz to erosion_1
# Moved 63-2829 L.nii.gz to erosion_0
# Moved 63-700385 L.nii.gz to erosion_0
# Moved 63-700449 L.nii.gz to erosion_0
# Moved 63-700449 R.nii.gz to erosion_0
# Moved 63-7894 L.nii.gz to erosion_1
# Moved 63-7894 R.nii.gz to erosion_1
# Moved 64-10402 L 2023 02 08.nii.gz to erosion_1
# Moved 64-10402 R 2023 02 08.nii.gz to erosion_0
# Moved 64-10402 R 2023 11 21.nii.gz to erosion_0
# Moved 64-3795 L.nii.gz to erosion_0
# Moved 64-6935 R.nii.gz to erosion_1
# Moved 64-700092 L.nii.gz to erosion_1
# Moved 64-700178 L.nii.gz to erosion_0
# Moved 64-700383 L.nii.gz to erosion_0
# Moved 64-7881 R.nii.gz to erosion_0
# Moved 64-7936 L.nii.gz to erosion_1
# Moved 64-7936 R.nii.gz to erosion_1
# Moved 64-7980 L.nii.gz to erosion_1
# Moved 64-7980 R.nii.gz to erosion_0
# Moved 64-8619 L 2022.nii.gz to erosion_0
# Moved 64-8619 R 2021.nii.gz to erosion_1
# Moved 65-14582 R 2022.nii.gz to erosion_1
# Moved 65-14920 R.nii.gz to erosion_1
# Moved 65-1579 L.nii.gz to erosion_1
# Moved 65-20101 L.nii.gz to erosion_1
# Moved 65-20101 R.nii.gz to erosion_0
# Moved 65-20231 L.nii.gz to erosion_0
# Moved 65-20231 R.nii.gz to erosion_0
# Moved 65-23331 L.nii.gz to erosion_0
# Moved 65-23331 R.nii.gz to erosion_1
# Moved 65-24090 L 2023 11 17.nii.gz to erosion_0
# Moved 65-24090 R 2023 11 17.nii.gz to erosion_0
# Moved 65-24090 R 2023 11 29.nii.gz to erosion_0
# Moved 65-2425 L 2022 10 03.nii.gz to erosion_1
# Moved 65-2425 L 2023.nii.gz to erosion_1
# Moved 65-2425 R 2022 02 17.nii.gz to erosion_0
# Moved 65-2425 R 2022 10 03.nii.gz to erosion_0
# Moved 65-25886 R.nii.gz to erosion_0
# Moved 65-27050 R.nii.gz to erosion_0
# Moved 65-27889 L.nii.gz to erosion_0
# Moved 65-4483 L.nii.gz to erosion_1
# Moved 65-4998 L.nii.gz to erosion_1
# Moved 65-4998 R.nii.gz to erosion_1
# Moved 65-700003 L.nii.gz to erosion_1
# Moved 65-700131 L.nii.gz to erosion_0
# Moved 65-700131 R.nii.gz to erosion_0
# Moved 65-700405 L.nii.gz to erosion_1
# Moved 65-700405 R.nii.gz to erosion_1
# Moved 65-8582 R.nii.gz to erosion_1
# Moved 66-13889 R.nii.gz to erosion_0
# Moved 66-18213 L.nii.gz to erosion_0
# Moved 66-18213 R.nii.gz to erosion_0
# Moved 66-20679 L.nii.gz to erosion_1
# Moved 66-2177 R.nii.gz to erosion_0
# Moved 66-218 L 2023 06 16.nii.gz to erosion_0
# Moved 66-23248 L 2023 11 29.nii.gz to erosion_0
# Moved 66-23248 R 2023 11 29.nii.gz to erosion_1
# Moved 66-4559 L.nii.gz to erosion_1
# Moved 66-59 L.nii.gz to erosion_1
# Moved 66-59 R.nii.gz to erosion_1
# Moved 66-700261 R.nii.gz to erosion_1
# Moved 66-700314 L.nii.gz to erosion_1
# Moved 66-700314 R.nii.gz to erosion_0
# Moved 66-700362 L.nii.gz to erosion_1
# Moved 66-700362 R.nii.gz to erosion_0
# Moved 66-700404 L.nii.gz to erosion_1
# Moved 66-700681 L.nii.gz to erosion_1
# File organization complete.

# %%
import os
import cv2
import albumentations as A
import numpy as np
from tqdm import tqdm

def create_medical_augmentation():
    """
    Create an augmentation pipeline suitable for medical images
    """
    transform = A.Compose([
        # Spatial transforms
        A.ShiftScaleRotate(
            shift_limit=0.0625, 
            scale_limit=0.1, 
            rotate_limit=45, 
            border_mode=cv2.BORDER_CONSTANT, 
            p=0.5
        ),
        
        # Noise and blur
        A.OneOf([
            A.GaussNoise(var_limit=(10.0, 50.0), p=1.0),
            A.GaussianBlur(blur_limit=(3, 7), p=1.0),
        ], p=0.3),
        
        # Contrast and brightness
        A.OneOf([
            A.RandomBrightnessContrast(
                brightness_limit=0.2,
                contrast_limit=0.2,
                p=1.0
            ),
            A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), p=1.0)
        ], p=0.3),
    ])
    return transform

def process_folder(input_folder, output_folder, num_augmentations=3):
    """
    Apply augmentations to all images in a folder
    """
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)
    
    # Get list of jpg files
    image_files = [f for f in os.listdir(input_folder) 
                  if f.lower().endswith('.jpg') or f.lower().endswith('.jpeg')]
    
    # Create augmentation pipeline
    transform = create_medical_augmentation()
    
    # Process each image
    for image_file in tqdm(image_files, desc="Processing images"):
        # Read image
        image_path = os.path.join(input_folder, image_file)
        image = cv2.imread(image_path)
        if image is None:
            print(f"Failed to read image: {image_file}")
            continue
            
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        # Get filename without extension
        filename = os.path.splitext(image_file)[0]
        
        # Create augmented versions
        for i in range(num_augmentations):
            # Apply augmentation
            augmented = transform(image=image)['image']
            
            # Convert back to BGR for saving
            augmented_bgr = cv2.cvtColor(augmented, cv2.COLOR_RGB2BGR)
            
            # Save augmented image
            output_path = os.path.join(
                output_folder, 
                f"{filename}_aug_{i+1}.jpg"  # Changed to .jpg
            )
            cv2.imwrite(output_path, augmented_bgr)

# %%
# Example usage
input_folder = r"D:\Kananat\_dataset_2d\train\erosion_1"  # Replace with your input folder path
output_folder = r"D:\Kananat\_dataset_2d\train_augmented\erosion_1"  # Replace with your output folder path

process_folder(
    input_folder=input_folder,
    output_folder=output_folder,
    num_augmentations=5  # Number of augmented versions per image
)
# Out:
# Processing images: 100%|██████████| 1519/1519 [00:22<00:00, 68.79it/s]
