# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -------------------
# absl-py                      2.1.0
# aiohttp                      3.9.5
# aiosignal                    1.2.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-timeout                4.0.3
# attrs                        23.1.0
# blinker                      1.6.2
# Brotli                       1.0.9
# cachetools                   5.3.3
# certifi                      2024.7.4
# cffi                         1.16.0
# charset-normalizer           3.3.2
# click                        8.1.7
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.2.1
# cryptography                 43.0.0
# cycler                       0.12.1
# debugpy                      1.8.5
# decorator                    5.1.1
# dm-tree                      0.1.8
# exceptiongroup               1.2.2
# executing                    2.0.1
# ...
