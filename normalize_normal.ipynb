# %%
import numpy as np

def squeeze_bg(data, bg_value=0):
    """
    Crop 3D image to smallest bounding box containing all non-background voxels.
    
    Parameters:
    -----------
    data : numpy.ndarray
        3D image array from nii_img.get_fdata()
    bg_value : float or int
        Background value (default: 0)
    
    Returns:
    --------
    numpy.ndarray
        Cropped 3D image array
    """
    # Find indices where data is not background
    non_bg = np.where(data != bg_value)
    
    # If entire image is background, return as is
    if len(non_bg[0]) == 0:
        return data
    
    # Find bounding box coordinates
    min_x, max_x = non_bg[0].min(), non_bg[0].max()
    min_y, max_y = non_bg[1].min(), non_bg[1].max()
    min_z, max_z = non_bg[2].min(), non_bg[2].max()
    
    # Crop the image (add 1 to max indices to include them)
    cropped = data[min_x:max_x+1, min_y:max_y+1, min_z:max_z+1]
    
    return cropped

# %%
import numpy as np

def pad_crop_to_cube(data, n, pad_value=0):
    """
    Pad and crop 3D image to (n, n, n) dimension.
    Padding is applied on both sides, cropping removes from the back.
    
    Parameters:
    -----------
    data : numpy.ndarray
        3D image array
    n : int
        Target dimension size for all axes
    pad_value : float or int
        Value to use for padding (default: 0)
    
    Returns:
    --------
    numpy.ndarray
        Resized 3D image array of shape (n, n, n)
    """
    current_shape = data.shape
    
    # Process each axis independently
    for axis in range(3):
        current_size = data.shape[axis]
        
        if current_size < n:
            # Padding needed - pad on both sides
            total_pad = n - current_size
            pad_before = total_pad // 2
            pad_after = total_pad - pad_before
            
            # Create padding configuration
            pad_width = [(0, 0), (0, 0), (0, 0)]
            pad_width[axis] = (pad_before, pad_after)
            
            # Apply padding
            data = np.pad(data, pad_width, mode='constant', constant_values=pad_value)
            
        elif current_size > n:
            # Cropping needed - crop from the back
            if axis == 0:
                data = data[:n, :, :]
            elif axis == 1:
                data = data[:, :n, :]
            else:  # axis == 2
                data = data[:, :, :n]
    
    return data

# %%
import nibabel as nib
from pathlib import Path

input_folder = Path(r"D:\Kananat\Data\Last0\2_Masked")
output_folder = Path(r"D:\Kananat\Data\Last0\3_Preprocessed")

i = 0
for file in input_folder.glob("*.nii.gz"):
    i+=1
    print(f"{i} Processing file: {file.name}")

    file_path = str(file)
    nii_img = nib.load(file_path)

    data = nii_img.get_fdata()
    data = np.clip(data, -400, 1600)
    data = squeeze_bg(data, bg_value=-400)
    data = pad_crop_to_cube(data, n=256, pad_value=-400)
    data = (data + 400) / 2000  # Normalize to [0, 1]

    new_img = nib.Nifti1Image(data.astype(np.float32), nii_img.affine, nii_img.header)
    output_path = output_folder / file.name.replace("_masked.nii.gz", "_preprocessed.nii.gz")
    
    nib.save(new_img, output_path)
print("Done")
# Out:
# 1 Processing file: 47-16872 L_masked.nii.gz
# 2 Processing file: 47-16872 R_masked.nii.gz
# 3 Processing file: 47-22136 L_masked.nii.gz
# 4 Processing file: 47-22136 R_masked.nii.gz
# 5 Processing file: 47-4881 L 2014_masked.nii.gz
# 6 Processing file: 47-4881 L 2018_masked.nii.gz
# 7 Processing file: 47-4881 R 2014_masked.nii.gz
# 8 Processing file: 47-4881 R 2018_masked.nii.gz
# 9 Processing file: 48-26453 L_masked.nii.gz
# 10 Processing file: 48-5955 L_masked.nii.gz
# 11 Processing file: 48-5955 R_masked.nii.gz
# 12 Processing file: 49-18165 L_masked.nii.gz
# 13 Processing file: 49-18165 R_masked.nii.gz
# 14 Processing file: 49-3614 L_masked.nii.gz
# 15 Processing file: 49-3614 R_masked.nii.gz
# 16 Processing file: 50-11620 L 20250213_masked.nii.gz
# 17 Processing file: 50-11620 R 20250213_masked.nii.gz
# 18 Processing file: 50-30909 R_masked.nii.gz
# 19 Processing file: 51-26987 L_masked.nii.gz
# 20 Processing file: 51-26987 R_masked.nii.gz
# 21 Processing file: 51-28114 L_masked.nii.gz
# 22 Processing file: 51-28114 R_masked.nii.gz
# 23 Processing file: 51-3282 L_masked.nii.gz
# 24 Processing file: 51-3282 R_masked.nii.gz
# 25 Processing file: 52-11116 L_masked.nii.gz
# 26 Processing file: 52-11116 R_masked.nii.gz
# 27 Processing file: 52-15073 L_masked.nii.gz
# 28 Processing file: 52-15073 R_masked.nii.gz
# 29 Processing file: 52-15242 L_masked.nii.gz
# 30 Processing file: 52-15242 R_masked.nii.gz
# 31 Processing file: 52-18852 L 20160526_masked.nii.gz
# 32 Processing file: 52-18852 L_masked.nii.gz
# 33 Processing file: 52-18852 R 20160526_masked.nii.gz
# 34 Processing file: 52-18852 R_masked.nii.gz
# 35 Processing file: 52-27708 R_masked.nii.gz
# 36 Processing file: 52-37193 L 20160405_masked.nii.gz
# 37 Processing file: 52-37193 L_masked.nii.gz
# 38 Processing file: 52-37193 R 20160405_masked.nii.gz
# 39 Processing file: 52-37193 R_masked.nii.gz
# 40 Processing file: 53-12918 L_masked.nii.gz
# 41 Processing file: 53-12918 R_masked.nii.gz
# 42 Processing file: 53-13011 L_masked.nii.gz
# 43 Processing file: 53-13011 R_masked.nii.gz
# 44 Processing file: 53-22559 L_masked.nii.gz
# 45 Processing file: 53-22559 R_masked.nii.gz
# 46 Processing file: 53-24700 L_masked.nii.gz
# 47 Processing file: 53-24700 R_masked.nii.gz
# 48 Processing file: 53-26507 L_masked.nii.gz
# 49 Processing file: 53-26507 R_masked.nii.gz
# 50 Processing file: 54-1411 L_masked.nii.gz
# 51 Processing file: 54-1411 R_masked.nii.gz
# 52 Processing file: 54-17099 L_masked.nii.gz
# 53 Processing file: 54-17099 R_masked.nii.gz
# 54 Processing file: 54-21497 L 2014_masked.nii.gz
# 55 Processing file: 54-21497 L 2016_masked.nii.gz
# 56 Processing file: 54-21497 R 2014_masked.nii.gz
# 57 Processing file: 54-21497 R 2016_masked.nii.gz
# 58 Processing file: 54-25927 L 20160424_masked.nii.gz
# 59 Processing file: 54-25927 L_masked.nii.gz
# 60 Processing file: 54-25927 R 20160424_masked.nii.gz
# 61 Processing file: 54-25927 R_masked.nii.gz
# 62 Processing file: 54-50 L 20160226_masked.nii.gz
# 63 Processing file: 54-50 L_masked.nii.gz
# 64 Processing file: 54-50 R 20160226_masked.nii.gz
# 65 Processing file: 54-50 R_masked.nii.gz
# 66 Processing file: 55-15078 L_masked.nii.gz
# 67 Processing file: 55-15078 R_masked.nii.gz
# 68 Processing file: 55-1648 L_masked.nii.gz
# 69 Processing file: 55-1648 R_masked.nii.gz
# 70 Processing file: 55-17177 L 2018_masked.nii.gz
# 71 Processing file: 55-17177 L 2020_masked.nii.gz
# 72 Processing file: 55-17177 R 2018_masked.nii.gz
# 73 Processing file: 55-17177 R 2020_masked.nii.gz
# 74 Processing file: 55-27313 L_masked.nii.gz
# 75 Processing file: 55-9422 L_masked.nii.gz
# 76 Processing file: 55-9422 R_masked.nii.gz
# 77 Processing file: 56-14343 L_masked.nii.gz
# 78 Processing file: 56-18364 L_masked.nii.gz
# 79 Processing file: 56-18364 R_masked.nii.gz
# 80 Processing file: 56-19232 L_masked.nii.gz
# 81 Processing file: 56-24221 L_masked.nii.gz
# 82 Processing file: 56-24221 R_masked.nii.gz
# 83 Processing file: 56-26683 L_masked.nii.gz
# 84 Processing file: 56-27847 L_masked.nii.gz
# 85 Processing file: 56-27847 R_masked.nii.gz
# 86 Processing file: 56-30067 R 20240131_masked.nii.gz
# 87 Processing file: 56-9695 L_masked.nii.gz
# 88 Processing file: 56-9695 R_masked.nii.gz
# 89 Processing file: 57-10397 L 2015_masked.nii.gz
# 90 Processing file: 57-10397 L 2018_masked.nii.gz
# 91 Processing file: 57-10397 R 2015_masked.nii.gz
# 92 Processing file: 57-10397 R 2018_masked.nii.gz
# 93 Processing file: 57-12957 L_masked.nii.gz
# 94 Processing file: 57-12957 R_masked.nii.gz
# 95 Processing file: 57-16393 L_masked.nii.gz
# 96 Processing file: 57-16393 R_masked.nii.gz
# 97 Processing file: 57-24048 L_masked.nii.gz
# 98 Processing file: 57-24983 L 20160702_masked.nii.gz
# 99 Processing file: 57-24983 L_masked.nii.gz
# 100 Processing file: 57-24983 R 20160702_masked.nii.gz
# 101 Processing file: 57-24983 R_masked.nii.gz
# 102 Processing file: 57-28760 L_masked.nii.gz
# 103 Processing file: 57-28760 R_masked.nii.gz
# 104 Processing file: 57-29097 L_masked.nii.gz
# 105 Processing file: 57-29097 R_masked.nii.gz
# 106 Processing file: 57-30513 L_masked.nii.gz
# 107 Processing file: 57-30513 R_masked.nii.gz
# 108 Processing file: 57-34770 L 20160117_masked.nii.gz
# 109 Processing file: 57-34770 L_masked.nii.gz
# 110 Processing file: 57-34770 R 20160117_masked.nii.gz
# 111 Processing file: 57-34770 R_masked.nii.gz
# 112 Processing file: 57-36050 L_masked.nii.gz
# 113 Processing file: 57-36050 R_masked.nii.gz
# 114 Processing file: 58-15574 L_masked.nii.gz
# 115 Processing file: 58-15574 R_masked.nii.gz
# 116 Processing file: 58-23240 L_masked.nii.gz
# 117 Processing file: 58-23240 R_masked.nii.gz
# 118 Processing file: 58-32020 R_masked.nii.gz
# 119 Processing file: 58-38918 L_masked.nii.gz
# 120 Processing file: 58-38918 R_masked.nii.gz
# 121 Processing file: 58-41636 L 20160129_masked.nii.gz
# 122 Processing file: 58-41636 R 20160129_masked.nii.gz
# 123 Processing file: 58-42016 L_masked.nii.gz
# 124 Processing file: 58-42016 R_masked.nii.gz
# 125 Processing file: 58-43911 L_masked.nii.gz
# 126 Processing file: 58-43911 R_masked.nii.gz
# 127 Processing file: 58-651 L_masked.nii.gz
# 128 Processing file: 58-651 R_masked.nii.gz
# 129 Processing file: 58-9834 L_masked.nii.gz
# 130 Processing file: 58-9834 R_masked.nii.gz
# 131 Processing file: 59-14284 L_masked.nii.gz
# 132 Processing file: 59-14284 R_masked.nii.gz
# 133 Processing file: 59-23032 R_masked.nii.gz
# 134 Processing file: 59-2326 L 20160220_masked.nii.gz
# 135 Processing file: 59-2326 R 20160220_masked.nii.gz
# 136 Processing file: 59-24008 L_masked.nii.gz
# 137 Processing file: 59-27051 L_masked.nii.gz
# 138 Processing file: 59-27051 R_masked.nii.gz
# 139 Processing file: 59-31824 L_masked.nii.gz
# 140 Processing file: 59-31824 R_masked.nii.gz
# 141 Processing file: 59-33496 L_masked.nii.gz
# 142 Processing file: 59-33496 R_masked.nii.gz
# 143 Processing file: 59-35009 L_masked.nii.gz
# 144 Processing file: 59-35009 R_masked.nii.gz
# 145 Processing file: 59-36616 L_masked.nii.gz
# 146 Processing file: 59-36616 R_masked.nii.gz
# 147 Processing file: 59-38408 L_masked.nii.gz
# 148 Processing file: 59-39978 L_masked.nii.gz
# 149 Processing file: 59-39978 R_masked.nii.gz
# 150 Processing file: 59-6269 L 20160326_masked.nii.gz
# 151 Processing file: 59-6269 L_masked.nii.gz
# 152 Processing file: 59-6269 R 20160326_masked.nii.gz
# 153 Processing file: 60-16447 L_masked.nii.gz
# 154 Processing file: 60-16447 R_masked.nii.gz
# 155 Processing file: 60-21851 L_masked.nii.gz
# 156 Processing file: 60-21851 R_masked.nii.gz
# 157 Processing file: 60-24908 L 2017_masked.nii.gz
# 158 Processing file: 60-24908 L 2023_masked.nii.gz
# 159 Processing file: 60-24908 R 2017_masked.nii.gz
# 160 Processing file: 60-24908 R 2023_masked.nii.gz
# 161 Processing file: 60-25232 L_masked.nii.gz
# 162 Processing file: 60-25232 R_masked.nii.gz
# 163 Processing file: 60-2688 L_masked.nii.gz
# 164 Processing file: 60-2688 R_masked.nii.gz
# 165 Processing file: 60-2918 L_masked.nii.gz
# 166 Processing file: 60-30757 R_masked.nii.gz
# 167 Processing file: 60-33107 L_masked.nii.gz
# 168 Processing file: 60-33107 R_masked.nii.gz
# 169 Processing file: 60-33597 L 2017_masked.nii.gz
# 170 Processing file: 60-33597 L 2019 03 11_masked.nii.gz
# 171 Processing file: 60-33597 L 2019 09 02_masked.nii.gz
# 172 Processing file: 60-34373 L 2017_masked.nii.gz
# 173 Processing file: 60-34373 L 2019_masked.nii.gz
# 174 Processing file: 60-34373 L 20241008_masked.nii.gz
# 175 Processing file: 60-34373 R 2017_masked.nii.gz
# 176 Processing file: 60-34373 R 2019_masked.nii.gz
# 177 Processing file: 60-34373 R 20241008_masked.nii.gz
# 178 Processing file: 60-38868 R_masked.nii.gz
# 179 Processing file: 60-39505 L_masked.nii.gz
# 180 Processing file: 60-39505 R_masked.nii.gz
# 181 Processing file: 60-4194 L_masked.nii.gz
# 182 Processing file: 60-4194 R_masked.nii.gz
# 183 Processing file: 60-700759 L_masked.nii.gz
# 184 Processing file: 60-700759 R_masked.nii.gz
# 185 Processing file: 60-700919 L_masked.nii.gz
# 186 Processing file: 60-700919 R_masked.nii.gz
# 187 Processing file: 60-701005 L 2017_masked.nii.gz
# 188 Processing file: 60-701005 L 2021_masked.nii.gz
# 189 Processing file: 60-701005 R 2017_masked.nii.gz
# 190 Processing file: 60-701005 R 2021_masked.nii.gz
# 191 Processing file: 60-701042 L_masked.nii.gz
# 192 Processing file: 60-701042 R_masked.nii.gz
# 193 Processing file: 60-701142 L_masked.nii.gz
# 194 Processing file: 60-701142 R_masked.nii.gz
# 195 Processing file: 60-701166 L_masked.nii.gz
# 196 Processing file: 60-701166 R_masked.nii.gz
# 197 Processing file: 60-701195 L_masked.nii.gz
# 198 Processing file: 60-7166 L_masked.nii.gz
# 199 Processing file: 60-7166 R_masked.nii.gz
# 200 Processing file: 60-9722 L_masked.nii.gz
# 201 Processing file: 60-9722 R_masked.nii.gz
# 202 Processing file: 61-13344 L_masked.nii.gz
# 203 Processing file: 61-13344 R_masked.nii.gz
# 204 Processing file: 61-14198 L_masked.nii.gz
# 205 Processing file: 61-14198 R_masked.nii.gz
# 206 Processing file: 61-16015 L_masked.nii.gz
# 207 Processing file: 61-16015 R 2022_masked.nii.gz
# 208 Processing file: 61-18860 L_masked.nii.gz
# 209 Processing file: 61-18860 R_masked.nii.gz
# 210 Processing file: 61-20310 L_masked.nii.gz
# 211 Processing file: 61-20310 R_masked.nii.gz
# 212 Processing file: 61-21027 L_masked.nii.gz
# 213 Processing file: 61-21027 R_masked.nii.gz
# 214 Processing file: 61-21564 L_masked.nii.gz
# 215 Processing file: 61-21564 R_masked.nii.gz
# 216 Processing file: 61-25724 L_masked.nii.gz
# 217 Processing file: 61-25724 R_masked.nii.gz
# 218 Processing file: 61-32062 L_masked.nii.gz
# 219 Processing file: 61-32062 R_masked.nii.gz
# 220 Processing file: 61-33141 L_masked.nii.gz
# 221 Processing file: 61-33141 R_masked.nii.gz
# 222 Processing file: 61-34247 L_masked.nii.gz
# 223 Processing file: 61-34247 R_masked.nii.gz
# 224 Processing file: 61-5225 L_masked.nii.gz
# 225 Processing file: 61-5586 L_masked.nii.gz
# 226 Processing file: 61-5586 R_masked.nii.gz
# 227 Processing file: 61-6974 L_masked.nii.gz
# 228 Processing file: 61-6974 R_masked.nii.gz
# 229 Processing file: 61-700034 L_masked.nii.gz
# 230 Processing file: 61-700034 R_masked.nii.gz
# 231 Processing file: 61-700101 L_masked.nii.gz
# 232 Processing file: 61-700101 R_masked.nii.gz
# 233 Processing file: 61-700554 L_masked.nii.gz
# 234 Processing file: 61-700554 R_masked.nii.gz
# 235 Processing file: 61-700847 L_masked.nii.gz
# 236 Processing file: 61-700847 R_masked.nii.gz
# 237 Processing file: 61-701246 L_masked.nii.gz
# 238 Processing file: 61-701246 R_masked.nii.gz
# 239 Processing file: 62-12734 R_masked.nii.gz
# 240 Processing file: 62-12908 R_masked.nii.gz
# 241 Processing file: 62-13410 L_masked.nii.gz
# 242 Processing file: 62-13410 R_masked.nii.gz
# 243 Processing file: 62-1401 L_masked.nii.gz
# 244 Processing file: 62-14053 L_masked.nii.gz
# 245 Processing file: 62-14053 R_masked.nii.gz
# 246 Processing file: 62-21678 L_masked.nii.gz
# 247 Processing file: 62-2274 R 2019_masked.nii.gz
# 248 Processing file: 62-2274 R 2021_masked.nii.gz
# 249 Processing file: 62-23102 L_masked.nii.gz
# 250 Processing file: 62-23102 R_masked.nii.gz
# 251 Processing file: 62-24379 R_masked.nii.gz
# 252 Processing file: 62-24749 L_masked.nii.gz
# 253 Processing file: 62-24749 R_masked.nii.gz
# 254 Processing file: 62-25311 R_masked.nii.gz
# 255 Processing file: 62-25333 L_masked.nii.gz
# 256 Processing file: 62-25333 R_masked.nii.gz
# 257 Processing file: 62-26639 L_masked.nii.gz
# 258 Processing file: 62-26639 R_masked.nii.gz
# 259 Processing file: 62-27556 L_masked.nii.gz
# 260 Processing file: 62-27556 R_masked.nii.gz
# 261 Processing file: 62-30049 L_masked.nii.gz
# 262 Processing file: 62-30049 R_masked.nii.gz
# 263 Processing file: 62-330 L_masked.nii.gz
# 264 Processing file: 62-330 R_masked.nii.gz
# 265 Processing file: 62-34626 R_masked.nii.gz
# 266 Processing file: 62-435 L_masked.nii.gz
# 267 Processing file: 62-435 R_masked.nii.gz
# 268 Processing file: 62-700605 R_masked.nii.gz
# 269 Processing file: 62-700851 L_masked.nii.gz
# 270 Processing file: 62-700851 R_masked.nii.gz
# 271 Processing file: 62-701148 L_masked.nii.gz
# 272 Processing file: 62-701148 R_masked.nii.gz
# 273 Processing file: 62-701248 R_masked.nii.gz
# 274 Processing file: 62-701261 L_masked.nii.gz
# 275 Processing file: 62-701261 R_masked.nii.gz
# 276 Processing file: 62-7533 L 2021_masked.nii.gz
# 277 Processing file: 62-7533 R 2020_masked.nii.gz
# 278 Processing file: 62-7533 R 2021_masked.nii.gz
# 279 Processing file: 62-8585 L_masked.nii.gz
# 280 Processing file: 62-8585 R_masked.nii.gz
# 281 Processing file: 63-0010001 L 20240527_masked.nii.gz
# 282 Processing file: 63-0010001 R 20240527_masked.nii.gz
# 283 Processing file: 63-12252 L_masked.nii.gz
# 284 Processing file: 63-12252 R_masked.nii.gz
# 285 Processing file: 63-1330 L_masked.nii.gz
# 286 Processing file: 63-1330 R_masked.nii.gz
# 287 Processing file: 63-15359 L_masked.nii.gz
# 288 Processing file: 63-15359 R_masked.nii.gz
# 289 Processing file: 63-17862 L_masked.nii.gz
# 290 Processing file: 63-17862 R_masked.nii.gz
# 291 Processing file: 63-17877 L_masked.nii.gz
# 292 Processing file: 63-17877 R_masked.nii.gz
# 293 Processing file: 63-17957 L_masked.nii.gz
# 294 Processing file: 63-17957 R_masked.nii.gz
# 295 Processing file: 63-20205 L_masked.nii.gz
# 296 Processing file: 63-20205 R_masked.nii.gz
# 297 Processing file: 63-2829 L_masked.nii.gz
# 298 Processing file: 63-700223 L_masked.nii.gz
# 299 Processing file: 63-700223 R_masked.nii.gz
# 300 Processing file: 63-700385 L_masked.nii.gz
# 301 Processing file: 63-700385 R_masked.nii.gz
# 302 Processing file: 63-700449 L_masked.nii.gz
# 303 Processing file: 63-700449 R_masked.nii.gz
# 304 Processing file: 63-7894 L_masked.nii.gz
# 305 Processing file: 63-7894 R_masked.nii.gz
# 306 Processing file: 63-9054 L 20240308_masked.nii.gz
# 307 Processing file: 63-9054 R 20240308_masked.nii.gz
# 308 Processing file: 64-10402 L 2023 02 08_masked.nii.gz
# 309 Processing file: 64-10402 R 2023 02 08_masked.nii.gz
# 310 Processing file: 64-10402 R 2023 11 21_masked.nii.gz
# 311 Processing file: 64-10902 L_masked.nii.gz
# 312 Processing file: 64-10902 R_masked.nii.gz
# 313 Processing file: 64-3795 L_masked.nii.gz
# 314 Processing file: 64-6935 L_masked.nii.gz
# 315 Processing file: 64-6935 R_masked.nii.gz
# 316 Processing file: 64-700092 L_masked.nii.gz
# 317 Processing file: 64-700178 L_masked.nii.gz
# 318 Processing file: 64-700383 L_masked.nii.gz
# 319 Processing file: 64-7881 L_masked.nii.gz
# 320 Processing file: 64-7881 R_masked.nii.gz
# 321 Processing file: 64-7936 L_masked.nii.gz
# 322 Processing file: 64-7936 R_masked.nii.gz
# 323 Processing file: 64-7980 L_masked.nii.gz
# 324 Processing file: 64-7980 R_masked.nii.gz
# 325 Processing file: 64-8619 L 2021_masked.nii.gz
# 326 Processing file: 64-8619 L 2022_masked.nii.gz
# 327 Processing file: 64-8619 R 2021_masked.nii.gz
# 328 Processing file: 65-11496 L_masked.nii.gz
# 329 Processing file: 65-14582 R 2022_masked.nii.gz
# 330 Processing file: 65-14582 R 2023_masked.nii.gz
# 331 Processing file: 65-14920 L_masked.nii.gz
# 332 Processing file: 65-14920 R_masked.nii.gz
# 333 Processing file: 65-1579 L_masked.nii.gz
# 334 Processing file: 65-1579 R_masked.nii.gz
# 335 Processing file: 65-20101 L_masked.nii.gz
# 336 Processing file: 65-20101 R_masked.nii.gz
# 337 Processing file: 65-20231 L_masked.nii.gz
# 338 Processing file: 65-20231 R_masked.nii.gz
# 339 Processing file: 65-23331 L_masked.nii.gz
# 340 Processing file: 65-23331 R_masked.nii.gz
# 341 Processing file: 65-24090 L 2023 11 17_masked.nii.gz
# 342 Processing file: 65-24090 R 2023 11 17_masked.nii.gz
# 343 Processing file: 65-24090 R 2023 11 29_masked.nii.gz
# 344 Processing file: 65-2425 L 2022 02 17_masked.nii.gz
# 345 Processing file: 65-2425 L 2022 10 03_masked.nii.gz
# 346 Processing file: 65-2425 L 2023_masked.nii.gz
# 347 Processing file: 65-2425 R 2022 02 17_masked.nii.gz
# 348 Processing file: 65-2425 R 2022 10 03_masked.nii.gz
# 349 Processing file: 65-2425 R 2023_masked.nii.gz
# 350 Processing file: 65-25886 R_masked.nii.gz
# 351 Processing file: 65-26867 L_masked.nii.gz
# 352 Processing file: 65-26867 R_masked.nii.gz
# 353 Processing file: 65-27050 R_masked.nii.gz
# 354 Processing file: 65-27889 L_masked.nii.gz
# 355 Processing file: 65-32395 L 20250123_masked.nii.gz
# 356 Processing file: 65-4483 L_masked.nii.gz
# 357 Processing file: 65-4618 L 20241218_masked.nii.gz
# 358 Processing file: 65-4618 R 20241218_masked.nii.gz
# 359 Processing file: 65-4998 L_masked.nii.gz
# 360 Processing file: 65-4998 R_masked.nii.gz
# 361 Processing file: 65-700003 L_masked.nii.gz
# 362 Processing file: 65-700003 R_masked.nii.gz
# 363 Processing file: 65-700131 L_masked.nii.gz
# 364 Processing file: 65-700131 R_masked.nii.gz
# 365 Processing file: 65-700197 L_masked.nii.gz
# 366 Processing file: 65-700197 R_masked.nii.gz
# 367 Processing file: 65-700405 L_masked.nii.gz
# 368 Processing file: 65-700405 R_masked.nii.gz
# 369 Processing file: 65-8582 R_masked.nii.gz
# 370 Processing file: 66-12948 R_masked.nii.gz
# 371 Processing file: 66-13889 R_masked.nii.gz
# 372 Processing file: 66-1461 R 20250319_masked.nii.gz
# 373 Processing file: 66-18213 L_masked.nii.gz
# 374 Processing file: 66-18213 R_masked.nii.gz
# 375 Processing file: 66-20679 L_masked.nii.gz
# 376 Processing file: 66-21702 L_masked.nii.gz
# 377 Processing file: 66-2177 L_masked.nii.gz
# 378 Processing file: 66-2177 R_masked.nii.gz
# 379 Processing file: 66-218 L 2023 06 16_masked.nii.gz
# 380 Processing file: 66-218 R 2023 06 16_masked.nii.gz
# 381 Processing file: 66-22465 R 20240527_masked.nii.gz
# 382 Processing file: 66-23248 L 2023 11 29_masked.nii.gz
# 383 Processing file: 66-23248 R 2023 11 29_masked.nii.gz
# 384 Processing file: 66-4559 L_masked.nii.gz
# 385 Processing file: 66-4559 R_masked.nii.gz
# 386 Processing file: 66-59 L_masked.nii.gz
# 387 Processing file: 66-59 R_masked.nii.gz
# 388 Processing file: 66-700261 L_masked.nii.gz
# 389 Processing file: 66-700261 R_masked.nii.gz
# 390 Processing file: 66-700314 L_masked.nii.gz
# 391 Processing file: 66-700314 R_masked.nii.gz
# 392 Processing file: 66-700362 L_masked.nii.gz
# 393 Processing file: 66-700362 R_masked.nii.gz
# 394 Processing file: 66-700404 L_masked.nii.gz
# 395 Processing file: 66-700404 R_masked.nii.gz
# 396 Processing file: 66-700681 L_masked.nii.gz
# 397 Processing file: 66-700681 R_masked.nii.gz
# 398 Processing file: 66-8695 R 20241114_masked.nii.gz
# 399 Processing file: 67-10136 R 20241208_masked.nii.gz
# 400 Processing file: 67-24015 L 20250213_masked.nii.gz
# 401 Processing file: 67-24015 R 20250213_masked.nii.gz
# 402 Processing file: 67-700034 L 20240127_masked.nii.gz
# 403 Processing file: 67-700034 R 20240127_masked.nii.gz
# 404 Processing file: 67-9653 L 20240701_masked.nii.gz
# 405 Processing file: 68-700050 L 20250226_masked.nii.gz
# 406 Processing file: 68-700050 R 20250226_masked.nii.gz
# 407 Processing file: 68-700244 L 20250419_masked.nii.gz
# Done
